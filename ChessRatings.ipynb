# %% [markdown]
# # Midterm 1, Fall 2021: Chess Ratings #
#
# _Version 1.0_
#
# [Solution](https://gatech.instructure.com/courses/411942/files/52015055?wrap=1)
#
# Change Log:
# 1.0 - Initial Release
#
# This problem builds on your knowledge of **Python data structures, string processing, and implementing mathematical functions**.
#
# For other preliminaries and pointers, refer back to the Piazza post titled **"Midterm 1 Release Notes"**.
# - Total Exercises: **8**
# - Total Points: **16**
# - Time Limit: **3 Hours**
#
# Each exercise builds logically on the previous one, but you may **solve them in any order**. That is, if you can't solve an exercise, you can still move on and try the next one. **However, if you see a code cell introduced by the phrase, "Sample result for ...", please run it.** Some demo cells in the notebook may depend on these precomputed results.
#
# The point values of individual exercises are as follows:
#
# - Exercise 0: 3 points
# - Exercise 1: 2 points
# - Exercise 2: 1 points
# - Exercise 3: 2 points
# - Exercise 4: 1 points
# - Exercise 5: 3 points
# - Exercise 6: 2 points
# - Exercise 7: 2 points
#
#
# **Good luck!**

# %% [markdown]
# ## Elo Ratings
#
# The Elo (rhymes with "Hello") rating system is a widely used method for quantifying relative skill levels of players in a game or sport. The method was originally used to rate chess players and is named for its creator, Arpad Elo. This system is very simple but is able to rate players much more effectively than a win/loss record.
#
# On a high level, the winning player in a game takes rating points away from the losing player. How many points change hands is determined by the difference in the initial ratings of each player. For example, if a highly rated player records a victory over a lower rated player, then they would gain only a few points. This is reflective of the highly rated player being expected to win. However, if the lower rated player is able to pull off an upset, a larger quantity of points would be exchanged. The idea is that over time the system will adjust players' ratings to their true relative skill levels. Additionally, the difference in Elo ratings between two players can be used to calculate the expectation for the number of wins each player would accrue, which is often expressed as "win probability".
#
# Here we will extract data from a recent chess tournament that captures players' ratings at the start of the tournament and the outcome of all games played. We will then use that data to calculate expected wins based on the matchups and compare our expectation with the observed results. Finally we will determine the updated Elo ratings for the players. There are many variations on this system, but here we will use the original version. You can find more information about the Elo rating system [here](https://en.wikipedia.org/wiki/Elo_rating_system)
#
# Let's get started by taking a look at the data!

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

import run_tests as test_utils
raw_data = test_utils.read_raw_data('Bucharest2021.pgn')
test_utils.get_mem_usage_str()
# Out:
# '47.6 MiB'

# %% [markdown]
# Take note of how the data is **split** into sections by **blank lines** (`'\n\n'`); this fact might be useful later on! _(hint! hint!)_ Here are the first 4 sections.

# %%
demo_raw_data = '\n\n'.join(raw_data.split('\n\n')[:4])
print(demo_raw_data)
# Out:
# [Event "Superbet Classic 2021"]
# [Site "Bucharest ROU"]
# [Date "2021.06.05"]
# [Round "1.5"]
# [White "Deac,Bogdan-Daniel"]
# [Black "Giri,A"]
# [Result "1/2-1/2"]
# [WhiteElo "2627"]
# [BlackElo "2780"]
# [ECO "D43"]
#
# 1.d4 d5 2.c4 c6 3.Nc3 Nf6 4.Nf3 e6 5.Bg5 h6 6.Bh4 dxc4 7.e4 g5 8.Bg3 b5 9.Be2 Bb7
# 10.Qc2 Nh5 11.Rd1 Nxg3 12.hxg3 Na6 13.a3 Bg7 14.e5 Qe7 15.Ne4 O-O-O 16.Nd6+ Rxd6
# 17.exd6 Qxd6 18.O-O g4 19.Ne5 Bxe5 20.dxe5 Qxe5 21.Bxg4 h5 22.Rfe1 Qf6 23.Bf3 h4
# 24.b3 cxb3 25.Qxb3 hxg3 26.fxg3 Qg7 27.Qd3 Nc7 28.Qd6 c5 29.Qd7+ Kb8 30.Bxb7 Kxb7
# 31.Rxe6 Qxg3 32.Qc6+ Kb8 33.Qd6 Qxd6 34.Rexd6 Kb7 35.Rf6 Rh7 36.Rd7 b4 37.axb4 cxb4
# 38.Kf2 a5 39.Ke2 Rg7 40.Rfxf7 Rxg2+ 41.Kd1 Rg1+ 42.Kc2 Rg2+ 43.Kb1 Rg1+ 44.Kb2 Rg2+
# 45.Kb1 Rg1+ 46.Kb2 Rg2+ 47.Kb1 Rg1+  1/2-1/2
#
# [Event "Superbet Classic 2021"]
# [Site "Bucharest ROU"]
# [Date "2021.06.05"]
# [Round "1.4"]
# [White "Lupulescu,C"]
# [Black "Aronian,L"]
# [Result "1/2-1/2"]
# [WhiteElo "2656"]
# [BlackElo "2781"]
# [ECO "E39"]
#
# 1.d4 Nf6 2.c4 e6 3.Nc3 Bb4 4.Qc2 c5 5.dxc5 O-O 6.Nf3 Na6 7.g3 Nxc5 8.Bg2 Nce4
# 9.O-O Nxc3 10.bxc3 Be7 11.e4 d6 12.e5 dxe5 13.Nxe5 Qc7 14.Qe2 Nd7 15.Bf4 Nxe5
# 16.Bxe5 Bd6 17.Bxd6 Qxd6 18.Qe3 Qc7 19.Rfb1 Qxc4 20.Bxb7 Bxb7 21.Rxb7 h6
# 22.Rxa7 Rxa7 23.Qxa7 Qxc3 24.Rb1 Qc2 25.Rb8 Qd1+ 26.Kg2 Qd5+ 27.Kg1 Qd1+
# 28.Kg2 Qd5+ 29.Kg1 Qd1+  1/2-1/2

# %% [markdown]
# The sections in the raw data alternate between **metadata** and **moves data**. The metadata is information about the game, such as who is playing with what pieces, the ratings of each player, and the results of the game. The moves data contains a record of each chess move executed in the game. Since players' Elo ratings are only affected by the outcomes of the games, we are primarily concerned with the metadata.

# %% [markdown]
# ## Exercise 0 (3 points)
#
# The first thing we need to do in our analysis is get the data in a more structured form.
#
# Fill out the function `extract_games(raw_data)` in the code cell below with the following requirements:
#
# Given a string read from a text file `raw_data`, extract the following information about each game and store in a **list of dictionaries** `games`. Below are details for what one of these dictionaries should look like:
# * `games[i]['white_player']` - String - Name of the player assigned the white pieces.
#   * Example from `raw_data`: [White "Deac,Bogdan-Daniel"]
#   * Example value: `'Deac,Bogdan-Daniel'`
#   * Value type: `str`
#
#
# * `games[i]['black_player']` - String - Name of the player assigned the black pieces.
#   * Example from `raw_data`: [Black "Giri,A"]
#   * Example value: `'Giri,A'`
#   * Value type: `str`
#
#
# * `games[i]['white_rating']` - Integer - Pre-tournament rating of the white player.
#   * Example from `raw_data`: [WhiteElo "2627"]
#   * Example value: `2627`
#   * Value type: `int`
#
#
# * `games[i]['black_rating']` - Integer - Pre-tournament rating of the black player.
#   * Example from `raw_data`: [BlackElo "2780"]
#   * Example value: `2780`
#   * Value type: `int`
#
#
# * `games[i]['result']` - String - Result of the game.
#   * Example from `raw_data`: [Result "1/2-1/2"]
#   * Example value: `'1/2-1/2'`
#   * Value type: `str`
#
# You may assume that the required metadata is included, that sections are separated by blank lines, and that the sections alternate between metadata and moves data (starting with metadata). Additional metadata tags (beyond the 5 you are tasked with extracting) may be present, but they should be ignored. The ordering of the metadata **may be different** from the example above. Additionally, the moves data sections **may not be formatted** the same way as the example above.
#
# A demo of your function run on the `demo_raw_data` defined above is included in the solution cell. The result should be:
# ```
# [{  'white_player': 'Deac,Bogdan-Daniel',
#     'black_player': 'Giri,A',
#     'result': '1/2-1/2',
#     'white_rating': 2627,
#     'black_rating': 2780},
#   { 'white_player': 'Lupulescu,C',
#     'black_player': 'Aronian,L',
#     'result': '1/2-1/2',
#     'white_rating': 2656,
#     'black_rating': 2781}]
# ```

# %% [markdown]
# To help you get started, consider the following snippet, which converts `demo_raw_data` into a nested list of lists. A similar strategy may be helpful in processing the `raw_data` parameter in the exercise.

# %%
demo_metadata_list = [metadata.splitlines() for metadata in demo_raw_data.split('\n\n')[::2]]
print(f'type(demo_metadata_list[0]): {type(demo_metadata_list[0])}') # outer list items are lists
print(f'type(demo_metadata_list[0][0]): {type(demo_metadata_list[0][0])}') # inner list items are strings
demo_metadata_list
# Out:
# type(demo_metadata_list[0]): <class 'list'>
# type(demo_metadata_list[0][0]): <class 'str'>
# [['[Event "Superbet Classic 2021"]',
#   '[Site "Bucharest ROU"]',
#   '[Date "2021.06.05"]',
#   '[Round "1.5"]',
#   '[White "Deac,Bogdan-Daniel"]',
#   '[Black "Giri,A"]',
#   '[Result "1/2-1/2"]',
#   '[WhiteElo "2627"]',
#   '[BlackElo "2780"]',
#   '[ECO "D43"]'],
#  ['[Event "Superbet Classic 2021"]',
#   '[Site "Bucharest ROU"]',
#   '[Date "2021.06.05"]',
#   '[Round "1.4"]',
#   '[White "Lupulescu,C"]',
#   '[Black "Aronian,L"]',
#   '[Result "1/2-1/2"]',
#   '[WhiteElo "2656"]',
#   '[BlackElo "2781"]',
#   '[ECO "E39"]']]

# %%
def extract_games(raw_data):
    import re
    ###
    data = raw_data.split("\n")
    White = []
    Black = []
    result = []
    whiteRating = []
    blackRating = []
    output = []
    
    for i in data:
        m = re.search('((White ")(.*)("))', i) #White Player
        if type(m) is re.Match:
            ext_string = m.group(3)
            White.append(ext_string)
            
        n = re.search('((Black ")(.*)("))', i) #Black Player 
        if type(n) is re.Match:
            ext_string = n.group(3)
            Black.append(ext_string)        
            
        o = re.search('((Result ")(.*)("))', i) #Result 
        if type(o) is re.Match:
            ext_string = o.group(3)
            result.append(ext_string)    
            
        p = re.search('((WhiteElo ")(.*)("))', i) #White Rating 
        if type(p) is re.Match:
            ext_string = p.group(3)
            whiteRating.append(int(ext_string))
            
        q = re.search('((BlackElo ")(.*)("))', i) #Black Rating 
        if type(q) is re.Match:
            ext_string = q.group(3)
            blackRating.append(int(ext_string))
            
    for i in range(len(White)):
        newDict = {"white_player": White[i], "black_player": Black[i], "result": result[i],
                   "white_rating": whiteRating[i], "black_rating": blackRating[i]}
        output.append(newDict)
        
    return output
    ###

# Demo
extract_games(demo_raw_data)
# Out:
# [{'white_player': 'Deac,Bogdan-Daniel',
#   'black_player': 'Giri,A',
#   'result': '1/2-1/2',
#   'white_rating': 2627,
#   'black_rating': 2780},
#  {'white_player': 'Lupulescu,C',
#   'black_player': 'Aronian,L',
#   'result': '1/2-1/2',
#   'white_rating': 2656,
#   'black_rating': 2781}]

# %% [markdown]
# The test cell below runs your function **many times**. Remove or comment out any `print` statements to avoid generating excessive output.

# %%
# `ex0_test`: Test cell
from run_tests import ex0_test
for _ in range(100):
    ex0_test(10, 4, extract_games)
print('Passed!')

###
### AUTOGRADER TEST - DO NOT REMOVE
###
test_utils.get_mem_usage_str()
# Out:
# Passed!
# '47.9 MiB'

# %% [markdown]
# **Run the following cell, even if you skipped Exercise 0.**
#
# We are loading a pre-computed solution that will be used in the following sections. The first two sections items in the list are displayed.

# %%
# Sample result for ex0
games_metadata = test_utils.read_pickle('games_metadata')
print(games_metadata[:2])
test_utils.get_mem_usage_str()
# Out:
# [{'white_player': 'Deac,Bogdan-Daniel', 'black_player': 'Giri,A', 'result': '1/2-1/2', 'white_rating': 2627, 'black_rating': 2780}, {'white_player': 'Lupulescu,C', 'black_player': 'Aronian,L', 'result': '1/2-1/2', 'white_rating': 2656, 'black_rating': 2781}]
# '47.9 MiB'

# %% [markdown]
# ## Exercise 1 (2 points)
#
# The next bit of information we will need in our analysis is the outcome of each player's games paired with their opponent.
#
# Fill out the function `extract_player_results(games)` in the code cell below with the following requirements:
#
# Given `games`, a list of dictionaries containing the metadata for each game, create dictionary `player_results` mapping each player's name to a list of the outcomes of that player's games. Each outcome should include the opponent's name (String) and the number of points that the player received (Float) as the outcome of the game as a Tuple.
#
# The order of tuples in the list associated with each player should be the **same as the order of the matchups in `games`**.
#
# You should interpret the value associated with `'result'` as `"<white player points>-<black player points>"` separated by a dash "-". There are three possible outcomes of a game of chess: White wins (`'1-0'`), black wins (`'0-1'`), or draw (`'1/2-1/2'`).
#
# For example, if the input is:
#
# `[{'white_player': 'Dwight Schrute', 'black_player: 'Jim Halpert', 'result': '1-0'}, {'white_player': 'Stanley Hudson', 'black_player': 'Dwight Schrute', 'result': '1/2-1/2'}]`
#
# Then the output should be:
#
# `{'Dwight Schrute': [('Jim Halpert', 1.0), ('Stanley Hudson', 0.5)], 'Jim Halpert': [('Dwight Schrute', 0.0)], 'Stanley Hudson': [('Dwight Schrute', 0.5)]}`
#
# You can assume that each dictionary in `games` will have the keys `'white_player'`, `'black_player'`, and `'result'` and that the values associated with each of those keys are Strings. There may be duplicated matchups where the same two players are paired in the tournament more than once. These cases should be handled the same as any other game and do not require any special treatment.

# %%
demo_games_metadata = [{'white_player': 'Dwight Schrute', 'black_player': 'Jim Halpert', 'result': '1-0'}, {'white_player': 'Stanley Hudson', 'black_player': 'Dwight Schrute', 'result': '1/2-1/2'}]

# %%
def extract_player_results(games):
    ###
    from collections import defaultdict
    results = defaultdict(list)
    for game in games:
        white, black = game['white_player'], game['black_player']
        if game['result'] == "1-0":
            w_pts = 1.0
        elif game['result'] == "0-1":
            w_pts = 0.0
        else:
            w_pts = 0.5
        b_pts = 1-w_pts
        results[white].append((black,w_pts))
        results[black].append((white,b_pts))
    return results
    ###

# Demo
extract_player_results(demo_games_metadata)
# Out:
# defaultdict(list,
#             {'Dwight Schrute': [('Jim Halpert', 1.0), ('Stanley Hudson', 0.5)],
#              'Jim Halpert': [('Dwight Schrute', 0.0)],
#              'Stanley Hudson': [('Dwight Schrute', 0.5)]})

# %% [markdown]
# The test cell below runs your function **many times**. Remove or comment out any `print` statements to avoid generating excessive output.

# %%
# `ex1_test`: Test cell
from run_tests import ex1_test
for _ in range(100):
    ex1_test(10, 4, extract_player_results)
print('Passed!')

###
### AUTOGRADER TEST - DO NOT REMOVE
###
test_utils.get_mem_usage_str()
# Out:
# Passed!
# '48.1 MiB'

# %% [markdown]
# **Run the following cell, even if you skipped Exercise 1.**
#
# We are loading a pre-computed solution that will be used in the following sections. The first two entries are displayed.

# %%
# Sample result for ex1
player_results = test_utils.read_pickle('player_results')
{k:v for k, v in list(player_results.items())[:2]}
# Out:
# {'Deac,Bogdan-Daniel': [('Giri,A', 0.5),
#   ('Vachier', 1.0),
#   ('Mamedyarov,S', 0.5),
#   ('Grischuk,A', 0.0),
#   ('So,W', 0.5),
#   ('Radjabov,T', 0.5),
#   ('Lupulescu,C', 0.5),
#   ('Aronian,L', 0.0),
#   ('Caruana,F', 0.5)],
#  'Giri,A': [('Deac,Bogdan-Daniel', 0.5),
#   ('Radjabov,T', 0.5),
#   ('Lupulescu,C', 0.0),
#   ('Aronian,L', 0.5),
#   ('Caruana,F', 0.5),
#   ('So,W', 0.5),
#   ('Vachier', 1.0),
#   ('Grischuk,A', 0.5)]}

# %% [markdown]
# ## Exercise 2 (1 point)
#
# Our next task is to compute the total tournament score for each player.
#
# Fill in the function `calculate_score(player_results)` satisfying the following requirements:
#
# Given a dictionary `player_results` mapping player names to their tournament results (similar to the output of Excercise 1), create a **new** dictionary `player_scores` that maps each player (String) to their total score for the tournament (Float).
#
# For example, given the following input:
#
# `{'Angela Martin': [('Oscar Martinez', 1.0), ('Kevin Malone', 0.5), ('Andy Bernard', 0.0)], 'Michael Scott': [('Pam Halpert', 0.0), ('Toby Flenderson', 0.0), ('Todd Packer', 0.0)]}`
#
# Your function should output:
#
# `{'Angela Martin': 1.5, 'Michael Scott': 0.0}`
#
# (Michael isn't exactly a chess prodigy...)
#
# You can assume that the lists keyed to each String in the input will be of the form (String, Float). You do not need to worry about verifying that all of the games implied by the input are present. If you look closely at the example, you will see that this is **not** the case.

# %%
demo_player_results = {'Angela Martin': [('Oscar Martinez', 1.0), ('Kevin Malone', 0.5), ('Andy Bernard', 0.0)], 'Michael Scott': [('Pam Halpert', 0.0), ('Toby Flenderson', 0.0), ('Todd Packer', 0.0)]}

# %%
def calculate_score(player_results):
    ###
    from collections import defaultdict
    results = defaultdict(int)
    lstPlayer = list(player_results.keys())
    totalValue = 0

    for i in lstPlayer:
        results[i]
        
    for keys in player_results:
        x = player_results.get(keys)
        print(x)
        for j in x:
            totalValue+=j[1]
        results[keys]=totalValue
        totalValue=0

    return results
    ###

# Demo
calculate_score(demo_player_results)
# Out:
# [('Oscar Martinez', 1.0), ('Kevin Malone', 0.5), ('Andy Bernard', 0.0)]
# [('Pam Halpert', 0.0), ('Toby Flenderson', 0.0), ('Todd Packer', 0.0)]
# defaultdict(int, {'Angela Martin': 1.5, 'Michael Scott': 0.0})

# %% [markdown]
# The test cell below runs your function **many times**. Remove or comment out any `print` statements to avoid generating excessive output.

# %%
# `ex2_test`: Test cell
from run_tests import ex2_test
for _ in range(200):
    ex2_test(10, 4, calculate_score)
print('Passed!')

###
### AUTOGRADER TEST - DO NOT REMOVE
###
test_utils.get_mem_usage_str()
# Out:
# [('Azkdyeb,P', 0.5), ('Hrsegjxyj,Chqcitr', 1.0), ('Gcnfluwzm,Vnyxslvjo', 0.0), ('Tpwpho,Efgxgkvk', 0.0)]
# [('Czqlbmszr,Yh', 0.0), ('Putmwzabb,B', 0.0), ('Ukisdsxmvnwl,Fimp', 1.0), ('Eyjqfekd,Fefgb', 0.5)]
# [('Cjchhaqyfislp,Avrdll', 1.0), ('Uxnuhy,Mibprfdgs', 0.0), ('Erigto,I', 0.0), ('Jooelhryq,Sggobmqys', 1.0)]
# [('Waibncfrzsld,Pey', 0.5), ('Uozedaskd,Ecsik', 0.5), ('Hklpqfeaswydp,Xvzxvylje', 0.5), ('Lupulbzowvft,Kzwhryhr', 0.0)]
# [('Zwlpnawqibnh,Z', 0.5), ('Uqbgdcmrz,Nzvrnz', 0.5), ('Xebshbvxdv,Dnl', 0.5), ('Tsdhldabbgq,Qnqkuuon', 1.0)]
# [('Ztzhle,Qz', 0.0), ('Ltsbftbsqw,Nj', 0.0), ('Dudant,Iyly', 0.5), ('Mokwjlkdzrz,Xsdzut', 1.0)]
# [('Azfvihc,Kuf', 0.0), ('Xigrrwcycvo,Ohxisvt', 1.0), ('Zteqdyr,Acg', 0.0), ('Hbztnwtvu,Qpn', 1.0)]
# [('Akvucptnab,Tigwxq', 1.0), ('Rcbbidohia,Ilmsthgy', 0.5), ('Rvcfubfo,Ztzmbxr', 0.5), ('Wqdaonpruyf,Rd', 0.0)]
# [('Vfrnnk,Siehwpz', 0.5), ('Fnoykgxn,Ylmovrzh', 0.5), ('Vebynkelxjsq,Upv', 0.5), ('Ozzmlydcv,Gbnmov', 0.5)]
# [('Fjmofggt,Edl', 0.5), ('Jjwhjgjic,Gwrabe', 0.5), ('Fgzjtwfzj,W', 0.0), ('Wsdsemzdcsjrf,I', 1.0)]
# [('Cyyucsmwdljj,Gslsel', 0.5), ('Lppqrz,Dbkimo', 0.5), ('Cftdzjadmvsd,Zkzsy', 1.0), ('Ejgyhhio,Mvndcdcrk', 1.0)]
# [('Lrbpdndzvb,Sh', 0.5), ('Jstckijz,Lseql', 0.0), ('Ltibysxleeewh,Yerkf', 0.0), ('Ohmkrwt,Doymskxm', 1.0)]
# [('Rpjyjenjpi,Iq', 1.0), ('Kkpjwold,Rgvt', 0.0), ('Obsukiyt,Fdygrzmt', 0.0), ('Nionivwhc,A', 0.5)]
# [('Wxzkxbky,Weptlmw', 1.0), ('Dodsdfa,Ttrgeg', 1.0), ('Rldblnfty,Zsntizon', 0.0), ('Dwmzrlcdovhso,Beiza', 1.0)]
# [('Mdbhbasj,Fjzmhcu', 0.0), ('Wbimhpxtlkgtj,Urtr', 0.0), ('Dixrnilebpdch,Gyr', 0.5), ('Hkldatbcxkjo,Tnuki', 0.5)]
# [('Spsvgue,Clkdzdg', 0.0), ('Gayzexr,Mm', 0.5), ('Gijrgrgp,Rsdlme', 0.0), ('Gvyyga,Mt', 0.5)]
# [('Ifznmc,Ooqnhfty', 0.0), ('Uijzetrifbms,Pkfx', 0.0), ('Ezigmaek,Xb', 1.0), ('Socvmltkrwpyk,E', 0.5)]
# [('Szyfmfcxintob,Qzsyved', 0.0), ('Zswoibqstnsja,Sl', 0.5), ('Htsxfiwkvwhzd,Q', 0.0), ('Maqzauyx,Hpbgda', 0.5)]
# [('Betbwzwpxmvw,Vwahadnos', 1.0), ('Fnhhnwdbgtrj,Vqms', 0.5), ('Pekivug,Ozlk', 0.0), ('Onaazxf,Sruiv', 0.5)]
# [('Anfjjpxljn,Ti', 0.0), ('Qtlugq,Bvhsi', 0.0), ('Jdbhav,Yumc', 0.5), ('Tjqkfqxnccxl,Ti', 0.5)]
# [('Uqzlrrd,Cbbjeuqt', 1.0), ('Ybjllnzyyo,Jjpmnhjxi', 0.5), ('Qkeiwsrnwnbs,Ihdee', 0.5), ('Wjgijfajvy,Lhwo', 1.0)]
# [('Yfymgsazkmt,Qwbv', 0.5), ('Fbklzchqonwm,Nnge', 1.0), ('Rwoqhjogqvdce,Gjtzh', 0.5), ('Sklsdavmj,Ydlkgewae', 1.0)]
# [('Xfshrq,Dsvh', 0.5), ('Oppztsibnw,Wdea', 1.0), ('Esxcpmoqa,X', 0.5), ('Afrnzxiqpfz,T', 0.5)]
# [('Erkrfspan,Vfuujhnfn', 0.0), ('Gfougzfac,Pkpochiwg', 0.5), ('Icsusmr,N', 0.5), ('Kztyfstfglew,Tvfmesz', 1.0)]
# [('Plkyfzxoogfz,Nk', 0.0), ('Kivciebhzhx,Jqjv', 0.0), ('Drtoki,Etg', 0.5), ('Zlfczqtgd,Mxjpzvb', 1.0)]
# [('Yooxip,Lg', 0.0), ('Vekmomnswx,Gwln', 1.0), ('Xuprbgkcfae,Dfoocm', 1.0), ('Mevtaelaye,Lmgf', 1.0)]
# [('Ploatnc,Vyt', 1.0), ('Nunrgdycslzb,Tvttqu', 1.0), ('Gneceegzpdns,Ely', 0.5), ('Kkloqrnyli,Nghfnxr', 0.5)]
# [('Kvmhaoqcgv,Rehob', 1.0), ('Vdxxuhwkj,N', 1.0), ('Vgmkhey,Apsbw', 0.0), ('Odbfrqsblq,Xzuujvcg', 0.5)]
# [('Dpyvutebeto,Bhglno', 0.5), ('Xljaxfikj,Iktf', 0.5), ('Kxlixjfjni,Wuyayabv', 1.0), ('Ahoegrkr,Sgzrktr', 1.0)]
# [('Dxdgsysfdendw,Wdg', 1.0), ('Jcaobq,Ydt', 1.0), ('Hjtjwwchd,Ebe', 1.0), ('Dapxtsqmxtpzs,Ouawl', 1.0)]
# [('Njcbjbkxwr,Rspjyc', 0.0), ('Pbvhpccwhiu,Yu', 1.0), ('Twabdjznwk,Fw', 0.5), ('Oyrilshllmeb,Nypulwmon', 1.0)]
# [('Ozgbqh,H', 1.0), ('Numzaui,Piyh', 0.5), ('Caalwtdqpvmog,Stt', 0.5), ('Uyynlmbhbp,F', 0.0)]
# [('Bdwngfp,Mtlcev', 0.5), ('Mzojoll,Yarypwcah', 0.0), ('Ltiequbicr,Aydmllvfv', 1.0), ('Icwcqrqrtn,Ejk', 0.5)]
# [('Tlkyygqvbmmcz,Mgbvhabmo', 1.0), ('Gnmhmowpncm,Advbkrepk', 0.5), ('Zyblbthkjuk,Riwkn', 0.0), ('Gxhlplkx,Zmqf', 0.5)]
# [('Kprder,Pp', 0.5), ('Fqlbpdqzctqx,Tojdome', 1.0), ('Dnmmbyjbe,Incwcyutp', 0.5), ('Xlxmsorfique,Znjdfm', 0.0)]
# [('Ncntivwsu,Lnv', 0.5), ('Fbwxffnx,Iimymsnc', 1.0), ('Fbhljo,Rhl', 0.5), ('Ucfkiju,I', 1.0)]
# [('Vwlhotdcgfw,Upajq', 0.5), ('Bpqjsabllrnu,N', 0.0), ('Cqovrjv,Mfml', 0.5), ('Joqclekje,Ory', 0.5)]
# [('Oudtez,Gcfy', 0.5), ('Lctzgjjguig,Akq', 0.0), ('Pqxnswg,Tmc', 0.5), ('Zodoajifd,O', 0.0)]
# [('Lcmblauihv,Mgnhwhmip', 1.0), ('Goexyiehmlwv,Cqygh', 0.0), ('Twzdgyjk,Rtagdcl', 0.0), ('Hqmlbsfkxzbt,I', 0.5)]
# [('Mcasxkbrg,Ssibkpd', 0.5), ('Fqltsshvcfoq,Rx', 0.5), ('Vqvgxkhrfssz,D', 0.0), ('Nkuxphphuc,Iydmdvl', 0.5)]
# [('Ntqozqwexgxqo,Nwxp', 1.0), ('Asllxcsoeuzjx,Jqhwjg', 1.0), ('Mqscmaxsctjxk,Mcnjs', 0.5), ('Iltdpjzbbz,Ctxws', 0.5)]
# [('Bgjpudzfzccqb,Iq', 1.0), ('Iihievjhsdvdq,Gqr', 1.0), ('Nbqpjxdqxdjyy,Ydbpumkta', 0.5), ('Rtkfsmvrrighr,K', 1.0)]
# [('Krhfhvpk,Ouohiolk', 0.5), ('Ngnodzfatjnlb,Ezg', 1.0), ('Qppafmhbidsd,Bzcbsil', 1.0), ('Lkonaw,Ejroh', 1.0)]
# [('Cifgzcsdfdicj,Vqjngwgl', 1.0), ('Dlkhajvdhbzb,Ibc', 0.5), ('Ldfqplaixwqu,Yv', 1.0), ('Uwpbddjprx,Rbrlw', 0.0)]
# [('Mvwrxtzz,Xudton', 1.0), ('Bexnghgwy,Kjfuzolk', 1.0), ('Gchluz,F', 0.5), ('Ybspcrjntzcv,Ggxaizxf', 0.0)]
# [('Bmrfaobks,Mmfw', 1.0), ('Udhkgephe,Aweypsz', 0.0), ('Thcitpx,Ajjxwnc', 0.0), ('Ynisopsppreid,U', 1.0)]
# [('Fssstit,Zldvqdd', 0.0), ('Aiboosk,Pn', 1.0), ('Ohbqdkyqv,R', 0.5), ('Mmzzxciv,Rrrwgopt', 1.0)]
# [('Newqurve,Wh', 1.0), ('Ikuuoeafpf,Xyp', 1.0), ('Ruljiadpxegd,Sidphquj', 0.0), ('Xgizufdujfvva,Zq', 0.0)]
# [('Wuwmxbqkiodfx,Xo', 0.0), ('Tmpjndnn,An', 0.0), ('Yuqqhe,Djeh', 1.0), ('Ijncipupudxal,Oz', 1.0)]
# [('Hmlzrcihkyl,Xugw', 1.0), ('Txxvraxqtdctj,Buqtlns', 1.0), ('Adaqwghsuq,Wfdxf', 0.0), ('Dubjqo,Rpbyet', 0.0)]
# [('Uromtn,Kim', 0.5), ('Snvkbmzt,Z', 0.5), ('Tqbbpg,So', 1.0), ('Erevhu,Yhevsddg', 1.0)]
# [('Lxhihcsrr,Pzbcusir', 1.0), ('Mhkjfprx,Atmd', 0.0), ('Uyheeajv,Yyiwdq', 0.0), ('Tiuyoqasbwy,Dswonkuf', 0.0)]
# [('Ubmhnightw,Zn', 1.0), ('Xaxynmntfkhb,Kbaqiqpvj', 0.0), ('Dxzwbpgxdi,S', 1.0), ('Ornajxxtcyl,H', 1.0)]
# [('Iiefoq,Lmxl', 0.5), ('Gdjkbtui,Ychqphsc', 1.0), ('Rohynje,J', 0.0), ('Mmxdaxfsbbi,Owlhyrwr', 0.5)]
# [('Hhscjw,Q', 1.0), ('Hxqcye,Rhexexr', 0.5), ('Yyippifsz,Sxqoylxd', 0.0), ('Vvtybv,Lhh', 0.5)]
# [('Nttihefwjgkay,Gzob', 1.0), ('Tegbfsw,Swnrqikbi', 0.0), ('Qipxejmiqdyi,Xi', 1.0), ('Fbcakyh,Pwurg', 1.0)]
# [('Xzbvpn,Tyx', 1.0), ('Fykwazfr,Khykcoaxi', 1.0), ('Vtwdeqky,Wnmorhvcz', 1.0), ('Ocjrhtbeljdc,Myk', 0.5)]
# [('Oqwoheaeqol,Jdtiupmra', 0.0), ('Pvouiutq,Fpd', 0.5), ('Vvfuwbcn,Dbj', 0.5), ('Ucsrbuoz,Sgsyhuxvf', 1.0)]
# [('Savkwkzhiryl,Nxc', 1.0), ('Vcffoej,L', 0.0), ('Ecsszkkwmgdj,Gky', 0.0), ('Khbqmachxmme,Ngbfbryy', 1.0)]
# [('Tlwosc,Utzacvysa', 0.5), ('Mtrlrgawvwpre,O', 0.5), ('Rcycebhsyzrw,Joimxbcq', 0.5), ('Eqgjkf,Xhh', 0.5)]
# [('Tdlxruuev,Dbabd', 0.0), ('Bhomfozn,Zsgxhh', 1.0), ('Lskvpfawcbc,Niwoj', 0.5), ('Zjqdrzbxbydh,Psujdxol', 1.0)]
# [('Jschgqcxejktw,Mrcyjeq', 0.0), ('Eyvqrzlradjy,Irs', 0.0), ('Tzxgzzwua,J', 0.0), ('Mkgnvwtegs,Pjdxm', 0.0)]
# [('Hipszdog,Eusxr', 0.0), ('Dadvtwfhb,Kqvmdtu', 1.0), ('Rdhwsrmgfn,Fqu', 0.0), ('Poxaxsfcb,M', 1.0)]
# [('Ycehkeptbbb,Hurnoqaat', 0.0), ('Fdtxdnf,R', 1.0), ('Apblgnkya,Aamaqsh', 1.0), ('Pmwnxyjlbsi,Qulhwqmvc', 0.5)]
# [('Flzbur,Balhr', 0.0), ('Vxrhzj,Fcjdczes', 0.5), ('Tylfleqwroegj,Fsly', 0.0), ('Dvyyqdokmey,Tzaofde', 0.5)]
# [('Wfbhueci,Hoqwdf', 1.0), ('Gbcveyadxgr,Ggn', 0.5), ('Wzapvphhrscx,Luorakhb', 1.0), ('Fuztphi,Rz', 0.0)]
# [('Xjotvmd,Uta', 1.0), ('Syicxv,Hhfao', 0.0), ('Kgtgsukbyay,Yovmygxgn', 0.5), ('Laifvnx,Jxb', 0.5)]
# [('Hfvtgekdswvwb,Iesrkfu', 1.0), ('Qviggnijtk,Fsasyun', 1.0), ('Bqchyrtewf,E', 0.0), ('Hxtczsvpm,Bonnvqn', 0.0)]
# [('Ycvyiq,Fbqiup', 0.5), ('Gehxndpgbxota,Jf', 0.0), ('Yknfgv,Lhxpr', 0.5), ('Nleccxd,Ijmneak', 0.0)]
# [('Isjorcexdn,Ckfgt', 1.0), ('Rpgftq,Xknglx', 0.0), ('Pjidclgdocm,Rc', 1.0), ('Ieapcitvynzbd,S', 1.0)]
# [('Qbwfvrnkdoab,Udw', 0.5), ('Ptbppezm,Mxkgsteo', 1.0), ('Gtuxec,Sjkklikzz', 0.0), ('Weuukv,Vklui', 0.0)]
# [('Jlymtgjgn,Ibmzncwm', 0.5), ('Liytsnkvuto,Erebt', 1.0), ('Udgrjer,Fibrwxodc', 0.5), ('Jtnbzsyzya,Wq', 1.0)]
# [('Lyfacixcknzfv,Ovp', 0.5), ('Vgbdrcnvixumn,Cwtjhybeh', 0.0), ('Nfepyzxgbtz,Neak', 0.0), ('Tdvhaqry,Uq', 0.0)]
# [('Wncylgnko,Twu', 0.5), ('Mixqxpdmncyc,Dagc', 0.5), ('Vxyvfxjya,Qotnbmt', 1.0), ('Cpwytrqoj,M', 0.0)]
# [('Wntcpktqpjedz,T', 1.0), ('Xnauoor,Fbsolhnu', 0.5), ('Qjdreygf,Lqqmja', 1.0), ('Jxorbaueujn,Iekywdicy', 1.0)]
# [('Uvrmvkeq,Kdazvieq', 0.5), ('Ywryyqb,O', 0.0), ('Kviogcyyjhds,W', 0.5), ('Tpehrqtskwvkw,Mgivaf', 1.0)]
# [('Hadlwirx,Igsckhndz', 1.0), ('Ykeyon,Gjxoda', 0.5), ('Bsymnkq,Cryq', 0.5), ('Kpripz,Zggmusd', 0.0)]
# [('Psnevam,Ouqjp', 0.0), ('Lamkeympssxdf,Fcnjpot', 1.0), ('Smkygetjeyaa,Qci', 1.0), ('Qjbunqyhlgi,Qces', 0.0)]
# [('Bwnisrlytuxnl,Uxlryuc', 0.5), ('Ukmkwse,Mqbp', 0.5), ('Yycgosfu,Yf', 1.0), ('Oxqbwfzyimjgv,O', 1.0)]
# [('Tabijqs,Kdtiees', 0.0), ('Xqhowbgjn,Qxeicfke', 0.0), ('Spnjbzkpb,Mgnobpp', 1.0), ('Jlpmaavqtqc,Unwiaiw', 1.0)]
# [('Taxfaksxc,I', 1.0), ('Dfequgnwy,Snlxufwkk', 0.0), ('Nwrwshdpefdwc,Aauc', 1.0), ('Swxpffhufhtiw,Ferynch', 1.0)]
# [('Bklbhqvkj,Rzdt', 0.0), ('Qozerhchbu,Xtgtdewd', 0.5), ('Kzngofbnuhk,Ixqwnmhk', 0.0), ('Abxepn,Qetagc', 0.0)]
# [('Wqpihrfz,Owxad', 1.0), ('Meqzcu,Cwh', 1.0), ('Yjzfmyfojl,P', 0.0), ('Jtabhg,Nhhvsdjmg', 1.0)]
# [('Rytkhskdq,Diafhdqc', 0.5), ('Zqhnrm,Hocxpylwn', 0.5), ('Hosxqycmzzd,Pbocsfhym', 1.0), ('Uxyzupegvdfl,Orqjoqdi', 0.5)]
# [('Dclrlqzem,Gud', 0.5), ('Wqmygya,Orltazk', 0.5), ('Rddqqyuwmsq,Awmz', 1.0), ('Jrvfayoi,Oq', 1.0)]
# [('Guhblsbv,Jdnqp', 0.0), ('Srflizbt,G', 0.0), ('Iteorqeqdcbmn,Vp', 1.0), ('Vlkwwcwyxiv,Msalqn', 0.5)]
# [('Ouocwrnrs,Wpbqzbs', 0.5), ('Pogpqmrlgq,Stm', 1.0), ('Uyjewefc,Lybpyu', 0.0), ('Hhnjzumgswnp,Tytsxjib', 0.5)]
# [('Etvlsrj,Ovfy', 0.0), ('Kbjfqcbg,Wjimvczxc', 1.0), ('Dfymxse,Idahxyy', 1.0), ('Ojqkxcm,Lkdhf', 1.0)]
# [('Jqqwyicqfd,Axtocid', 1.0), ('Acyuindu,Llwub', 0.0), ('Yixmztb,Tp', 0.0), ('Kcfkbgxlyk,Xe', 0.5)]
# [('Nhvyelcowqwun,Smo', 0.0), ('Yfleqcyjgwqje,Pxkuc', 1.0), ('Fgiqkzuktwebx,E', 1.0), ('Yxyvhbhe,G', 1.0)]
# [('Wcuczj,Cabmgrept', 0.0), ('Zxdxtkcjatma,Bgjs', 1.0), ('Kjepyet,Jii', 1.0), ('Rlpwixyulzpg,Anvzja', 0.5)]
# [('Lihifxgxbyx,Mc', 0.0), ('Fmimfqeokv,Votz', 0.5), ('Kecrivp,Wjy', 0.5), ('Rtszbm,Yfbzxeg', 0.0)]
# [('Nvuaeufnlrloo,Qmj', 1.0), ('Cvkosfvnw,Skw', 0.5), ('Nkmxpknfwr,Anrx', 0.0), ('Dvraglm,Nrqxit', 1.0)]
# [('Greeyagad,Fbabca', 0.0), ('Kuuvhuvsmo,Lfvgieo', 0.0), ('Zvnrxcmegt,Bunsqhv', 1.0), ('Enoero,Sgcjosjg', 1.0)]
# [('Gpsmajapgyu,Ced', 1.0), ('Sftwqlhchdps,Vrresfmb', 0.5), ('Emwnbt,Eretsjfu', 0.0), ('Jmwbtjily,Co', 1.0)]
# [('Vrzgbex,Bh', 0.0), ('Svgkyajwxyga,Sbwwatfzc', 0.0), ('Ofpall,Kdlpqz', 1.0), ('Zyxcbdfemsshh,Omtzfmchy', 0.0)]
# [('Kyrjweotj,Bjq', 1.0), ('Nsfvmxpjoxlat,Oxpzweqrv', 1.0), ('Hakiqjj,Riw', 0.5), ('Pvmhnmxtfxwjp,Pzmpjs', 1.0)]
# [('Eyielqyamey,Zoretw', 0.5), ('Kicgdwkk,Xwt', 0.0), ('Dokftcicklebl,Wnl', 0.5), ('Simirsnxlt,Fsxnkv', 0.0)]
# [('Dqhwdt,Pebr', 0.5), ('Pgerrpedxitg,Fjzakzrbl', 0.5), ('Mqxmonkhg,Fyff', 0.5), ('Fgkuxdj,Aolgwtl', 0.0)]
# [('Ucscfpluipg,Is', 1.0), ('Arrukoqcyhgm,Pattixfgp', 1.0), ('Nmfrawzyux,Kykr', 0.5), ('Pqehhg,Awzbnl', 0.0)]
# [('Gyhnbtkpnh,Qtkccfx', 0.0), ('Rvffqdmart,Xspclusax', 0.0), ('Ksqbto,Fjzzjirk', 0.0), ('Ikvuwn,I', 0.0)]
# [('Jhgvqddyty,Bmfooebnj', 1.0), ('Judtfcgrczy,Sddlww', 0.0), ('Nynwyf,Zvvsji', 0.0), ('Vkmehnndvox,Alv', 1.0)]
# [('Uyeghgrq,Vwnpuw', 0.5), ('Czotjocbwgxtd,M', 0.0), ('Hpgqvzwpfe,Uzjd', 1.0), ('Hbjhqdv,L', 0.0)]
# [('Sroqiuzlhmciw,Qdqejt', 0.5), ('Rocgqxouxvasa,Tloojcaj', 0.0), ('Xabpjueihba,Sioo', 0.5), ('Mkkquof,Grtlfn', 0.5)]
# [('Llobyhvg,Brfrulqmy', 1.0), ('Vvmlzlnsfplv,Bgtkmewi', 0.5), ('Xsvqbbel,Zoftqg', 0.0), ('Cgkywrvyxcez,Cpzbmqq', 1.0)]
# [('Xstdclrkfo,Advoku', 1.0), ('Foqnynvkbjokk,Gmqripe', 1.0), ('Zodfhoujc,Sqxdqktll', 0.0), ('Wdhxtdf,Z', 1.0)]
# [('Wmbthyyvfz,B', 1.0), ('Ghootazfsk,Qqjookcmk', 0.5), ('Bhvrqitjz,Rovmj', 1.0), ('Ntmrsaongr,Akcsknvv', 1.0)]
# [('Ykqjbslwx,Sqqhe', 0.0), ('Mlboqisodmmvm,Vz', 0.5), ('Jvqxyylwewb,Qgjkejffd', 0.0), ('Fsrdxuty,V', 1.0)]
# [('Wfjryrtk,Ubtimhzze', 0.5), ('Ymhfvxzy,Rn', 0.5), ('Lcmcfse,Ebrytr', 0.5), ('Ezuxoqpoq,Ysghakg', 1.0)]
# [('Ietljujwhjl,Hgxel', 1.0), ('Yqslaj,Efv', 0.5), ('Serqhbncff,Cjjyheqik', 0.5), ('Nmluakt,Sxin', 1.0)]
# [('Mrhispdevu,Xtht', 1.0), ('Kjbtrxdu,Qvoapmnq', 1.0), ('Wwyujygblpc,Bqjhxv', 1.0), ('Oysxqnk,H', 0.5)]
# [('Pjqswqybmid,Njwo', 0.0), ('Zjhmlwxwz,Bxo', 0.5), ('Ovvrvlun,Xvq', 0.0), ('Dqzuaylh,Mjp', 1.0)]
# [('Cdlpnu,Wg', 0.5), ('Fjiuquls,Dnk', 1.0), ('Fjgbhvm,Vyocobl', 0.5), ('Fzzqqv,Ea', 0.5)]
# [('Srjvojpsqdxim,Onwvoppl', 1.0), ('Wkvahpzrlsq,Ptfyhv', 0.5), ('Eloxuaomh,Nuzlg', 0.0), ('Nbomfi,I', 0.5)]
# [('Hkewehuhuymxm,Lrdk', 0.0), ('Exwsdy,Oldx', 1.0), ('Rvievcednnhuz,Xt', 1.0), ('Kyzzvphqcfnea,Rs', 0.5)]
# [('Meqeybyt,Emz', 1.0), ('Cguptnoksyw,T', 0.5), ('Axhkhboksli,Uzsvlt', 1.0), ('Qywdeplnr,Qtz', 0.5)]
# [('Efxzaw,Iibklvcv', 0.5), ('Uqdtsc,Vbi', 1.0), ('Twomdrhkjhyvf,Kiwr', 0.0), ('Xumxpxqelllo,Ttsxhoo', 1.0)]
# [('Gebeamrspu,Kath', 0.0), ('Jelliftmyih,F', 1.0), ('Sxaehki,Juyqsmlsm', 1.0), ('Mcynnvnmvsnuz,Scxznq', 1.0)]
# [('Mpqpchthqtf,No', 0.0), ('Femogvze,Nldbjzo', 0.0), ('Autfkc,Poxu', 0.0), ('Edeqftoqxuvnq,O', 0.0)]
# [('Caiyumfk,Epthj', 1.0), ('Cewrpcuxs,Mzbvsxb', 1.0), ('Ycfplwgasw,Ao', 1.0), ('Ecdxndhydhxes,Vvkuuqlj', 0.0)]
# [('Fonmobjmpf,Lhiztcmov', 1.0), ('Mtsfouvuzyzup,Weossqjj', 1.0), ('Pnbnrmrjpisdr,Dqwas', 0.5), ('Zdqcehqpbjf,Rwejjx', 0.0)]
# [('Wcespzrkdnh,Zrjnbf', 0.5), ('Xmkozydidep,Xy', 1.0), ('Lkmvzqjqmjuj,Zb', 0.0), ('Rtcotvrzf,Drrhul', 0.0)]
# [('Uwuaxujzetue,Lntyz', 1.0), ('Ketmedwlj,Pbfnvju', 0.0), ('Wkwfjzx,Uqm', 0.0), ('Puyqik,Ktt', 1.0)]
# [('Yrazqmbgpz,Rnetfhogr', 0.0), ('Rvvbazo,C', 0.5), ('Zzdldfdzurcsc,Nolkchitb', 0.0), ('Gxwnvrd,Hrxx', 0.5)]
# [('Krpejslznif,Kc', 0.0), ('Tzocbrbwhzuw,Bgzvmew', 1.0), ('Tmoljzutbaz,Oet', 0.0), ('Ypnjvacftyygu,B', 0.5)]
# [('Kfmhun,Kyuo', 0.5), ('Wmpkbunzm,Niiwww', 0.0), ('Wsnzgfom,Vtrxs', 1.0), ('Dvrsejfw,V', 0.0)]
# [('Hnmcnkwkgw,Lglbacsbd', 0.5), ('Bpoeuolrwtq,Flrtn', 0.0), ('Wxfjmgyshucct,Vohcae', 0.0), ('Kdupyyyzsigpz,Ypovy', 0.0)]
# [('Ixywxhdjb,Zx', 0.5), ('Ynwqzvnw,S', 0.5), ('Xorlklbcnkmjd,Fxmdsfbz', 0.5), ('Vwzacx,Pwmuh', 0.5)]
# [('Axvyhydygy,Qkzdxqgx', 0.5), ('Tqeeetlawduls,Tmdx', 0.0), ('Hzaitnyhqkp,Kg', 0.5), ('Pgggptngl,Kospdr', 0.5)]
# [('Iubuekqfdejnp,Yeam', 0.0), ('Barrouogbti,Aiueqrv', 0.5), ('Ezvmityif,Ockqx', 0.5), ('Crkegezbrg,Zmvuqe', 0.5)]
# [('Vzhtkmn,Q', 0.5), ('Fqxwxlsmhmyd,Uetvn', 1.0), ('Vtrcgnajd,Jevuhg', 1.0), ('Blcborcaxmxs,Dimzz', 1.0)]
# [('Svzuahdgpcnof,Yllkfb', 1.0), ('Haheterhyx,Hjsym', 0.0), ('Cofemlbnl,Pu', 0.5), ('Okzrosvtj,Xa', 0.5)]
# [('Pkxfvb,Tpepncci', 0.5), ('Yblhifu,Zvfzv', 1.0), ('Zfiqgxcui,Fodj', 1.0), ('Itzhwbknwe,Rf', 1.0)]
# [('Ovqrxxqxuuvos,Khbc', 0.0), ('Jwubdzqxhnwy,Vcs', 0.5), ('Eqeiwoha,Egwo', 1.0), ('Iqavmnefoe,Ygdugrvk', 0.0)]
# [('Wfkkeq,Hyi', 0.0), ('Jnwkvggbue,Tn', 1.0), ('Twtsrpwh,Fypjd', 0.0), ('Rjpsfuz,Aa', 0.5)]
# [('Odqoyiynm,Zoc', 0.0), ('Lumxekjhhzp,Eroph', 0.5), ('Fjzgwuoeyb,Xnkhacl', 0.0), ('Ccqmwszf,Aezaffj', 0.5)]
# [('Ermfaigzdmv,Ppy', 1.0), ('Wrimuphhpv,Qgkmsqua', 1.0), ('Ljvxuhffukg,Kvwudqi', 0.0), ('Kbbzlmgwm,Bwuu', 1.0)]
# [('Xibjpxnxu,Ddlqzw', 0.0), ('Irosajz,Vtpkq', 1.0), ('Flcursfvnf,Cs', 0.0), ('Gsqicjyqdkigi,Ravsbn', 0.0)]
# [('Hwvvekevulpmm,Vhi', 0.0), ('Zghstaahyuxj,Cx', 1.0), ('Hlirzil,Kdoltx', 0.0), ('Ljovit,Phfue', 0.0)]
# [('Zbvixypxo,Exyxesws', 0.0), ('Eadcbwjobwkx,Thi', 1.0), ('Ysggdlfoaklm,Nalxbjfpo', 1.0), ('Eqtghwqhogj,Kxd', 0.0)]
# [('Ykwrzehgc,Amnjhunh', 0.0), ('Ergcjwnykxabj,N', 1.0), ('Qdnfwnitdvw,Yolxctt', 0.0), ('Necqnpwtksfw,Ojuw', 0.5)]
# [('Zsqqgsdnpdj,Smxc', 0.0), ('Ubbqjcok,Rba', 0.0), ('Scymbc,Urdn', 1.0), ('Onbhngt,Cmjjit', 0.5)]
# [('Wfnmaadnwot,F', 0.5), ('Azvrfxl,Cqzpxidqq', 0.5), ('Xvtfntuunp,Nuzzjsao', 0.5), ('Ynzmdkze,R', 0.5)]
# [('Cstfmgycwphsz,Ydgxvfdyw', 0.0), ('Juduksga,Wfuirorqc', 0.0), ('Npmqtryvamjan,Epualgv', 0.0), ('Mnjeokkcx,Sgtx', 0.0)]
# [('Upguwkryuvixe,Kyxzzie', 0.5), ('Pjngjx,O', 0.0), ('Lwxpbbfnjw,Xsghvtbus', 0.0), ('Camsgz,Cx', 1.0)]
# [('Tkdhxentgfd,Octrgznlt', 0.0), ('Dznmqekxpjti,Uugg', 0.5), ('Xyifzzxps,E', 0.0), ('Tjwmiokjvrqo,Sumhga', 1.0)]
# [('Almxcz,Vasuusauz', 0.5), ('Bridiqlfokymi,Ljrl', 0.5), ('Doxyur,Wqrrmqkyz', 0.0), ('Hhwiaxt,Pnzaoca', 1.0)]
# [('Nfzbhytai,Ygtsa', 0.5), ('Qrbaakudjxtpz,Nikqdgy', 0.0), ('Nzpulusgm,Fhk', 0.5), ('Hsblstf,Luaj', 0.0)]
# [('Ymglmqpe,Cmlonoh', 0.0), ('Msyjaewz,Hyiqcbm', 1.0), ('Xuvbedabmshly,Ga', 0.5), ('Vlomuhntgsgt,Sx', 0.5)]
# [('Rcifqehvijpqf,Qqzba', 1.0), ('Ryuehuybendp,Qeev', 0.5), ('Tsbgkk,Kry', 0.0), ('Rtyjeb,Bmznwz', 0.5)]
# [('Jaufiazun,Uppwhp', 0.0), ('Arfyilwbz,Ejoin', 0.0), ('Oqnvqtvzt,Rolo', 0.0), ('Deufhshmz,E', 1.0)]
# [('Capscs,Mx', 0.0), ('Lvzqhzhkhybcl,Plqyqzto', 0.5), ('Goikmjij,Qoowo', 0.0), ('Jzmejiq,Genpf', 0.0)]
# [('Tnkwvasjo,Uew', 1.0), ('Xtgamwdjie,Noxc', 0.0), ('Ajhcrhlb,Whrvpuq', 0.5), ('Vxoqtxxjfllx,Wakrzcy', 0.0)]
# [('Fpgxhdo,Qsswti', 0.5), ('Foxrwgmvcne,Syc', 0.5), ('Mtoriukkldpey,Rsgislfrq', 0.0), ('Trjjtda,Jscozs', 0.0)]
# [('Rovcfhzbq,Isvwp', 0.5), ('Uekmzwsxo,Gvo', 1.0), ('Yynxzuy,K', 1.0), ('Yzvdqdffxnin,Xkwuy', 0.0)]
# [('Bdyyjjgreniia,Mqkptsi', 0.5), ('Xabwztcy,Azw', 0.0), ('Vrdzudnnbjse,R', 1.0), ('Evgknsed,Rmnydw', 1.0)]
# [('Bvqzuaj,Izhld', 0.0), ('Bgignwa,Na', 0.0), ('Iisvtofrjdl,Wkimhi', 1.0), ('Tbuvpwkaw,Mfxpvr', 0.0)]
# [('Kheplnkgobcaj,Kif', 0.5), ('Oezujlfno,Odfw', 0.0), ('Nqaoktura,Ryhb', 0.5), ('Tcipmvmnz,Xsyieop', 1.0)]
# [('Ecgsqohq,Kjid', 1.0), ('Janaki,Ltvdsrto', 1.0), ('Raeosmm,Igawvr', 0.5), ('Ztfbbe,Tyhfjxnf', 0.5)]
# [('Xpmmxcpbcfw,Fsgke', 0.5), ('Ojspbfmp,Nr', 0.5), ('Uziagileed,Nmlcqjql', 0.0), ('Yzgvmp,Teo', 0.0)]
# [('Ebetxoxdn,Cum', 0.0), ('Gcvedygffakg,Jhmn', 1.0), ('Ehlvbkv,Azfyeisz', 0.5), ('Xhgjsraefifss,Vjs', 0.5)]
# [('Jvndqtcna,Iiifvnz', 0.0), ('Nmknhubveed,Ahug', 0.5), ('Kojilpimnmkn,Nvg', 0.0), ('Poucqmnukbumw,Qrjg', 0.5)]
# [('Cqbuzxwtz,Z', 0.0), ('Wipxyslpeu,B', 0.5), ('Bntgmyt,Mqibbbyot', 0.5), ('Cwezkqgijz,Vjsyg', 1.0)]
# [('Thdghckqp,Yv', 1.0), ('Dhsazmzblg,Dgzmvjp', 0.0), ('Mxfxkqwghodsd,Vnroh', 1.0), ('Eiihvabysyodg,S', 0.5)]
# [('Uvymffb,Awkp', 0.5), ('Dspdmbcwnvjr,Vgasua', 1.0), ('Iohuxozfsahm,Usjv', 0.0), ('Gwedbftqayzsl,Fofbrzgdv', 0.0)]
# [('Ptqoohyq,Bvtnbhwk', 0.5), ('Rptibzzeu,Jviyn', 0.5), ('Pmruho,Kopbbnfpi', 1.0), ('Gamcczkag,Fdk', 0.5)]
# [('Kfqzifgjkqsd,Rqnu', 1.0), ('Iahzgsoeqtbuz,Feyww', 1.0), ('Iqgkhpzppk,Mobig', 0.0), ('Mezfogvyyedm,Lofwgiyvg', 0.5)]
# [('Rnsudhkhp,L', 0.0), ('Hdokajtfjhptq,Wpso', 1.0), ('Ylffecvlk,Df', 0.0), ('Lzmjaeqgk,Pg', 0.0)]
# [('Udkaoq,Iuglrxo', 1.0), ('Xcggswneynkn,Rrjc', 0.5), ('Hqpgegxmfos,Pavpise', 0.0), ('Csipmfisarrny,Pzyxcloy', 1.0)]
# [('Pyevmtr,Dan', 0.5), ('Egoxaeohj,Txrvc', 1.0), ('Jziwsirttw,Zb', 0.0), ('Eqblaupp,Znqb', 0.5)]
# [('Nilbeow,Nipxzjgl', 0.0), ('Gxdmubgyg,Fx', 0.0), ('Hfaygtxhh,Okv', 1.0), ('Fqxecyp,Ig', 0.0)]
# [('Gzisnssfr,Sysogjjr', 0.5), ('Lhgyged,Y', 1.0), ('Betqzoylwy,Fjow', 0.0), ('Cckswn,Eh', 0.0)]
# [('Lxonytlk,Lvuarfsa', 1.0), ('Nxplmvmbogtfb,Ocznoqy', 1.0), ('Mhzucjytxccev,W', 0.0), ('Yhxunfh,Pthg', 0.5)]
# [('Aqbgohzf,Ujcngwc', 1.0), ('Cwlnqryafqif,Jndwbo', 1.0), ('Ukhejtgc,Faeutx', 1.0), ('Xiwpixdvqxbav,Esey', 0.0)]
# [('Dsbpgwpw,Dm', 1.0), ('Yjoubaxurnw,Kun', 0.5), ('Ncjpzs,Kkejwwjre', 0.0), ('Fknnyxlyot,On', 1.0)]
# [('Svpgkkmw,Fiowhz', 0.5), ('Lbcnaysvhqkoa,Art', 0.0), ('Ojdlblusxwupa,Gkiqj', 1.0), ('Vvbkvwulu,I', 0.0)]
# [('Mifgitk,Mgqdhm', 0.5), ('Xutbbxfxphjpj,Pef', 0.0), ('Hptzcgdtmopw,Glfdp', 1.0), ('Cwidrjmgwnspf,Fcexj', 0.0)]
# [('Epvgeskdayglu,Otwsvmo', 1.0), ('Bguggouznlvqn,Ca', 0.0), ('Jinqtvslbvuld,Kctqsqjq', 1.0), ('Lgfpfop,Tiwyl', 0.5)]
# [('Syquusnvxycnn,Otova', 0.0), ('Dyouditv,Yolaplipb', 0.5), ('Zcjohvkwsefh,Rkolyhyyz', 1.0), ('Ltfobhlyof,Znsajcare', 0.5)]
# [('Fhlzvz,Zick', 1.0), ('Soconnoxurg,Zaddpkrov', 0.0), ('Lhmgfm,Otbcar', 1.0), ('Icnwxgnxdi,Aqizlqlmr', 0.0)]
# [('Pimovr,Bjdnk', 1.0), ('Cnfkqjfk,Yzbfjx', 0.5), ('Mnmceqwqaf,Hxblohw', 1.0), ('Tnxqufg,Jjegyf', 0.0)]
# [('Jctrdacqvr,Dnunr', 1.0), ('Lieedkkkhkh,Hvwgnb', 0.5), ('Odhxfz,M', 1.0), ('Orlzjevubyep,Dq', 0.5)]
# [('Zudnwzty,Sritkxzv', 0.0), ('Ilotatq,Zlwwrpo', 0.0), ('Zsdxjmg,Ma', 0.5), ('Oadpvxp,Oqwk', 0.5)]
# [('Rdwtynkwdcvvm,A', 0.0), ('Yxwocux,Osbgwwlt', 1.0), ('Gwrcctipjgfe,Mdx', 0.5), ('Mdqtsswz,Voowpurvt', 1.0)]
# [('Ihhfugmyykm,Skj', 0.5), ('Vprexbkcksye,D', 0.5), ('Zcnzmkh,Y', 0.5), ('Jsttvq,Dral', 0.0)]
# [('Zylujbjsmre,Nzcr', 0.0), ('Hcfgrndjc,N', 0.5), ('Jqxzku,Hyggagqij', 0.5), ('Lpswcnrmuk,Z', 0.0)]
# [('Qiannvlzpdrko,Idgm', 0.5), ('Hgmrarinmx,Cn', 0.5), ('Gzphonearmuy,Riudeqw', 1.0), ('Djoeirbz,Edunvsehw', 1.0)]
# [('Mugfbnqy,Mlcwvfz', 0.0), ('Axqyhlpmmmdwj,Imflvqy', 1.0), ('Ffhgqeojjplqr,Mwotggxvr', 0.0), ('Esbdjnigapl,Voqcmya', 1.0)]
# [('Khlmtpjjboji,Kxxnede', 0.0), ('Caeusyprzuzws,Evdkvxb', 0.0), ('Ruhkomcss,Lqgdwn', 1.0), ('Xwcpgoporpncz,X', 0.0)]
# [('Stryvdytso,Oyiioylmp', 1.0), ('Tlactddlkk,Csb', 0.5), ('Fdiuhtgmbxf,Wvsf', 1.0), ('Yjqtgrlcyrp,See', 0.5)]
# [('Duoccgvcobve,I', 1.0), ('Vfbrwh,Zheh', 0.0), ('Hjagkxoe,Xsh', 1.0), ('Jknvtxq,C', 0.0)]
# [('Abqycws,Gkjrq', 0.0), ('Uptzeftf,Lfdu', 1.0), ('Lrsccuasxlbf,Kn', 1.0), ('Aypzybh,Tkavw', 1.0)]
# [('Lrugsrxhmxu,Fidiixjtn', 0.0), ('Crlaoel,Fgqr', 0.5), ('Zpqlqpof,Mkckno', 0.0), ('Gchhsof,Rouvnz', 0.0)]
# [('Dcyorrefdcd,H', 1.0), ('Pxtjifeqspfaf,Pwzs', 0.0), ('Svjnrnvkqyf,Osckmpcy', 0.0), ('Utmbzjmy,Iejqvfrsc', 1.0)]
# [('Msomtlgzgsq,Wpv', 1.0), ('Ybwpxoadet,Knyvsjpvn', 0.0), ('Cypxigpqmprf,Pc', 0.0), ('Osgzqypdjru,Cxxah', 0.0)]
# [('Elmnyvffajnhh,Eqtkusmuv', 0.5), ('Zvrgqj,Joncprznt', 0.5), ('Dqtxblqtqz,W', 0.5), ('Iopahafmwxi,Mw', 1.0)]
# [('Wlpnrxz,Wjcgtmslb', 1.0), ('Wjiuyhbzyg,Mlxqnebpy', 0.5), ('Iyjmkqgh,Xfvs', 1.0), ('Qjzfqgb,Bhkrecmcn', 0.5)]
# [('Nkzhbce,Kvxxsikda', 1.0), ('Xqrihd,Pzoncqfvd', 1.0), ('Idzopzlmyxf,P', 0.0), ('Yaavayyjtidk,N', 1.0)]
# [('Sxvlcr,Dweg', 0.0), ('Pnnuigb,Mihcog', 0.5), ('Makotpinfzm,Xktorv', 0.0), ('Zalubuyv,Ukyvjyj', 1.0)]
# [('Fjzyosqq,Bys', 1.0), ('Twvkvjhgbi,Nbv', 0.0), ('Hrxirafudxval,Hpwrfnxmf', 0.5), ('Uyyyep,Sh', 0.0)]
# [('Dshagycka,Sfgg', 0.5), ('Lmrsczbse,Vcxadn', 0.5), ('Hmxpcjivgr,Qdgis', 0.0), ('Lqixwqnvppc,Eyro', 1.0)]
# [('Lwvxxn,Jymnlzcg', 0.5), ('Gowdws,Qcc', 0.5), ('Vofpqc,Rzqcwti', 0.5), ('Aeanykln,Qfpliwgsa', 0.0)]
# [('Amjrzasdamjb,Jit', 0.0), ('Oztvuu,Zmkbguog', 1.0), ('Cpsplwtlalhvr,J', 0.5), ('Izubptatks,A', 0.5)]
# [('Ykupdo,Ouxofjt', 1.0), ('Mynvxsg,N', 0.0), ('Iojntor,Jktjpz', 0.0), ('Qphpkdfqq,Oozof', 0.0)]
# [('Xwjhiqoetoy,Vxfza', 0.5), ('Kbqrflxr,Dm', 1.0), ('Mqnyeukzra,P', 0.0), ('Ujdxrgurji,Ledao', 1.0)]
# [('Lzamnpudjbx,Btzdqldao', 0.5), ('Qximnxxnfhaq,Qwwkfeg', 1.0), ('Iocjramxabk,Tayycqcik', 1.0), ('Zdnymnvc,Ap', 1.0)]
# [('Ycgvuwipomjq,Bg', 0.5), ('Dnqyvtvocig,Gqtriqax', 0.5), ('Onrknef,Nthyhl', 1.0), ('Xiglvl,Wmp', 1.0)]
# [('Vpiboni,Sznzcefyb', 0.5), ('Rnfvrb,Xcs', 0.5), ('Gsoibecejwe,Wrzifpczf', 0.5), ('Pldjlq,Crpjht', 0.0)]
# [('Wkduucdrpz,Ew', 0.5), ('Guxjhtutt,Hnymjdfph', 0.0), ('Yyptfbgrps,Vgvy', 0.0), ('Phcieiids,Euzy', 1.0)]
# [('Ffmxmuxhhybdj,Gioa', 0.5), ('Isvgno,Fng', 0.0), ('Juhlkqxkicxxo,Tlodhdyol', 0.5), ('Iijqoywuly,Zua', 0.5)]
# [('Rmkgxzm,Tdpq', 0.0), ('Qqxopywkehty,Xykbfixb', 1.0), ('Fwgorwxebs,Erwnz', 0.0), ('Dfmfcfyvv,Jhuxrzmh', 1.0)]
# [('Lnkfsswdlndit,Gwuijearu', 0.0), ('Xaqrvggdi,Ttb', 0.5), ('Nrsnmatbvw,Hbkhjjvwh', 0.0), ('Uposiupzcl,Bd', 0.0)]
# [('Oymkosj,Tcuhlqdyo', 0.0), ('Clzebimujo,Levdqki', 0.5), ('Cywbzckzah,Asmgke', 0.0), ('Umfvommjythm,Wslriie', 0.0)]
# [('Uzvcmf,Hvxvw', 1.0), ('Enypxip,Ngwcuvzkn', 1.0), ('Nyjslstuc,Tkspam', 0.0), ('Xbmtzs,Moshjdlr', 0.5)]
# [('Gbueewghgbml,Jvgvycxdw', 1.0), ('Dhpzqufmnnv,Sedqd', 1.0), ('Ekgdqbmisjm,E', 1.0), ('Jpdfcxz,To', 0.5)]
# [('Xjzwyslxx,Ywsy', 0.5), ('Eiwwnln,Grjfw', 1.0), ('Zzxrdboduct,Yeqxnuo', 0.0), ('Runqiqbarqn,Oatfhstil', 1.0)]
# [('Rmevcf,Raxjb', 0.0), ('Zqtvamrbmse,Wzavol', 0.0), ('Ncyvgakovks,Xpajgjxm', 0.5), ('Kpqlzl,Jf', 0.0)]
# [('Vokuyjqral,Ki', 0.0), ('Oexvecwc,Xgfyzdgtw', 0.5), ('Zpbdvgqman,D', 0.0), ('Feejgol,Rrevmpbn', 1.0)]
# [('Nekpxbyqposo,Zqxqxaudh', 0.0), ('Rnetpmzld,Yfubj', 0.5), ('Raeygg,Te', 0.5), ('Mkplyzgtpu,Zggjgotni', 0.5)]
# [('Vulnro,C', 0.0), ('Ccqbokpm,K', 1.0), ('Bbonxqkblt,H', 0.5), ('Dictuirfzcwjj,Nnmkjvbul', 0.5)]
# [('Wdworfpblwhh,Mvmu', 1.0), ('Zqvkumpzzo,Fg', 1.0), ('Engekdwzgqukm,Gp', 0.5), ('Zxccmurbc,Tchjqeptb', 0.5)]
# [('Olqtrt,Jshfgppc', 0.0), ('Cgbsdzprtmaku,Seniu', 1.0), ('Gzqzepln,S', 1.0), ('Npqrhhvt,Ogrle', 1.0)]
# [('Igosxtz,Bfcsmjpz', 0.0), ('Ilrjjdvdskiw,Hy', 1.0), ('Xvlljeewto,Opkrsvbf', 1.0), ('Tckyrookkwhwd,D', 1.0)]
# [('Xczssruqioex,Xadcdm', 0.0), ('Ohmyiwxzjdhdb,Iv', 0.5), ('Uvlumxvx,Xjdjes', 0.5), ('Obikzmifdcvo,Qkfzxj', 1.0)]
# [('Kbjlbsthsy,Tyailf', 0.0), ('Trujohhuindy,Gpt', 0.0), ('Ymeafeqlaora,Eeo', 0.0), ('Mrskoh,Wiqz', 0.5)]
# [('Mfjcwejpbqvq,B', 0.0), ('Sqrmvvy,Cjcoyjem', 0.5), ('Eymcqfo,F', 0.5), ('Aoptqvmhufbmj,Bfigxsm', 1.0)]
# [('Xzmibygmjoy,Bfjedy', 1.0), ('Laiehwvzkhwgv,Klpyxzpr', 0.5), ('Nvqkiorkfhrc,Ksvc', 0.0), ('Oswkhclsly,Sll', 0.5)]
# [('Jpyzlvp,Ubc', 0.5), ('Zdmwaurafqrtz,Vaei', 1.0), ('Xcqmqnyez,Ymg', 0.0), ('Igyqduklteq,Effqswlc', 0.0)]
# [('Bvgrwil,Ai', 0.0), ('Zkvractkmej,Owrmitnwl', 1.0), ('Drhymrwzaq,Zavn', 1.0), ('Ewychqneimbg,Reejo', 1.0)]
# [('Uwrwhwtfu,Odm', 1.0), ('Rxcxnju,Hxuprf', 0.5), ('Pgivcygi,Mdslmkp', 1.0), ('Pmwksaxzhtuh,Xrgnag', 1.0)]
# [('Mgudihy,Wmaioi', 1.0), ('Skhxeis,Ndyhs', 1.0), ('Vqmnwzqd,Np', 0.5), ('Tkcpkzdhbpc,Ntiz', 0.0)]
# [('Qpgahgfjqr,Yqwzsu', 0.5), ('Drkmlluxcpwmd,Vdzrn', 1.0), ('Nzshkoargx,Nlow', 1.0), ('Utdegktoy,Siet', 0.0)]
# [('Wxcwakzjxje,Uqiaqow', 1.0), ('Nfnxit,Lpjgumabb', 0.5), ('Xoptwpxlnvvmt,S', 0.0), ('Qtrqyzf,Dlb', 1.0)]
# [('Gccbxfpgb,Tfdvrw', 0.5), ('Qklnnitldywpt,Jdgdd', 1.0), ('Tlgihmhtlwgy,Bkamogra', 1.0), ('Mgveoofrva,Zmdscon', 0.0)]
# [('Yydkflosppqbc,Eykvqojjp', 0.5), ('Gmjzlriccpjby,Rxyukde', 0.5), ('Xwrlbg,Bt', 0.0), ('Tdyfbxuftial,L', 0.0)]
# [('Klqcwmm,Heznuh', 0.5), ('Bdqrzvb,J', 1.0), ('Fjjfgj,Ovr', 0.0), ('Rqzqbubytm,N', 0.5)]
# [('Widkgdfuokl,Nlw', 0.5), ('Ysybdxudfasy,Enms', 0.5), ('Owtkihullvzgr,Pcowvo', 0.0), ('Dmgvtxjv,Gtlcjv', 0.0)]
# [('Hlklqespgt,Nnk', 0.5), ('Ssetexwwsajx,Fbunbxudj', 0.0), ('Qozegjj,Gbvssphme', 1.0), ('Snfjghmiygc,Qqf', 0.5)]
# [('Gktdumsvhjga,Eomfetv', 0.0), ('Ikipbrkvh,Vugdvdws', 0.5), ('Ymbcjlmx,Gl', 0.5), ('Ievgukopjccpj,Cckwo', 0.5)]
# [('Mhseycgpfk,A', 0.0), ('Dpjzxjnjao,Vtf', 1.0), ('Rxoxri,Mkieyworc', 0.0), ('Yiqytzbfv,Pwklcl', 1.0)]
# [('Omxiwnk,Ref', 1.0), ('Pombow,E', 1.0), ('Odvddsw,Kfmkxan', 0.0), ('Bzrvbxeux,Iwlt', 0.0)]
# [('Pkwxntuwvh,Lfuz', 0.0), ('Hlxmokxekb,Za', 0.5), ('Yjwhoqep,T', 0.0), ('Lkiwdkcx,Pcslpv', 0.0)]
# [('Twffmguqn,Vhbhlk', 0.5), ('Ffgpkvyohni,Ski', 1.0), ('Rvlwxfad,Ompohh', 0.5), ('Pzspouam,Uysylxu', 0.5)]
# [('Mhkfvwhi,R', 0.5), ('Uvpouib,Oftse', 1.0), ('Xdkoans,Jpbymots', 0.0), ('Rcdbjkwbnq,Uvhl', 1.0)]
# [('Gszkof,Ahrpv', 0.0), ('Sypftcqumxiog,Iwjlqpx', 0.5), ('Glrwnkrsohb,Kfldvx', 0.5), ('Fftuxvue,Ojnee', 1.0)]
# [('Lskzfargepg,Nlfj', 1.0), ('Mjqgtybuycgck,Rzfrejdh', 1.0), ('Eqgrcg,Hzrc', 0.0), ('Mmoxmlxuhu,Smojw', 0.5)]
# [('Zukcuc,Hae', 1.0), ('Shuzfowpsp,Jktvsjbj', 1.0), ('Wheepwq,M', 0.5), ('Blpuvmbkedd,Vhji', 0.0)]
# [('Vuddmuzdbxl,Wksggunsb', 0.0), ('Flsaqadwse,Kpt', 0.5), ('Lidrqmeujhqbn,Qios', 0.5), ('Okxsdhdeqs,Eowgfauiz', 0.5)]
# [('Uwuvhff,Wistadx', 0.5), ('Jyolpktjhkcip,D', 0.0), ('Eedtjugqvuz,H', 1.0), ('Hfhhqsmqmh,Yhmvupsp', 0.0)]
# [('Gjcmevgjvakcs,Usxop', 0.5), ('Ltzuyw,R', 0.5), ('Vkpxjec,Vwtv', 0.0), ('Qunugvciyjhhb,Rn', 0.5)]
# [('Xcetxu,Vpw', 0.5), ('Fsmnfywy,L', 0.5), ('Yatclcmk,Lrl', 0.5), ('Vtekfq,Ckigkk', 0.0)]
# [('Gxwqhrs,Jhun', 0.0), ('Egcixxryfj,Nmclmuo', 0.5), ('Axooqmgx,Tiapk', 0.5), ('Mcwoptwg,Lhhmrldzb', 0.5)]
# [('Jlankljx,Ug', 0.0), ('Mxtivrxhb,Zngvpwhhs', 1.0), ('Axtbtzhzxfnd,Hlhzwu', 1.0), ('Kverbpldgzcl,Qej', 0.0)]
# [('Wndkcrolrrlac,Nmijtzd', 0.5), ('Aueavqirsggt,Rkt', 0.5), ('Idocuycesmffh,Pidtifq', 0.0), ('Ojrtznpn,Kaisbwtt', 1.0)]
# [('Bbxnmeotavryw,Oj', 0.0), ('Gfgkdkhxwqbw,Ccklg', 1.0), ('Zjolgcmg,Swhbqsov', 0.5), ('Yoiriaqjwkhqz,O', 0.5)]
# [('Fdhljml,Ac', 1.0), ('Godgwzceod,Zy', 0.5), ('Mtdyitdkhd,Ajateany', 0.0), ('Gdudplbpmcidc,Hjed', 0.5)]
# [('Wyvjqexhlduy,Srwrgts', 0.5), ('Dkovwcwxaronc,Me', 0.5), ('Brbmyttynkez,Zlc', 1.0), ('Smbpfgutz,Qnacn', 0.0)]
# [('Zqvmqmotnptu,Fldnkooab', 1.0), ('Cwmargeq,Qz', 0.5), ('Zhbfauzrv,Xaztme', 0.5), ('Cvpjvtlktz,Ghok', 1.0)]
# [('Mkztrvbo,Xikkg', 0.5), ('Zxzmdkpx,Wuy', 0.5), ('Tpzzmturbpwl,Sasbif', 1.0), ('Ejwvyv,Gn', 1.0)]
# [('Xpkrsyxnhfij,Wcqohiw', 0.5), ('Zitetdto,Ihyqdule', 1.0), ('Xpdzkvgcac,Nqbhroyn', 0.0), ('Upzpts,Rk', 0.0)]
# [('Aefmotlybqghw,Ajxbmy', 0.0), ('Kiedamdhsfvgh,Lyqcxhv', 0.5), ('Jfnmhvk,Fe', 1.0), ('Dyqliqhyf,Kza', 1.0)]
# [('Utpfhzod,Tjnchdrrj', 0.0), ('Tpxnnwim,Bituilzd', 0.5), ('Gzanbw,Ts', 1.0), ('Emhdymqvofdeb,Mack', 0.0)]
# [('Gacekfnf,Rf', 0.0), ('Isspulfw,Qnlmphjji', 0.0), ('Qwmvqz,D', 0.5), ('Wqcrftxdmha,Ml', 1.0)]
# [('Iqtqmgtgmyvdm,Qgo', 0.0), ('Ahyafuu,Iwrsbx', 0.0), ('Fzwjdovuwow,G', 1.0), ('Voehkkzuhob,P', 1.0)]
# [('Diklrwaxmltz,Fpk', 0.5), ('Pphupgslur,Himazq', 0.5), ('Fedzkzfthoi,Tovhxcepd', 0.0), ('Lqfxjdev,Eqdmoyzvr', 0.0)]
# [('Xofuoqaqhxh,Dhbnxkj', 0.0), ('Cnsdqwkc,Fc', 0.5), ('Mpqwplc,Aaqiphjr', 1.0), ('Ceqmzclwf,Ozgdzrqoq', 1.0)]
# [('Toqhsnbpkoqf,Bxbxng', 0.5), ('Bzxqtly,Vn', 0.0), ('Lpjlvsesqhbbk,Ztoq', 0.0), ('Rpugjowvx,Tkipcxr', 1.0)]
# [('Kfapfibbxgtwx,D', 1.0), ('Fksdiu,H', 0.0), ('Jenpnzhc,Ghgbhxs', 0.0), ('Qspdvfnbugj,Cvjeznbg', 0.0)]
# [('Rhgqgqpyh,Nt', 0.0), ('Sxwxbajaq,Poro', 0.0), ('Vyblaiwucfm,Vvo', 1.0), ('Vvhkknnzelib,Dp', 0.5)]
# [('Leliurbfhp,Os', 0.0), ('Fqkkjcnlnbqw,Jowqlzq', 0.5), ('Dyewww,Smkkiktd', 0.5), ('Ytwfbeceacn,Lls', 0.0)]
# [('Mkhukakriy,Mmt', 1.0), ('Upvghxdbd,Maplmjb', 1.0), ('Rnteecbch,Esliq', 0.5), ('Gujkwafpdx,Mi', 0.5)]
# [('Fjtqld,Ymjmzgiv', 1.0), ('Ddmszbepr,Sotwk', 0.0), ('Ldhtctipxjjm,Ls', 0.0), ('Vxoziljmoh,Rnkvgdi', 1.0)]
# [('Ddlyepbtwmsj,Hisrkh', 0.0), ('Exibzczuqzyn,Lkxnaog', 0.0), ('Kfoufsyemx,Oswadcfjl', 0.5), ('Ftovyjg,Tloezoud', 0.0)]
# [('Uidocsd,Jm', 0.0), ('Djyvbswjqbv,Wpo', 0.0), ('Xcvvymkf,K', 0.0), ('Qyahwbpmzgt,Ewjmk', 0.5)]
# [('Awlwbqy,Spvle', 0.0), ('Iptwifktq,Pnpsu', 1.0), ('Ylqseqmgd,Vq', 0.0), ('Cguaamanwo,Bwrjjr', 1.0)]
# [('Waamwgfuv,Qmnmdcp', 0.0), ('Nocfgqlzw,Ipxlrpogu', 1.0), ('Nxmdyk,Xgtlphea', 1.0), ('Eqtemjg,Ncugke', 0.0)]
# [('Vuqoicpawyj,Kkiopw', 0.5), ('Qkatsin,Zizknhok', 0.5), ('Vksljkke,Vl', 1.0), ('Weojdvnbnah,Mweq', 0.5)]
# [('Mygeax,Fxa', 0.0), ('Wynszggo,Zotnqoxkh', 0.5), ('Djhxjz,Tvhoukn', 0.5), ('Gtvvklkpdpt,I', 1.0)]
# [('Netrbanjgh,Aegja', 1.0), ('Ojurbzldx,Uwcaeych', 0.0), ('Auctbxfhw,Rgrqce', 0.0), ('Nskcewbiosjy,Lsthui', 0.5)]
# [('Rxcjedtbijk,Etunp', 1.0), ('Baijdnuo,Hjpm', 1.0), ('Neoqqgg,Zhcxopl', 0.0), ('Zrhsyjnxuh,Uwkdn', 0.5)]
# [('Jifixqdmxiv,Rgep', 0.0), ('Geuktnfzf,Pwk', 0.0), ('Ifjgbm,Hz', 1.0), ('Icrgcleqvqlx,Ig', 0.0)]
# [('Bmwcfjdutclfz,Tkywk', 0.5), ('Hqiceqdyhnij,R', 0.0), ('Wdetofmawdy,Srlrznq', 0.5), ('Ouonni,Foxll', 1.0)]
# [('Ffumuchr,Oqqmmlr', 0.5), ('Hxbtgsiwiwjj,Kqld', 0.5), ('Anwqyffqwnlb,Eormpejpk', 0.5), ('Xbdkeg,Mkkbaja', 1.0)]
# [('Ndndgfyw,Imzdqcr', 1.0), ('Rgtnovmm,Fvjoa', 0.5), ('Hbkxcoxff,Kfxzzlt', 1.0), ('Qvjgbsho,Jkmz', 0.5)]
# [('Sykhbkvggxa,Fpqkhtqo', 1.0), ('Qqtyznbxvtgb,Jq', 0.5), ('Jkwngssjjdoo,Andyoqqrk', 1.0), ('Fcmbha,Ngvnrf', 0.0)]
# [('Grqcwqyy,Tces', 0.5), ('Omeodebatbl,Q', 0.0), ('Yyyljeuvmr,Aav', 0.5), ('Wqyqmxgevxz,Xkni', 0.5)]
# [('Uftjxftbhbx,Gkgfua', 1.0), ('Nteoyb,Calcegv', 0.5), ('Pkntrpjbpapr,Ry', 1.0), ('Rszvikrjw,Dj', 1.0)]
# [('Pjiszr,Cf', 0.5), ('Bmowdnfvifs,Qij', 0.0), ('Ylemjtuldk,K', 0.5), ('Lwnujl,Lbmhpdes', 0.0)]
# [('Xbsydxmguqdnt,Ztugs', 0.5), ('Fmshekrn,Dekojkx', 1.0), ('Vsapbu,Apx', 1.0), ('Mucmwvqyw,Ono', 1.0)]
# [('Drcvgiu,Fhgzijob', 0.5), ('Ulzeqzop,Cbiur', 0.5), ('Vjfsshykcb,Obexdzf', 0.5), ('Wjelmvwfqq,Mbuc', 0.0)]
# [('Knoeefhejjj,E', 1.0), ('Qidxoaj,Lqsvnsa', 0.5), ('Exsqwrlcxeeyv,Ykvvfoz', 0.5), ('Sdpwwyv,Eycmfful', 0.0)]
# [('Xorzywucijms,Tdl', 0.0), ('Vbxhoz,Pznkaq', 1.0), ('Hbznhclmb,Nrie', 0.0), ('Xbhoedlk,V', 1.0)]
# [('Ocxeytw,Japkrbxla', 0.0), ('Mkzwmuhljy,U', 0.0), ('Uegixwxbiig,Nrsfnw', 0.5), ('Wistsqj,C', 0.0)]
# [('Hbksdjtwx,X', 0.0), ('Yhlqgrwsxt,Gepqbeh', 0.5), ('Tuzldkf,Rlzo', 1.0), ('Ayihjfqb,Uzaixk', 1.0)]
# [('Fnwszing,Zldy', 0.0), ('Hsinpfaqlgtg,Dvutcs', 0.5), ('Qlwkyuvlajogo,Fcnhe', 0.5), ('Rypazfvqjtj,Mfe', 1.0)]
# [('Tkfjceiigva,Xgcc', 0.5), ('Poxoasvseapr,R', 0.5), ('Jibamlieuoca,Gbk', 1.0), ('Ypdmzbsvqb,Mmt', 1.0)]
# [('Xevgybjd,Dhpngymfb', 0.5), ('Menggdgg,Zjcdr', 0.0), ('Ggaaoqlvqkntf,Rogqallee', 0.5), ('Axmpnldk,Xqxpc', 0.0)]
# [('Rmhmulk,Zf', 0.0), ('Imulwdiu,Fzztt', 0.0), ('Hvnncx,Cveo', 0.0), ('Axtsoi,Axjwn', 0.0)]
# [('Ajrmmbakcmtxp,Lcjbvhf', 1.0), ('Cmzxxprrl,Yk', 1.0), ('Syhlnjopewlyk,Hzkfk', 1.0), ('Vnivkcnredhdz,Jcaco', 1.0)]
# [('Ydqtoxdtmeilm,Iqrblg', 0.0), ('Jtkpksxglj,Qnmomr', 0.5), ('Sahsmk,Ugupqvfce', 1.0), ('Snwzqjs,Jfqufyt', 1.0)]
# [('Sbdddmrayjr,Kmrhn', 0.0), ('Awxuginrhp,Tsvn', 0.0), ('Birsvrt,Tndlsvttb', 0.5), ('Jxwfwrkvymv,Ppgqwxmku', 0.5)]
# [('Yzrkaxdf,J', 0.0), ('Mktvleg,Oo', 1.0), ('Gdjfcizqp,Ltvsdpc', 0.5), ('Wdnnscufnonzs,Us', 0.5)]
# [('Bvmgvqmuf,Awwvdhmo', 1.0), ('Depbvx,Rhvbty', 0.5), ('Osyuoqbcie,Xkxnycuw', 0.5), ('Dmpqovgrfmya,Bqlzcmun', 0.0)]
# [('Ewcflofpxa,Gk', 0.0), ('Pfkkxnqbzrq,Wgzlis', 0.5), ('Vbwdadplgbsop,Cixqtx', 0.0), ('Cnwocpptbt,Rtjvmdtq', 0.5)]
# [('Fmphmimyiqfmz,Mp', 0.0), ('Wjwmvk,Tblrzgiy', 0.5), ('Lobfdtfpkri,Zd', 0.0), ('Ajfuedgorzy,Ruumix', 0.5)]
# [('Valponwoqvx,Li', 0.0), ('Zhoiatbue,Ydvknnj', 0.0), ('Cnbrhv,Htno', 0.0), ('Rosyandstu,Pde', 0.0)]
# [('Mhkejxem,Qjzshlk', 0.0), ('Vfjghbatjfk,Tjrkp', 0.5), ('Suaouoahs,Xcynm', 0.0), ('Hxeceur,Rxazhnycs', 1.0)]
# [('Wtnxejnm,Avy', 1.0), ('Ycgmxduiiwdy,Q', 0.0), ('Rviejnw,Euwz', 1.0), ('Ybtjyut,Csjjbuw', 1.0)]
# [('Nxbdxsm,Ins', 1.0), ('Cmflpjocwax,N', 0.0), ('Yzukktmag,Gkhhykdog', 0.5), ('Qcrmhiiaw,Jhbj', 0.0)]
# [('Dsoxqzmat,Gyvnzg', 0.5), ('Iotpnwm,Icuksfe', 1.0), ('Wtieti,Z', 0.5), ('Johcsuug,Kxgvqdhnf', 0.0)]
# [('Svbqtlnah,Voi', 0.5), ('Vwomtllmnuqh,Sttqjavur', 1.0), ('Mdcxxddprwz,Hc', 0.0), ('Czambbr,Wpitry', 0.5)]
# [('Mqhzbnzjhrt,Fubnxj', 1.0), ('Iueckahz,D', 0.0), ('Rhwsik,Pwtwhyc', 0.5), ('Fxcvrgnepopqe,Kczvxl', 0.5)]
# [('Lmobnzd,Cuc', 0.0), ('Urnnvrhsii,Dhzncfvas', 0.5), ('Afhtwkqoo,Jtmntiptu', 0.0), ('Grjjis,Reyt', 1.0)]
# [('Umqbgpmslr,Xvrbffjth', 1.0), ('Pcsqyygzj,Kvouu', 0.5), ('Bofxacjwwhfpe,Rvmau', 0.0), ('Qbzpprurhyvvj,Ya', 1.0)]
# [('Tcsdcswok,Glpfbkv', 0.0), ('Yojhrftirqra,Tnd', 1.0), ('Slfwrxiz,Wnzv', 0.5), ('Pnlkogsaqeakc,Dfujdxh', 0.0)]
# [('Cqbjohkab,Trlbkx', 1.0), ('Okcjrbslyn,Jtrv', 0.5), ('Xodatr,Tfp', 1.0), ('Hnfoxdrqtwn,O', 0.5)]
# [('Zgoijavrc,Znhjpxc', 0.0), ('Ekmhkaeexad,M', 1.0), ('Nvsepn,Dkz', 0.0), ('Jzjmzqqdofdge,Tzjer', 1.0)]
# [('Ljxrtawkxizdl,Ak', 0.5), ('Dpucinqv,Rnlgcp', 1.0), ('Werxng,Qmpgyo', 0.5), ('Xufdcsk,Rd', 0.5)]
# [('Sckvugsy,Bsphpqe', 0.5), ('Javkrrgx,Wech', 0.5), ('Pzuvnhh,Kfgzsqa', 1.0), ('Rfpkbdymwgg,Bbucatmju', 0.0)]
# [('Ojmpph,Zngb', 1.0), ('Xszlbkdnf,Yanp', 0.0), ('Qcndvcxmatgfk,Yizt', 0.5), ('Utnhkhhqm,Mdvypmrf', 1.0)]
# [('Yqttdzmuq,Cejkf', 0.0), ('Phlnwwhxxtk,Ibimwpp', 1.0), ('Wqloksjhlixsd,F', 1.0), ('Scatnsefv,Oldhmt', 0.0)]
# [('Mnjedxowgyn,Ppz', 1.0), ('Xozurj,Qvfqxuapw', 0.0), ('Whddnmohue,Tfo', 1.0), ('Adbsjtni,Liaagv', 0.5)]
# [('Gjbfvgypxxwe,Dmqabyn', 0.0), ('Yzfcuf,Ehmatxiag', 0.5), ('Hwvgnwylvn,Qdez', 0.5), ('Ssathoewd,Oodhx', 0.0)]
# [('Xviypnedv,Sopmpq', 0.5), ('Uuurrlbts,Pprhrh', 0.0), ('Kwfkehy,Rrkeidlsb', 0.5), ('Isshkbq,Z', 1.0)]
# [('Hmrskz,Pboljp', 1.0), ('Wnwsarx,Cn', 1.0), ('Xmajtlabtkz,Eeluulul', 1.0), ('Vqizyu,Jxvszbgvo', 0.5)]
# [('Bcztgxuwy,Y', 0.0), ('Fgohjxbge,Iwrkbme', 1.0), ('Sffqtna,Uqepy', 0.0), ('Soihduizji,Cumvd', 0.0)]
# [('Luadizs,Vtpsb', 0.0), ('Sxejfylgrnon,D', 0.0), ('Ifwihhhgimiow,S', 0.0), ('Rnmjjglaay,Dpkuy', 0.0)]
# [('Wfdkdfxirx,Ddkuqcp', 0.0), ('Qogurft,Mrfu', 1.0), ('Npxejila,Cfv', 0.5), ('Dmklbt,Zvjx', 0.0)]
# [('Itdzhrzgxiri,Xlwqivbw', 1.0), ('Xadorl,Fdjpyngje', 1.0), ('Ykethdpro,Qrpuok', 1.0), ('Tskxsoyvafoka,Buopwrn', 1.0)]
# [('Jisarfkh,C', 0.0), ('Evwkrtku,P', 0.5), ('Yxzqqidztuefc,Uief', 0.5), ('Daeowd,Bux', 0.5)]
# [('Cygwvtv,Iomxglty', 0.5), ('Rfioqcaxtwt,Gfxm', 0.0), ('Nqdskfhmuw,Wchvz', 1.0), ('Pxjywly,Rmltxh', 0.5)]
# [('Lfegvjiffg,Ootvp', 0.0), ('Byxebpstddl,Trbg', 0.0), ('Ythtfktf,Foyah', 0.0), ('Ptspkvfjkf,Eam', 0.0)]
# [('Tpyettdimca,Ttwpxzqp', 0.0), ('Zxuwvikab,Xtijyqx', 0.5), ('Illjbwjperpb,Ujjn', 0.0), ('Dnsiybxl,Zocqlgwjs', 0.0)]
# [('Ntokgcrfvijr,Vbknidm', 1.0), ('Trtnjbwbmnbkt,Xlhncict', 1.0), ('Qljtizx,Plr', 1.0), ('Hqcmgubsdyz,Fwqp', 1.0)]
# [('Gakdkl,Uesa', 0.0), ('Imtlksaioi,I', 0.0), ('Dwazewa,Jc', 1.0), ('Snrpez,Kiloxyf', 1.0)]
# [('Iszidftk,Qb', 0.0), ('Odqykygip,Tvmaauhh', 0.0), ('Qucletj,Vkujtgo', 0.5), ('Tcfpmr,Naomcdl', 1.0)]
# [('Qsudxxdhf,F', 0.0), ('Jdaqwky,Ububeo', 0.0), ('Phpyou,Gz', 1.0), ('Ftjbxzxfq,Fyahgoq', 0.5)]
# [('Guivwmsusimb,J', 0.5), ('Vrrqjt,Bpxmcdr', 0.5), ('Whfqmlzwveddo,Fkwxb', 0.5), ('Cfsshckoirj,Pdgixi', 0.5)]
# [('Mskxmrhfg,Huupdvjcd', 0.5), ('Wsfirauvybx,Rtkxoev', 0.0), ('Oceemzix,Tddjsk', 1.0), ('Ulojopcjtkby,Zlrpgq', 0.5)]
# [('Buwaykanh,Gcvkovcz', 0.5), ('Utexbd,Vheqxzypd', 0.5), ('Lcqapt,Jjuaoyfka', 0.5), ('Jsttxnbhv,L', 1.0)]
# [('Gfqaiqnzjgw,Gpp', 0.5), ('Ldvuiwqdhv,Eogailv', 0.0), ('Eysczgkmrsbe,Ejinbhvj', 0.0), ('Eswnqlltzs,Xnbgcvz', 0.0)]
# [('Fcabkpqeyai,H', 0.0), ('Hebocbfkm,Emldoar', 0.5), ('Bilnofoqacfd,Ijyuyokmc', 0.5), ('Xohrgsacjzjk,Unse', 1.0)]
# [('Pdowvbktizc,Krl', 0.5), ('Wgkklyobvkgdd,Ethtwl', 0.0), ('Vhuhybvatt,Cvfmglrqt', 0.5), ('Netzdmd,Kpezr', 0.5)]
# [('Feamlk,Todr', 0.0), ('Tcacbe,M', 0.5), ('Rihubec,Vqsrsut', 1.0), ('Clbpfkwkg,Uznucmpn', 1.0)]
# [('Kvpesz,Sbjc', 1.0), ('Lyufvqehdjz,Sosux', 0.0), ('Jfxbqjp,Wqjr', 1.0), ('Pxndgksaljh,Asvjfcrgt', 0.0)]
# [('Pkanseswroqp,Dtodjy', 0.0), ('Luzgzlvxsjae,Kg', 1.0), ('Drijahwi,Yjrncsq', 0.0), ('Rvyhgtpafke,Yfqjq', 0.0)]
# [('Ikzfuekz,Gjgj', 1.0), ('Gxcsqchrrcsg,W', 1.0), ('Rsrzactclovsw,Htubwaqbx', 1.0), ('Unkjgauhmh,Qy', 0.0)]
# [('Igvazwqtoqksk,Tyzykrzj', 0.0), ('Btlrzvbaqp,T', 0.0), ('Nmcjohcmho,Euiga', 1.0), ('Wvtjoxromq,Tbzo', 0.5)]
# [('Sbpkkbfoaa,Mir', 1.0), ('Xcaffrpacvyv,Jlmgxvbh', 0.0), ('Jqgtqwkstfhfz,Zjagtrg', 0.5), ('Cyjppziijgteb,Zj', 1.0)]
# [('Kewqqpkhr,Dribbiaqq', 0.5), ('Jshqbaqtolejm,Lt', 1.0), ('Zzweuwieubt,Gvnsmpk', 1.0), ('Okfqoo,Ptbfitq', 0.0)]
# [('Ksbnguwwynh,Xzxwbdy', 0.0), ('Knjvgwcorgra,Nikylqd', 0.0), ('Tcfbbdufx,Vlhucu', 0.5), ('Pgjcewxvz,Xddohlovb', 0.0)]
# [('Gellxms,L', 0.0), ('Lbexhhyoc,Z', 1.0), ('Uorfoxgdjf,Ax', 1.0), ('Oodyekkd,Xsgizsw', 0.0)]
# [('Adpttdldflgt,Uoeeovdpb', 0.5), ('Pevnbsfnz,Frtitogap', 1.0), ('Rsppdrn,Thnjvlkl', 0.0), ('Orrlin,Tm', 1.0)]
# [('Okpintuoqiaxv,Tscxisb', 1.0), ('Qfcjsdjz,Nn', 0.0), ('Iilsdgtoyukzw,Quoylm', 1.0), ('Cegccxj,N', 0.0)]
# [('Gpgmkkwhppu,Fw', 1.0), ('Kpevgvad,E', 0.0), ('Zoiavwgjfijm,Huyunueev', 0.5), ('Pjazpc,Yq', 1.0)]
# [('Phqfxn,Aosn', 0.0), ('Nndxkbgsjdew,H', 0.0), ('Gvomhoc,Splmogpiq', 1.0), ('Tswtjqm,P', 0.0)]
# [('Tnoxkgtf,X', 0.5), ('Gmtvvgokreesd,Iwxzmtp', 0.5), ('Dykwuog,Azhtuafin', 1.0), ('Eiermirw,Xpoaw', 1.0)]
# [('Zjnyvv,Wryq', 0.0), ('Qqakuiv,Gzr', 0.0), ('Lzsbtcm,Kdcnact', 0.0), ('Unpkwh,Cefvpx', 0.5)]
# [('Dzzjsmzzdxwcg,Qhgrncm', 1.0), ('Ifnzbkiokyw,Zflqat', 0.5), ('Aoyjgvos,Vtbftrnea', 1.0), ('Wukcizhnphy,Porpp', 0.0)]
# [('Qgkxlzcb,Vgkjlmw', 1.0), ('Scemoy,Y', 0.5), ('Hvfsxzfqgu,Vkriz', 0.0), ('Febewh,Uccgkf', 1.0)]
# [('Gunkcjgr,Lvbpyh', 0.5), ('Zwfzgeqsag,Ett', 1.0), ('Toyrzfmb,Sz', 1.0), ('Gdfaclhvqh,Fpa', 0.5)]
# [('Chwzuljaq,Esawqln', 0.0), ('Durhxp,Dzould', 0.5), ('Usxaahbvib,Vjswrug', 0.5), ('Cwwwazeksf,Cnnrzwgjq', 1.0)]
# [('Jldoui,Vyxxpbkct', 0.0), ('Rgjtgdmtau,Jfdg', 1.0), ('Issvakftdh,Lwu', 0.0), ('Fagapjtqpx,Vkvb', 0.5)]
# [('Tzqpmz,Urpjzan', 0.0), ('Zhyjoxsimxblc,Ec', 0.5), ('Foeiiloqxoycz,Cwzdyiy', 1.0), ('Squtgmphcu,Jgiwq', 0.5)]
# [('Zuxiwqjejfos,Sfpucaby', 0.5), ('Aupsavrd,F', 0.0), ('Arugpqlbk,Bfrotetyc', 0.5), ('Vpzojfwselbn,Xytm', 0.5)]
# [('Acvdlyb,Pyxfs', 0.0), ('Pgscbdzkwi,Uwnldpkfy', 0.0), ('Faqlyksphzll,El', 0.5), ('Iondtt,Nynyos', 0.0)]
# [('Actvkhxo,Q', 0.0), ('Ijlzbgvxzkaxl,Vds', 0.0), ('Zufpqpzhhxo,Bzdeeog', 1.0), ('Iriicgpgejsov,P', 0.5)]
# [('Wnhsuue,Vdgdaub', 0.0), ('Tdblerwtrt,Odwmmy', 0.0), ('Bpupdxiaqygy,Zljmdefec', 1.0), ('Hudqnzegomvl,X', 0.5)]
# [('Rcnycfpwsan,An', 0.0), ('Srhdepkaghdgb,Eqt', 0.0), ('Prmzbe,Qjlya', 0.0), ('Ahlhsu,Jxzusyxtz', 1.0)]
# [('Zotzmlvxffdw,Hsxmlf', 1.0), ('Vouzlse,Wmelxoyry', 0.0), ('Zuylcrk,Bfnkn', 0.5), ('Pyyvrxk,Bdd', 0.0)]
# [('Rvnsvzr,N', 0.0), ('Zpifaoi,Irlrgwc', 0.5), ('Dutnvyynuwk,Spspzfkdp', 0.5), ('Vewafn,Dktk', 1.0)]
# [('Qqbrvod,Fkyjawg', 0.5), ('Vnqbwonehvmg,Qfj', 1.0), ('Tzgfzsvfp,F', 0.0), ('Mexvenhtxqwe,Xlcpanf', 0.0)]
# [('Fmqkdiylbrf,Ukao', 0.0), ('Zeinmdibpxg,Jalna', 0.0), ('Xkeummjbjfdr,H', 1.0), ('Mcdouovmsg,Zrinrneh', 0.0)]
# [('Gvlrifirouxj,Kyfpgjt', 0.0), ('Dtlsywkyizd,Ybrxla', 0.5), ('Rripbhsddmwnr,Rxqirkblk', 1.0), ('Sksndy,Czja', 0.0)]
# [('Ismcemjg,Ourvqefr', 0.0), ('Qykktbdvjrv,Dmg', 1.0), ('Gonitlcvqp,Kowzaon', 0.0), ('Pchcbel,Me', 1.0)]
# [('Jbtxaxti,Lzqorti', 0.5), ('Sodjlowonnoj,Ahbw', 0.0), ('Iezlydhdcfnvn,Vylloz', 0.0), ('Ypphxehougzd,Wctpp', 0.5)]
# [('Dalbmruz,Ljaf', 0.0), ('Mbhyqzqmls,Mbkcviyit', 0.0), ('Zplnnaocfz,Rlae', 0.0), ('Rkalex,P', 0.0)]
# [('Qepviofwh,Nqznqoiph', 1.0), ('Msywgcyb,Lhv', 0.0), ('Oywbyxrvle,Cigswamfl', 0.0), ('Kuqzcmj,Llk', 0.5)]
# [('Pyovom,Vg', 0.5), ('Ptpfxmqrvdcho,Ssjbvknk', 1.0), ('Dzhnvcrezxgbg,Dpijn', 1.0), ('Stadtvlfuwi,Owcrqw', 0.0)]
# [('Tpfqfis,Trq', 0.0), ('Cixykljzbby,Vqp', 0.0), ('Heztvjatvmu,Hqrqfh', 0.0), ('Gtoeraof,Zygxfutr', 1.0)]
# [('Bhbligyez,Bsdzlhaum', 0.0), ('Gykfwpyadww,Gwopknejd', 0.5), ('Kgjnwijs,Jrc', 1.0), ('Ctanjvpkwvur,Ygydp', 1.0)]
# [('Tklansyxpwqbk,Omejytwn', 1.0), ('Jmtstamtdfx,Jf', 1.0), ('Boffsiycjhdq,Xgso', 1.0), ('Txeogojjgcnno,Gayjulc', 1.0)]
# [('Dgpwsy,Jlalem', 0.0), ('Pbbigbhi,Vtd', 0.5), ('Sznkkcx,Spx', 0.0), ('Ennnnhqu,Tolgzl', 0.5)]
# [('Wphulvj,Cgvap', 0.0), ('Njukcva,Ygfyvlm', 1.0), ('Tsuumood,Xrzcabhes', 0.0), ('Qthdghqaitbt,Cykrv', 0.5)]
# [('Pbpjuvazkxnm,Y', 0.0), ('Uajjnsxez,S', 0.0), ('Ryavkzxx,Dvgyh', 0.0), ('Cxacacgvxyefo,Aws', 0.0)]
# [('Jwmwsliqm,N', 0.5), ('Jlewasukyy,Aryhwn', 0.0), ('Xaoroil,Ygjb', 1.0), ('Fpzyesuq,Ernbqpvd', 0.5)]
# [('Wbbdssn,U', 0.5), ('Exbhacfc,Cwukf', 0.0), ('Chzixydotxmbu,Zuydiz', 1.0), ('Tlmufoo,K', 1.0)]
# [('Itcgkcic,Kzlgoceg', 0.0), ('Wfbtwuctvqvxi,Yxq', 1.0), ('Xshmgxxuvxl,Gkmfxudg', 1.0), ('Bhldtrtn,Nmoui', 0.0)]
# [('Pontnkjmtq,Jeaqno', 0.5), ('Xnptcgeqi,Zx', 0.0), ('Wiavvuz,Xkkxfqsu', 0.5), ('Lssdtwaj,Q', 1.0)]
# [('Hgtncowhlc,F', 1.0), ('Qvnqvbyjsk,F', 1.0), ('Ytmtqgiwaj,Soruz', 1.0), ('Wuetzvh,Oxe', 0.0)]
# [('Vwfxtul,Npoub', 1.0), ('Vgiubxxji,Bbmtult', 0.0), ('Gzokzul,Wmuhzyq', 1.0), ('Qohqtzhjnce,Glv', 0.5)]
# [('Mozfag,Gca', 1.0), ('Ifjqzyzdyztvw,Z', 0.0), ('Ynfrlqvsb,Ylqt', 0.0), ('Zqlwlwodkz,Za', 0.0)]
# [('Oacciw,Lyucglgrw', 0.5), ('Sirmpqmz,Trsqowi', 0.0), ('Kpkvpkikmsudp,Mlcwzopaz', 0.5), ('Vygehh,Yjqehgdo', 0.0)]
# [('Fcjteooy,Tzmlolwh', 0.5), ('Eyyrajmyuvj,Xbzt', 0.5), ('Bksrialgbvcs,Phtagse', 0.0), ('Osbjjytvdun,Vxqy', 0.0)]
# [('Rwrwplsojv,Wmqjxog', 0.0), ('Hjcgasejohbbc,Xvoeavn', 0.0), ('Orthpmgt,F', 0.5), ('Xeftpwju,Skkcyj', 0.0)]
# [('Whwepkku,Yfksirsc', 0.5), ('Prayskaj,Rrxhsuu', 0.5), ('Dkcpbdz,Tda', 0.5), ('Yztgwbzui,J', 1.0)]
# [('Zlspiwrn,Whhpxs', 1.0), ('Rmdvmhbtmeub,Pqnaqoi', 1.0), ('Jvtauvzo,Dc', 1.0), ('Uyzaqaeatfs,Khfyhxlnt', 0.5)]
# [('Ibnoghs,Edlnpjii', 0.0), ('Hztsfvoeeehmw,O', 0.5), ('Jroajnoaxxmod,Iwu', 0.5), ('Amiafpdac,Qmlbfsqm', 0.0)]
# [('Byoogl,Eksb', 0.0), ('Bpkjahrrnymn,Ugffxrof', 1.0), ('Jviodxb,T', 0.5), ('Sdvdqnklyrkm,Hcrlc', 1.0)]
# [('Bzozmhiummztj,Ehgcom', 0.5), ('Qtvwelx,Qudiiwu', 0.5), ('Kqzuphmuj,Glonurp', 0.0), ('Mvbyume,Axzldxxlg', 1.0)]
# [('Guhzszjjqjpj,Izgsfppzg', 0.0), ('Okkzkskojcm,A', 0.0), ('Tqtngyzck,K', 0.0), ('Yuthnlavxym,X', 0.5)]
# [('Tnkjsmfepc,Igul', 0.5), ('Hfuixghn,Iaknzyj', 0.0), ('Goczyw,N', 0.5), ('Legkym,Xxvyhfo', 1.0)]
# [('Uchnstmjpxnu,Fiw', 0.5), ('Rilqtxjfdw,Xexaac', 0.0), ('Avtnnvk,Ssanx', 1.0), ('Ubbkqdifch,Ujnfjukls', 0.5)]
# [('Omdcbttllw,Rz', 0.0), ('Nfoifdfuea,Nw', 0.0), ('Kpollxgekb,G', 0.5), ('Kxhbvpxbeef,Lwwym', 1.0)]
# [('Bpftrfz,Febs', 0.5), ('Kqdrxr,I', 1.0), ('Xaezyqmuop,Vvaho', 0.5), ('Tbrpilp,Xgbfsjedw', 1.0)]
# [('Zptkgpmrvuw,Ovkv', 0.5), ('Nzeedwtwbxs,Prze', 1.0), ('Wgmuppirgu,Psobryzxg', 1.0), ('Xokcyn,Srce', 1.0)]
# [('Fimeonkig,Lf', 0.5), ('Dlfhpsmil,Vf', 1.0), ('Qxrvterw,Ul', 1.0), ('Fpjuvd,Urmjtl', 0.5)]
# [('Fkoaehae,Ulptexiil', 0.0), ('Kgexzve,Eoi', 0.0), ('Wdcyjjzbzeme,Ugiqg', 0.5), ('Urrdgzw,Mnuzdxli', 0.5)]
# [('Pemlqwtince,Gzetp', 0.5), ('Llbbgaqicuow,Qwwumhpge', 0.0), ('Uoxaoleeev,Xgwookvh', 0.5), ('Bptfsp,Omietczjm', 0.0)]
# [('Cdwoluj,Mwjbpksmt', 1.0), ('Vptxbjuqlvf,Rnvylix', 0.5), ('Yplygctark,X', 0.5), ('Wfrgeiybceztv,Stxeagve', 1.0)]
# [('Wrmfxxkgv,R', 0.5), ('Sqztjgs,Mq', 0.5), ('Ztodebbjeeah,Ykyrxa', 0.5), ('Bhcksh,Wbrpgej', 1.0)]
# [('Tzxauopp,Vlsnaim', 0.0), ('Gqzidhwxjpf,Erp', 1.0), ('Relgnmn,Rc', 0.0), ('Unqddyiplbqmy,Csafjcfrw', 0.0)]
# [('Sndhrrnf,Rghlkdpgs', 0.5), ('Nevnqkw,Nik', 1.0), ('Zpukmozepjf,Bk', 0.0), ('Rctfzdsxb,Lrhtkfpt', 0.5)]
# [('Drzoxdtjxajaz,Raorzuns', 0.0), ('Cprrnpaihao,Wj', 1.0), ('Lsfjiqfvas,Pc', 0.5), ('Caaphr,Boexdnczg', 0.5)]
# [('Bailyjlk,Vqwuclrx', 0.0), ('Dckvoczpjsc,Zekic', 0.0), ('Rwwgbodeny,Waj', 1.0), ('Jhweho,Tzqqbf', 1.0)]
# [('Vxhfynrb,Rf', 1.0), ('Qhofnwyupupha,Xbti', 0.5), ('Ybalomcvspqoj,Zbl', 0.0), ('Hchgzthumv,Cfejg', 0.0)]
# [('Zgavamifi,Rcwrqumz', 0.0), ('Bfbvowrij,Oiap', 0.0), ('Wpxwjzbdaa,Piobdwn', 0.0), ('Xsrvtpvtlvzul,Qmdmcid', 0.0)]
# [('Wtbsps,Toklqoy', 1.0), ('Etqofcv,Ncrwxqrwt', 0.5), ('Zwwjgltrir,Ayscf', 0.5), ('Hjooywx,Womwfj', 1.0)]
# [('Zdzccgvdi,Cw', 0.5), ('Yslfcw,Eu', 0.0), ('Glsjce,Opnd', 0.0), ('Trtwgikfgc,Unwoqzi', 1.0)]
# [('Rlzeniuz,Mfylo', 0.5), ('Phudzuf,Qbk', 0.0), ('Wnrwauktee,Fres', 0.5), ('Erluylghmb,Fjgtik', 1.0)]
# [('Gkzpyg,Akggql', 1.0), ('Kzrhdxkqg,Bthvkidm', 0.5), ('Okfqetziso,Zufhjye', 0.5), ('Kuieok,X', 1.0)]
# [('Qalqbqsdu,Rppnqrvj', 0.0), ('Rgenotw,Zwvu', 0.0), ('Djfmpdn,Ougn', 0.5), ('Arbugp,U', 0.0)]
# [('Edvzkswbxyo,Prjsyrbag', 0.5), ('Tnrykgzuafvq,Yp', 0.5), ('Osxfbpbmbzvl,Rowpcfnhy', 1.0), ('Vervoj,Qm', 0.0)]
# [('Jhvyaadxnapt,Kspwjvdf', 0.0), ('Pgzxld,Op', 0.0), ('Bxwvqassaprw,Uqrg', 0.5), ('Vbydjw,Wf', 1.0)]
# [('Fvnoqvcm,Cpgkwdzy', 0.5), ('Fhuialsqkwvid,Yw', 0.0), ('Uvkdcruhveqcf,Qrf', 0.0), ('Kbrcqrrvnfw,E', 0.5)]
# [('Ttvpnesj,Bal', 0.0), ('Ierwlr,Ujvsn', 0.5), ('Tcnbmo,A', 0.0), ('Dqzijcgalcp,Jav', 1.0)]
# [('Iwzdtxyecunjh,Syebpxdk', 0.5), ('Tvsqlau,Dsxyc', 0.5), ('Mtuzpofqwrl,Hs', 0.5), ('Mokqkdxpmerr,Bpps', 0.0)]
# [('Ygmlaqkaqsok,Lhx', 0.5), ('Ekblera,Zxk', 1.0), ('Cxfejdv,X', 0.0), ('Tncmgyy,Np', 0.0)]
# [('Hswasdqqxwm,O', 0.5), ('Vvlqmotbymflk,Of', 0.5), ('Khclpnnqnnc,Ttlnvgsq', 1.0), ('Kwagar,J', 0.5)]
# [('Qbaevuvuxz,Vwtbvu', 1.0), ('Anbxlek,Ceatnx', 0.5), ('Dqozug,T', 0.5), ('Rqmeqcyojawbb,Eojgf', 1.0)]
# [('Xvxlru,Mcbdwxl', 1.0), ('Pjoywie,Wyp', 1.0), ('Ipcxdxxceigr,Pepzxcb', 1.0), ('Sieckf,V', 1.0)]
# [('Bolzfqbbytsbm,Xsgkx', 0.0), ('Ufadgv,Gsryklad', 0.5), ('Uaaorfnmkzi,Gufqik', 1.0), ('Rgmncf,Irmkzah', 1.0)]
# [('Axzdixlkqodo,Mpiwqjv', 0.0), ('Xoqshfj,Bovbtro', 1.0), ('Btehauhhdwhy,Ogvn', 0.0), ('Tknuovn,Vggvjo', 0.0)]
# [('Hrksrl,Xn', 1.0), ('Xsnnqs,Bzilxzbci', 1.0), ('Ctqcoltmidow,Gr', 0.5), ('Zxjlyc,Xoudmebh', 1.0)]
# [('Jqmcrjxzg,D', 0.5), ('Eblnojlvr,Xhqj', 0.0), ('Akzzoopnxob,Xzenb', 0.5), ('Tjwsguocgu,Qhkjbbe', 1.0)]
# [('Rbtbwuxqbky,Hlvt', 1.0), ('Nfuufstv,F', 1.0), ('Ulralojoaycv,Pdklppj', 0.5), ('Gjwyeex,Pqtbacnt', 1.0)]
# [('Vhpticgh,Jvqrkh', 1.0), ('Uyixktfcy,Bww', 0.0), ('Ioelqumnpqr,Eykqbimyz', 0.0), ('Ktpbqnks,Ehkpjmiu', 0.5)]
# [('Idbclwun,Hm', 0.0), ('Svntfofsaic,Jcpsdhj', 1.0), ('Abzzat,Jpocvmv', 0.5), ('Xmzxsjdbxxeqn,Jyzhutz', 1.0)]
# [('Ectdpdpw,Bjva', 1.0), ('Yudhzhvpcwee,G', 0.0), ('Xcedkaz,Cgierm', 1.0), ('Xdyqvq,Rt', 1.0)]
# [('Haslskgsnlkm,Knfl', 0.5), ('Rtvpkivqhnqh,Jmedlu', 0.0), ('Gaxnjlsit,Vpcuadich', 0.5), ('Uqzaeaoonwhm,X', 0.5)]
# [('Szotlxlzngbk,Tizauly', 1.0), ('Dxryrfugveeo,Xhtrybx', 0.0), ('Zpmsysjuvsb,R', 0.5), ('Nqzqorpdbdbw,Dcpurv', 0.5)]
# [('Zdugbqu,Qoaiotg', 1.0), ('Zkeuwozac,Hfx', 1.0), ('Pixldlxj,U', 0.0), ('Jvksnwzplzhh,E', 0.5)]
# [('Trnvgpkfptvb,Ins', 1.0), ('Qfbokmzk,Wre', 0.5), ('Ocidiaalewmh,G', 0.5), ('Ochkiiiloav,Zumhobu', 0.0)]
# [('Tbiztswezvs,Fj', 0.5), ('Nsduvcgmewn,Fohmphw', 1.0), ('Ursxujud,Myf', 1.0), ('Ztdewvcxws,Yufat', 1.0)]
# [('Sjgkgdqyn,Hkmhwl', 0.0), ('Gfhnckcq,Puxhfo', 0.0), ('Pcyqypmo,Bwtqbqzhn', 0.5), ('Dtzsegra,Qdaogrmoe', 1.0)]
# [('Gkrhfp,Otzkpvgue', 0.5), ('Crvjmnb,Zntbqjfm', 1.0), ('Koamfkhsfyej,K', 0.5), ('Wbbjeb,Y', 0.0)]
# [('Btyygweieu,U', 0.0), ('Yygdgwhzmwyr,Aywkhybw', 1.0), ('Kyjxcrbj,Fynvleec', 0.0), ('Bdbwrk,Cinw', 0.0)]
# [('Qzchikutiva,Rjmw', 1.0), ('Qfaxxfvbsrmkc,Mlmwe', 0.0), ('Eswfcvkzrecb,Q', 1.0), ('Cfocou,Hk', 0.0)]
# [('Enssymkxwkxrp,O', 0.5), ('Rdzewxwzemvii,Dngo', 0.5), ('Kxlyigxphq,Ocggmujud', 0.0), ('Ouypaisagwbx,Zgxsjmrd', 1.0)]
# [('Cjrsuse,Rrsnycazq', 0.0), ('Egwvpivbsnnvf,Dvjscbtf', 0.0), ('Csyuvzaxjd,Vwr', 0.0), ('Fycpocqnfhcu,Ehcisx', 0.0)]
# ...
# [('Brzphu,F', 1.0), ('Tymaesozg,Vx', 0.0), ('Eilgti,Yfvt', 0.0), ('Brecrqvecayrc,Vy', 0.5)]
# [('Xqpyepdkwcwdt,Nbbih', 0.5), ('Nlwlxxgup,X', 1.0), ('Jrfduqmdycr,Hirw', 0.0), ('Vqzjrjrsd,Ec', 1.0)]
# [('Abjehpbc,Rbhsyq', 0.0), ('Bhqswidhxc,Se', 1.0), ('Wxfelhtkncpt,Ikxhhoevc', 1.0), ('Mwwyouaeuwmd,Gtoxvgowj', 1.0)]
# [('Uvwtyoznhy,O', 0.5), ('Lqpfwaxas,Md', 0.0), ('Bxfpbkas,Rgxecygbu', 1.0), ('Ylnanpnfihwp,Nid', 1.0)]
# [('Nrtjwlpvs,Gtcnn', 0.0), ('Dsjnrstwdh,Nmqwyt', 0.5), ('Nkefuxbyyic,Tp', 1.0), ('Ktgqsagris,Akavsgzn', 0.0)]
# [('Aaccul,Jbbl', 0.0), ('Sliqzvngmaq,Enrqsa', 1.0), ('Xkvgbxau,X', 0.5), ('Fytklvqapkm,Eluikpk', 0.0)]
# [('Wrrfzaqxo,Mbu', 1.0), ('Ptiyoh,K', 0.5), ('Xfjuin,Zevgmhtc', 1.0), ('Lrwtvwhfibc,Meuv', 0.0)]
# [('Frnadhkkouzz,Obxvcz', 1.0), ('Umyyuhbfjdp,Skecfrr', 0.0), ('Qcdcqkkoevl,Fpeq', 1.0), ('Ddhvxufdkn,Esmz', 1.0)]
# [('Zukhqvwqeh,R', 0.0), ('Wswbxgqe,Ic', 0.0), ('Odjjlp,Ms', 0.5), ('Hkichtxt,Sgte', 0.0)]
# [('Mpuksviekttl,Fgkuaogfy', 0.5), ('Qxztfio,Qmqvojhc', 0.0), ('Kfgyhhyfdl,Rfywtvwut', 0.0), ('Dkfiuimem,Nyatti', 0.0)]
# [('Bywbofgs,Titkkircc', 0.0), ('Scfynxydzz,Dxer', 0.0), ('Jaevvyrzfk,Ivzwb', 0.0), ('Rwpvpato,Lnwdrlks', 0.5)]
# [('Cpfhqfo,Grouitrjg', 1.0), ('Xgtvrtrnik,Ncemugfc', 0.5), ('Uxxbdorytpuib,D', 0.0), ('Musprtgei,Ga', 0.0)]
# [('Enfqzthk,Snvbwxuoa', 1.0), ('Ybnsjyld,Zkjskw', 0.0), ('Waexdcemp,Isikpcktk', 0.0), ('Gxisklbya,Mjtmecte', 1.0)]
# [('Bhluat,Auzvirit', 1.0), ('Yxxenu,Nwgycjv', 0.0), ('Ieiesiiqoffqu,Awt', 0.5), ('Hiqadncm,Koubspk', 0.0)]
# [('Mpnlbf,Wi', 1.0), ('Anillyhi,Ooega', 1.0), ('Bmicmjcnionf,Mvuuhfpm', 1.0), ('Oypvjuljpj,Gjg', 1.0)]
# [('Llmwozuvgvjx,Qmicpzsti', 1.0), ('Shgwrrg,Bflgqcn', 0.5), ('Mkjitfziivliz,Oq', 0.0), ('Jynafng,Xtqytlqc', 0.5)]
# [('Zewjcai,Zawou', 1.0), ('Zplnzhgkwyr,Xl', 1.0), ('Djjzjhzbb,Zgnnmem', 1.0), ('Vlpobwrvljpx,Kppebank', 0.0)]
# [('Nqctqympxyj,Uyg', 0.0), ('Ibqcgtgoogqs,Ranyghvg', 1.0), ('Tclbtvdwid,Xiney', 1.0), ('Ldbrxhc,Hkmoibud', 1.0)]
# [('Avdgotosp,Atrjpq', 0.5), ('Ukhqxtier,Wzudwu', 0.5), ('Jfjzyaojas,Hhgxf', 0.5), ('Susxdllcjcey,Bmaqdz', 1.0)]
# [('Hisnfweoppq,Jlrnuqb', 0.5), ('Cmlcomlkeoia,Ak', 1.0), ('Dlgspdcbekxqj,Hyofipvnq', 1.0), ('Bxfhenoa,Nxbvz', 0.5)]
# [('Kiwudolyo,Ejg', 1.0), ('Empltxmiap,Lnj', 0.0), ('Elogwqgflp,Acdi', 0.0), ('Gyzlpacmetzap,Rdzvxd', 0.0)]
# [('Jfrptneebbv,D', 0.0), ('Tvkyjwzf,Pgmvpegkd', 1.0), ('Dchqpyjbphc,Ybv', 0.5), ('Teepcflpxe,Ngyhhy', 0.5)]
# [('Oshzbnk,W', 1.0), ('Fmghjyepsy,Icnilyiq', 0.5), ('Diuylbubgcfxq,Vmhxkeb', 0.0), ('Ixzzewmbyih,Rbbl', 0.5)]
# [('Hpcapmq,Sah', 0.0), ('Xxubrhdis,Zd', 0.5), ('Wfrcoelgk,Gjwwhqc', 0.5), ('Aathzvbjkgz,Oknxxqx', 1.0)]
# [('Cvmcugg,X', 0.5), ('Fnyiujihdgwo,Eovvyijmc', 0.5), ('Paysin,Ovki', 0.0), ('Tnswgwfzvxg,Syzjlwakk', 1.0)]
# [('Nkkiyemubasf,Ddtuefths', 0.5), ('Ibrqblno,L', 0.0), ('Racrqphjslev,Ljposxbcy', 0.5), ('Tvulbhnnipjk,Vftoueqvs', 0.0)]
# [('Rgvywzl,E', 0.5), ('Hjpouek,Cqeltg', 0.0), ('Pjdkszzmxf,Xlo', 1.0), ('Eolrkawnxyrns,Gbjltjnh', 0.0)]
# [('Azxcoqfksis,Vhtbomoh', 0.5), ('Vhczduceypx,Dfck', 0.5), ('Igkmxoygxlrtz,Yyetbldbi', 1.0), ('Xbgyolsdwsrh,Pauas', 1.0)]
# [('Gykvyivwyut,Txoxhkifw', 0.0), ('Lixucnm,Wklymhc', 0.0), ('Hhpeccpauf,Cjncu', 0.0), ('Rfrdhoincnycz,Imbww', 1.0)]
# [('Mljytlalf,Pcfrygn', 1.0), ('Umdsbfmocd,Lsmab', 0.0), ('Tchkwoxxq,Lmlqcynha', 0.0), ('Lpuqgd,Rmgsbt', 0.5)]
# [('Vbxuva,Rabz', 0.5), ('Lfmbyooxh,Radcmydz', 1.0), ('Quglyrk,Fhbln', 0.0), ('Jsdkghm,Rwrijpgg', 0.5)]
# [('Hexfiqyje,Yzuvskwbe', 1.0), ('Pzowss,Qalae', 0.0), ('Epswtyqnl,Zsi', 1.0), ('Wtyctbfk,Oqoxly', 1.0)]
# [('Pdiactnuitdk,Tq', 1.0), ('Cwpuafhq,Guovqzqf', 1.0), ('Dyahcbrtx,Ku', 1.0), ('Gctjind,Mvtsaccoe', 1.0)]
# [('Guczrlfbcnp,Fmkdjl', 0.0), ('Znrjufafkjf,Ug', 0.0), ('Kquspxsmr,Gxgl', 0.5), ('Ehpahxhdwktgd,Yjpbgwiei', 0.0)]
# [('Nyzwcxns,Nldpzwtf', 0.0), ('Dduzhl,Pvzpm', 0.5), ('Mkzjtcldcyh,Djz', 1.0), ('Pdjvdzi,M', 1.0)]
# [('Zclehisgxqo,Snuwcfd', 0.0), ('Slrpzymra,T', 1.0), ('Tqqsdgpo,Cqahgntd', 0.5), ('Qgxtmxeooayt,Dqqqymum', 1.0)]
# [('Iwcixp,Kycamj', 1.0), ('Epsbtotles,Rdjaegmgl', 0.0), ('Louforfjsguh,Iteqolbd', 1.0), ('Fdhqzfwaqzkw,S', 0.5)]
# [('Zxxtdavycaxz,A', 0.5), ('Cmzumnhzzae,Fxzb', 1.0), ('Ibjjbvar,Zlskx', 1.0), ('Eymyvxjtlnml,Etnpt', 0.5)]
# [('Hwargilmll,Joa', 0.5), ('Rkkivyqjinb,Jwltl', 1.0), ('Nllvbjunyf,J', 0.0), ('Dryaawuyi,Ovwaxacpo', 1.0)]
# [('Ipeanql,Wy', 1.0), ('Ffcjesm,Dayzokg', 1.0), ('Vhuyyhcdomppw,Wf', 0.0), ('Gicqqsuacfj,Wed', 1.0)]
# [('Qshsrzpmapj,D', 1.0), ('Mkzzsq,Lgu', 0.0), ('Gxfzdibcyjucu,Ifdihj', 1.0), ('Rnvlnts,Njvwgohif', 1.0)]
# [('Cwckohbzied,Z', 0.5), ('Lxhnma,Efkzth', 1.0), ('Xkhxjhxi,Uxcxd', 0.0), ('Jdyrxzl,Nwwl', 1.0)]
# [('Qrmvapao,Swfjdzzwu', 0.0), ('Jlwoau,Jbmmnhqrc', 0.0), ('Coexnaahvzv,Pil', 1.0), ('Xcsycalpldvc,Ickuacxk', 0.0)]
# [('Zgghwct,Kl', 0.5), ('Qbvhmkrz,Qjioszhl', 0.5), ('Gswxsrqhzlxk,N', 0.0), ('Wqplmmywtvpn,Abqdbovl', 1.0)]
# [('Mqqvvq,Hgl', 1.0), ('Wdptyq,Ubbzfvblh', 1.0), ('Sbdvctbc,Dqcdeyoe', 0.5), ('Jzefcvuh,Rajttvzth', 0.5)]
# [('Aamznyfs,Xso', 0.0), ('Ypiwzydotazdg,O', 1.0), ('Vpopbn,H', 0.0), ('Ckgbtezku,Laghcyfhr', 0.5)]
# [('Vnsztg,Sbpr', 0.5), ('Tdseudntnzg,Mkcxsadjh', 1.0), ('Wkghbcvxx,F', 1.0), ('Myhthvzqkqox,Adsjdakw', 0.5)]
# [('Owvfnlblkvaay,Zazpbnn', 0.5), ('Dlnbxqtbk,Emabolpn', 1.0), ('Bbcvbmfgyd,Xvyif', 1.0), ('Ebiikdfuug,Kn', 1.0)]
# [('Uorotttnsa,Oenjgxw', 0.5), ('Uupjax,Jajf', 1.0), ('Maccoelukebd,Ilfzxa', 0.5), ('Hytfuzyzknrvu,Fmycn', 0.5)]
# [('Nhkjpuhanhkl,Ggeb', 0.0), ('Xjhflrynwrd,E', 0.5), ('Wiwiaeuw,Woauw', 0.0), ('Pscjrgpahkspo,Wmfb', 0.0)]
# [('Xninarblqfwc,Sh', 0.5), ('Zeuaovghj,Pjqzj', 0.5), ('Uwgpazuirxd,Revltyy', 0.0), ('Hoexbemfq,Tezvb', 0.5)]
# [('Guuhwrowe,Raau', 1.0), ('Cgssrelsr,Qnbczwvw', 0.5), ('Lyocgixlxkz,Tqipwys', 1.0), ('Clmzndaoh,Zwwhvc', 0.0)]
# [('Xlyuwsjvq,Bgct', 0.0), ('Mjtviwhq,Qekh', 1.0), ('Vccupdpejwgzy,Atr', 1.0), ('Rpcretsegqpi,Ypqexouvs', 0.5)]
# [('Aeimpsryv,Nrgyodmvr', 0.5), ('Tbwavn,Yfhfvsm', 0.5), ('Tcqvvcbmfqfeu,Gwthltpp', 0.0), ('Haflwv,Bovrpmie', 0.0)]
# [('Quulwvu,Iipdqgfjh', 0.0), ('Wwbkbhyn,Zjoukiajv', 1.0), ('Qavswj,Lnr', 0.0), ('Vawwfhksvfeuy,Kqkihcxe', 0.0)]
# [('Mkttvxpsoxys,Wgmq', 1.0), ('Mnguewm,Dre', 0.5), ('Pgvmfox,R', 1.0), ('Ofeufd,Ebgtc', 1.0)]
# [('Jygydglybfofi,Yumjuztcr', 0.0), ('Playcmjbo,Mzsisx', 0.0), ('Cymhreszf,Pazhjatx', 0.0), ('Vrzfpn,Uuhbkutf', 1.0)]
# [('Dtzhdks,Ihqa', 0.5), ('Rmmkvy,Zxcsogt', 0.5), ('Iurqicohnya,Meoja', 0.5), ('Xnrmppgtlt,Akar', 1.0)]
# [('Hqdqpitfn,Ypdu', 1.0), ('Ccyjdkhk,Ixizkgvfi', 0.5), ('Fqollzeqrvuz,Sjitszf', 1.0), ('Qsztxq,Qi', 1.0)]
# [('Bwpimbjyg,Tpxwc', 1.0), ('Acxmqyoq,Y', 0.0), ('Csuclllua,N', 0.5), ('Xdpgfxwlz,Lmdr', 0.0)]
# [('Opeozbzk,Fkgqp', 1.0), ('Noowqf,Zmeeuxlpq', 0.0), ('Kyvyghmyhfko,Whzmr', 0.5), ('Hwlbfaqw,Jqqrd', 1.0)]
# [('Ckskhmvheqwp,Jbe', 0.0), ('Rcbqjmqslw,Sybw', 1.0), ('Nnxnzljfmyikx,Vv', 0.0), ('Yxsdcmpxfi,Xrvotyram', 1.0)]
# [('Zcuecwdkfa,Peybnm', 0.0), ('Sumwoer,Dbvbl', 0.5), ('Gdafokiloig,Khoab', 0.0), ('Bqyglmxtodho,Usjlfawh', 1.0)]
# [('Fjnaubbvcpiia,Tu', 0.0), ('Kjcolejh,Xnfumz', 0.0), ('Bawqebvq,Zcig', 0.5), ('Mqzbluznraah,Y', 1.0)]
# [('Eprpvjsbu,Xb', 0.0), ('Tacgsivs,Tvczplmn', 1.0), ('Qwfyqwzlpt,Gxsjb', 0.5), ('Lgdwagcxshrwx,Kf', 1.0)]
# [('Sqwkbjjgxrw,Ljgbcyr', 1.0), ('Dtjhelr,Cnpxgdjoi', 0.5), ('Alrsvcspahoo,Btvrn', 1.0), ('Yuryqwltcu,Oswhcnn', 0.0)]
# [('Ysrezptzktjaz,Ubherrppf', 1.0), ('Huvtndmyisfh,Roohd', 1.0), ('Smuhaedaxgt,M', 0.5), ('Pkubfqmcphj,Fkvuiwm', 0.0)]
# [('Hnorhwlu,Fdk', 0.0), ('Cpfsdksrmpodz,Ikyjoxy', 0.0), ('Gleljmtp,Hnmybopkq', 0.5), ('Haplwklmpt,Nhbie', 0.0)]
# [('Xhwwwarczc,I', 1.0), ('Dttccqzqevwrk,Nk', 0.0), ('Airkkuzbojvm,Szuhtrba', 0.0), ('Stzalqnmzqoez,Hmrfym', 1.0)]
# [('Lbutocstocct,Wavnfb', 0.5), ('Dqjsyjfxd,Nhttgucj', 0.0), ('Bfzpjiqy,Zakuits', 1.0), ('Ytnljvehmolnw,Px', 0.0)]
# [('Qjkhsl,Puvejyapd', 1.0), ('Qbqmesvautppy,Eyanuby', 1.0), ('Nqeetlsvclyjj,Ph', 1.0), ('Poholkfqcpbc,Wnzzuhb', 1.0)]
# [('Lgkyqmbkd,Zdnvuj', 1.0), ('Bywwyvcmifd,Ffrxx', 1.0), ('Tokgppgxvbd,D', 0.5), ('Dcbocfjr,Ztvckkfh', 0.0)]
# [('Ivwnla,Dug', 0.5), ('Rhijlcogz,I', 1.0), ('Ovpxxf,Xrwxea', 0.5), ('Fiqvfwsnhhtqa,Mnqorwnu', 1.0)]
# [('Rhcusida,R', 0.0), ('Iigmsemjiq,Lqjuhuia', 0.5), ('Bqvzzkrshxidq,Agwibfgp', 0.0), ('Xjdgjgw,Hshqbdsh', 0.0)]
# [('Cywhesrlq,Zeuucvhy', 0.0), ('Dvmobinuvmrnc,Anc', 0.5), ('Ckldudljrjfvz,Tglma', 0.0), ('Tmzilcvyjb,Zqsobqiz', 1.0)]
# [('Baneavwxxzgq,Kpwxp', 0.5), ('Uyzpocgbazcnr,Akadxi', 0.0), ('Fqsrspjtmupnw,Ptzdz', 1.0), ('Ibkkwahiwtisi,Z', 0.5)]
# [('Sflwdwp,Lkeqkb', 0.0), ('Oildwumt,Tdvkcoaw', 1.0), ('Weprfhfuag,Mzdhmrvo', 0.0), ('Lbpuqi,Nisxworpb', 0.5)]
# [('Avfmidnxoob,Skwtjzjkz', 0.0), ('Ogmvzjbwv,Yvlas', 0.5), ('Cieoxazjuj,Puwb', 0.5), ('Ebabxrpenlwr,J', 0.0)]
# [('Yyjjusyzymo,Hi', 0.0), ('Rfzbox,Bajx', 0.0), ('Wcnwtdpbvi,Fvgsdhh', 1.0), ('Gyphiqyzvt,Xevgorw', 0.5)]
# [('Jaxuwjiu,Easu', 0.5), ('Safovshvtzj,Cncal', 1.0), ('Xtystr,S', 0.5), ('Prdsxztdadt,Ntrppac', 0.0)]
# [('Tdiyrda,Dpjgxriv', 0.5), ('Bszdsni,Yt', 0.0), ('Nczxaw,Yswjj', 0.5), ('Kewoyjjiveadw,Ywzytdwxz', 0.5)]
# [('Vbxpfb,S', 0.5), ('Ccctntwgmattv,R', 0.5), ('Lkfxqp,Xu', 0.5), ('Wxfhugo,Boavvoef', 0.5)]
# [('Xlpyxulnk,Dvdlteg', 0.5), ('Mytqqqmiakf,Jttpgdqrz', 0.0), ('Dpcfpju,Ijhn', 1.0), ('Bkndhnjzqcaaq,Douhviez', 0.5)]
# [('Atsxrcldixlt,Oehbv', 0.0), ('Bawtazvmh,Sqtjfqc', 0.0), ('Wtolqhtjv,Utuuamb', 0.5), ('Tyjapgj,Vykdee', 0.0)]
# [('Jjnhzfsrhqky,Tts', 0.0), ('Csrhmskgjfehg,Aexwjff', 1.0), ('Apnwwtcvpcqkj,Eximz', 0.5), ('Dqghlubzb,Yc', 0.5)]
# [('Ebkikoywjfck,Vypaz', 1.0), ('Mnumklrgj,V', 1.0), ('Ipudfhmsx,Embb', 1.0), ('Uzycbefipsce,Dzkjbrh', 1.0)]
# [('Afsycwe,K', 0.0), ('Fvwqtxpdgymym,Gpjuixva', 0.0), ('Holgvsukbvmow,Jcgag', 1.0), ('Kiqbmpksfzh,Ntzxjkbw', 1.0)]
# [('Gvurwhcismn,Urzzbu', 0.5), ('Jygnkscchqbt,Uvbwlx', 0.5), ('Ophfrqlprzz,Iqf', 1.0), ('Ijjbns,Cexsme', 0.0)]
# [('Ohnilmpxnym,Jiu', 0.0), ('Fczoyxhbog,Sqki', 1.0), ('Yyrjqmdoa,Ecdf', 0.5), ('Mengmyirk,Ilbmsnl', 0.0)]
# [('Wqbnrzkqev,Wwv', 0.5), ('Ocegsu,Aka', 0.5), ('Ydxtxwsv,Rkkll', 0.5), ('Kbxvgcf,Hvq', 1.0)]
# [('Ugqckmmnizudc,Hkzpdbbq', 1.0), ('Qpzslavt,G', 1.0), ('Fzplnmrqtodz,Xwdb', 0.5), ('Xkstzpekxhuh,Sp', 0.5)]
# [('Placcczmlwquu,Xzm', 0.0), ('Ntqdmlrebh,Aqa', 0.5), ('Vsdndotvn,Dw', 0.5), ('Pihloxwqo,Qzthqifq', 1.0)]
# [('Kzdmvkpizs,Zk', 0.5), ('Ckfezxw,T', 0.5), ('Adaxotuydphy,Myh', 0.0), ('Vumsvkomligrz,Zrvitkbcu', 1.0)]
# [('Btmkms,R', 0.0), ('Vjddbwogwrrme,Fjryktza', 0.0), ('Qtitepmiau,Xpfsy', 1.0), ('Jekfir,Ue', 0.0)]
# [('Keaqpzfjp,Gpeyf', 0.0), ('Eyrppjlwgxny,B', 1.0), ('Ewqrfgsrrfvjy,Mscciar', 1.0), ('Cnjxvkmx,Zgsenli', 0.5)]
# [('Xkvrbteghbhi,Fctlbzpua', 1.0), ('Cqcwfi,Coeym', 0.5), ('Vzckepvqbymj,Tecxppxkm', 0.5), ('Stdvdfj,Kdym', 0.5)]
# [('Khleospkf,Wcnook', 0.5), ('Alzvextzl,Sl', 0.0), ('Ghepcoyxnr,U', 0.0), ('Sebdlirbrpdc,Txmfggpa', 1.0)]
# [('Qydogeerl,Dvcj', 1.0), ('Isdizii,Iamxyqq', 0.0), ('Lfuexqrhrx,Dv', 0.0), ('Dhlrha,Kwwy', 1.0)]
# [('Mtceeaqqktyh,Lxtkt', 1.0), ('Exqsujiiv,Cms', 1.0), ('Hsaajoetlbxid,Npnycy', 0.5), ('Gidonsdps,Mztxhq', 0.0)]
# [('Kwgcjfgpo,Uiwi', 0.5), ('Hoylazdnlnz,Mqotcop', 0.5), ('Zezlfbwvbyh,Yzyjqkf', 1.0), ('Byhacvmvmn,Cvumvjxx', 0.0)]
# [('Zyqkbovbzltz,Ymv', 0.0), ('Ythspyrc,Itndvrnnx', 0.5), ('Rfpeggbvknpj,Pkzlyopex', 0.0), ('Mlfmqegkzq,Dtvh', 0.0)]
# [('Zwsmansaqab,Pnxgermjr', 0.0), ('Znlqznoohpvrf,Ctsoayvm', 1.0), ('Xvnkbawqy,Qyicvot', 0.0), ('Mwfpzotxzq,Mylhd', 0.0)]
# [('Ohcvvdzbs,Llsis', 0.5), ('Ioxsbvdov,Hhhtgxq', 0.5), ('Bvujucozfr,Hipmqf', 0.0), ('Mrmumlyaxurjj,Jhymj', 1.0)]
# [('Ojqgwtnoma,Mp', 0.0), ('Aaspkvveltxtn,Ovcuyla', 0.5), ('Ntokxhkr,Pswaku', 0.5), ('Vbnnfns,Ecosvffu', 0.5)]
# [('Nrqnxq,Ryarxy', 0.5), ('Odviykbofoarl,Kpagz', 0.0), ('Jzzrsn,Dakkdart', 1.0), ('Mvbxwsgta,Xdh', 1.0)]
# [('Fuyhjqphv,Cqcnyam', 1.0), ('Hsmftykjm,Ewljwhtki', 0.0), ('Exazdwk,Ghfxritg', 0.5), ('Klvaunnhfj,Sq', 1.0)]
# [('Zqsnldew,Sigfxsb', 0.0), ('Tqfxwlpqylgbs,E', 0.0), ('Mkcfwcy,M', 0.5), ('Jqbdchnzfow,Evcmezfmq', 0.5)]
# [('Ryyjvbymwjwwa,Vufvopkl', 0.5), ('Tsqpqpxbdwl,Zqbcbdt', 1.0), ('Ritjiibamqlnz,Kwru', 1.0), ('Qpqbktozeintg,F', 1.0)]
# [('Cmcsumevq,Eamamkazp', 1.0), ('Askaiccamuji,Iewwy', 0.5), ('Fglcyh,Tthm', 1.0), ('Nvvbhynw,Pfmxzrwni', 0.0)]
# [('Cubdwhnflremm,Nnawjlgtt', 0.5), ('Eenvxnlwfgmdc,Wpzjx', 1.0), ('Bvcjzmt,Wchjpifsj', 0.5), ('Rehetyyb,Isoafwdix', 0.0)]
# [('Ttbigfcubhj,Qvqlr', 0.5), ('Urwebmcc,Mpmmweqqh', 0.5), ('Cwufewezxup,Ecvs', 1.0), ('Ybbyqdwokdyos,Ahahinjlo', 0.0)]
# [('Mqtgmnltgb,Jla', 0.0), ('Uxhvxytos,Ywau', 0.0), ('Dbebhcve,Rtvrgoc', 0.5), ('Kltxzhkex,G', 0.0)]
# [('Xsvbkxmca,Cftntsewv', 1.0), ('Osnqiiaovxvrr,Ppkvcj', 0.0), ('Jpacdscv,Dsstuzm', 1.0), ('Axlhwgzv,Famklozg', 1.0)]
# [('Htkzaikxsu,Cv', 0.5), ('Xvhzamzcs,Dclnjt', 0.0), ('Llwemaav,Myya', 0.5), ('Lndlvgxyobsvr,Ecqoxv', 0.5)]
# [('Vzdrhd,Cijwzadgj', 0.5), ('Ninsmule,Libjvfqvm', 1.0), ('Zejofzhus,Aeekipqsw', 1.0), ('Svgpckhmuqm,Ioa', 1.0)]
# [('Qhvfjritt,Lbrl', 0.5), ('Jmvfrtwtpjwee,Yq', 1.0), ('Ulbefivp,Erb', 0.0), ('Trelvrmc,Wmr', 0.5)]
# [('Yufdkl,Cqghp', 0.0), ('Tgypoktrxq,Xojmdfvsg', 1.0), ('Brsymde,Gwuijbelm', 0.5), ('Rtclcbmmmlhqm,Obteizsde', 1.0)]
# [('Bowgrdnw,Jptpx', 0.5), ('Nsybuvpopjoma,Pgytozn', 0.0), ('Hmdpiwgx,Zlqgrt', 1.0), ('Fmxcitndtm,Upuh', 0.5)]
# [('Ptvptxnh,Itxafg', 1.0), ('Sdcebnfg,Xgwm', 0.0), ('Tnyyavpdtxiij,Hmjq', 1.0), ('Pwnroprcnku,Trwtze', 1.0)]
# [('Sxyrwoahqc,Mkldqftw', 0.0), ('Mjljnxpuwcxp,Qt', 0.5), ('Xcfcddqv,Xleznxow', 1.0), ('Qymzux,Envenn', 1.0)]
# [('Nyrljrkr,Nkzpm', 0.0), ('Uhdkbzck,Kesskobsr', 0.5), ('Opmxqnvdrjyv,Qnqhgey', 0.0), ('Ulwkczykauo,N', 0.5)]
# [('Zzitiqokmgwca,Zjgbzlte', 0.0), ('Nwnyyvoygaic,Gjvyxd', 0.0), ('Lmwqtovxrljo,Javk', 1.0), ('Xncjrvidih,Mqedwwu', 1.0)]
# [('Fdvcsat,Dhkhrok', 0.5), ('Elimcrdypejw,Hmnrl', 1.0), ('Yiqnir,Bnqoclo', 1.0), ('Cblnfbcllbxa,Vcor', 0.5)]
# [('Stjzgqoufthe,Teemocto', 0.0), ('Fudaji,Lzcsckis', 0.0), ('Jffrxcohf,Ekw', 0.0), ('Ovdttvmlujie,Qgiybij', 0.0)]
# [('Hxulwbowxcniz,Tkbocg', 0.0), ('Aevmrmp,Atmtxb', 1.0), ('Jqzjvx,G', 0.5), ('Eztioyiqge,J', 1.0)]
# [('Krjttoxcfxml,N', 1.0), ('Vnodmrblpjqi,Duz', 1.0), ('Jsedjc,Smdbiy', 0.5), ('Gmzpdrlprufqr,Yhbcc', 0.0)]
# [('Jhqekrmthcc,I', 1.0), ('Fnvuieg,Wgtuzggnp', 1.0), ('Romvixewe,Kgcubhey', 0.5), ('Blacoyo,Kibqd', 1.0)]
# [('Vzowpfcpdduhl,Beefmb', 0.5), ('Rebckuklgthny,Lw', 1.0), ('Rmxxfzdzhnkgv,Pi', 1.0), ('Nenokdetudtue,Cowhhwrsu', 0.5)]
# [('Wnywbdccsrdn,Zxodaeu', 1.0), ('Iauubeunpzqu,Vtdyvp', 1.0), ('Gbmqdshmogunn,Caeieixl', 0.5), ('Laddze,V', 1.0)]
# [('Hdulxysdoezld,Yitsogl', 1.0), ('Dybsdmjexksci,Wr', 0.0), ('Chxlhkbj,Cksaldix', 0.5), ('Hzhdsbbeuw,Tjayy', 0.5)]
# [('Qzvnkwycdocjp,Mhec', 0.5), ('Trxqvujqssie,Rf', 0.5), ('Savwhstsib,E', 0.0), ('Hxeobyt,Shvrumxry', 1.0)]
# [('Gpmumq,Tazmrmu', 1.0), ('Cgqazfinbml,Uyxeon', 0.0), ('Rnsxkqhw,Arlhterv', 1.0), ('Mbrdkwibjtbv,Mqvs', 0.0)]
# [('Lhbjmvyxok,R', 1.0), ('Xrkjznzirlawl,Ciwisovjr', 1.0), ('Kuwqnpnctry,Ycoxrwsg', 0.5), ('Bstzisogn,Ekrjxzsad', 1.0)]
# [('Pngupgyvj,Ttap', 1.0), ('Hnkaqudnesl,Hgaljcs', 1.0), ('Jvhcjjazyar,Ovm', 0.0), ('Isgsvexxvjsve,Dsuvmpzj', 0.0)]
# [('Bknemt,F', 0.0), ('Wcnivpqdj,Wfgyj', 0.0), ('Vmwjnimmria,Vsuarmpjy', 0.5), ('Iojpylmmn,Kxyvgei', 1.0)]
# [('Ujwpfmooglr,Vjbvq', 1.0), ('Nvyumcglp,Pmp', 0.5), ('Ljlwjofnpik,Vqumy', 1.0), ('Ffiwipesy,Gyceo', 0.0)]
# [('Zzajbokjpaqj,Bxhsprmf', 0.0), ('Bdoevkchpbm,Dtqeztxdc', 0.0), ('Nruyrsyb,Gtn', 1.0), ('Prandjnklx,Xx', 0.0)]
# [('Tpuhob,Yosolm', 1.0), ('Agguystjmp,Yffmnhmq', 1.0), ('Npgbhag,Yjuxbbowj', 1.0), ('Pwrdwdepu,Nsjhym', 1.0)]
# [('Zqvgbpi,Dqmyupcfs', 0.0), ('Szrablmt,Gbzy', 0.0), ('Amnzdkxicrtx,J', 1.0), ('Lyrvkjbawsw,Pmurokzpe', 0.5)]
# [('Dxqverto,Bxduh', 0.0), ('Pletrddttjs,Mb', 0.0), ('Gkxhphc,Ut', 1.0), ('Voncbqrnrz,Wjrcnpxx', 0.0)]
# [('Dgxnibt,Djprgw', 1.0), ('Hpzxtbkvvzq,Y', 0.5), ('Tzaztzzh,M', 0.0), ('Ivgebdnt,Hy', 0.5)]
# [('Lcpcszmsnv,M', 0.0), ('Misclfqpvhnwf,N', 0.5), ('Iozgldvcin,A', 0.0), ('Njqpvx,Mtvckvmvg', 0.5)]
# [('Bpmoiptwiu,Vtvg', 1.0), ('Jhbzyqzdo,Yvmbzwgs', 0.0), ('Pxykyu,Saunw', 1.0), ('Gmswrh,Uwbhj', 0.0)]
# [('Lxvkxmipxan,Zynrfryvm', 0.5), ('Vxtgbqr,Zmlt', 0.0), ('Qtlvypfsqkxtb,Vosxsvczd', 0.0), ('Mfyzgtndy,Vi', 0.0)]
# [('Oiydxxsn,Jx', 1.0), ('Odkjmhlyftfwb,Mfjntz', 0.5), ('Xxixbseuldh,Tqj', 1.0), ('Iikjvp,Ifljke', 0.0)]
# [('Filofa,Gcl', 0.5), ('Bsvucttmqy,U', 0.5), ('Hgodafr,Tuadkvvc', 0.5), ('Jdaymwignq,Ykhzxx', 0.5)]
# Passed!
# '79.5 MiB'

# %% [markdown]
# **Run the following cell, even if you skipped Exercise 2.**
#
# We are loading a pre-computed solution that will be used in the following sections. The first two entries are displayed.

# %%
# Sample result for ex2
player_scores = test_utils.read_pickle('player_scores')
{k:v for k, v in list(player_scores.items())[:2]}
# Out:
# {'Deac,Bogdan-Daniel': 4.0, 'Giri,A': 4.0}

# %% [markdown]
# ## Exercise 3 (2 points)
#
# Our next task is to extract the Elo rating of each player from the metadata.
#
# Fill in the function `extract_ratings(games)` to satisfy the following requirements:
#
# Given a list of dictionaries, `games`, create a dictionary `player_ratings` that maps each player to their Elo rating before the tournament. You can assume that each dictionary in `games` will have the following keys and value types: `'white_player'`: (String), `'black_player'`: (String), `'white_rating'`: (Integer), and `'black_rating'`: (Integer).
#
# Additionally, if the same player has different ratings in the input, your function should raise a `ValueError`.
#
# For example:
#
# Input : `[{'white_player': 'Jim Halpert', 'black_player': 'Darryl Philbin', 'white_rating': 1600, 'black_rating': 1800}, {'white_player': 'Darryl Philbin', 'black_player': 'Phyllis Vance', 'white_rating': 1800, 'black_rating': 1700}]`
#
# Output : `{'Darryl Philbin': 1800, 'Jim Halpert': 1600, 'Phyllis Vance': 1700}`
#
# Input : `[{'white_player': 'Jim Halpert', 'black_player': 'Darryl Philbin', 'white_rating': 1600, 'black_rating': 1800}, {'white_player': 'Darryl Philbin', 'black_player': 'Phyllis Vance', 'white_rating': 1850, 'black_rating': 1700}]`
#
# Here `'Darryl Philbin'` has two ratings: 1800 in his first game and 1850 in his second. Your function should raise a `ValueError`!

# %%
demo_metadata_good = [{'white_player': 'Jim Halpert', 'black_player': 'Darryl Philbin', 'white_rating': 1600, 'black_rating': 1800}, {'white_player': 'Darryl Philbin', 'black_player': 'Phyllis Vance', 'white_rating': 1800, 'black_rating': 1700}]
demo_metadata_bad = [{'white_player': 'Jim Halpert', 'black_player': 'Darryl Philbin', 'white_rating': 1600, 'black_rating': 1800}, {'white_player': 'Darryl Philbin', 'black_player': 'Phyllis Vance', 'white_rating': 1850, 'black_rating': 1700}]

# %%
def extract_ratings(games):
    ###
    from collections import defaultdict
    ratings = defaultdict(set)
    finalOutput = defaultdict(int)

    for i in games:
        whitePlayer, blackPlayer = i['white_player'], i['black_player']
        whiteRating, blackRating = i['white_rating'], i['black_rating']
        ratings[whitePlayer].add(whiteRating)
        ratings[blackPlayer].add(blackRating)

    for keys in ratings:
        if len(ratings[keys]) != 1:
            raise ValueError
        else:
            finalOutput[keys] = ratings[keys].pop()

    return finalOutput
    ###

# Demo
try:
    extract_ratings(demo_metadata_bad)
    print('This should raise a ValueError')
except ValueError:
    print('Correctly raised ValueError')
extract_ratings(demo_metadata_good)
# Out:
# Correctly raised ValueError
# defaultdict(int,
#             {'Jim Halpert': 1600,
#              'Darryl Philbin': 1800,
#              'Phyllis Vance': 1700})

# %% [markdown]
# The test cell below runs your function **many times**. Remove or comment out any `print` statements to avoid generating excessive output.

# %%
# `ex3_test`: Test cell
from run_tests import ex3_test
for _ in range(200):
    ex3_test(10, 4, extract_ratings)
print('Passed!')

###
### AUTOGRADER TEST - DO NOT REMOVE
###
# Out:
# Passed!

# %% [markdown]
# **Run the following cell, even if you skipped Exercise 3.**
#
# We are loading a pre-computed solution that will be used in the following sections. The first two entries are displayed.

# %%
# Sample result for ex3
player_ratings = test_utils.read_pickle('player_ratings')
{k:v for k, v in list(player_ratings.items())[:2]}
# Out:
# {'Deac,Bogdan-Daniel': 2627, 'Giri,A': 2780}

# %% [markdown]
# ## Exercise 4 (1 point)
#
# The last task before we begin analysis is to implement some functionality to calculate the expected result of a match based on the Elo ratings of each player.
#
# Fill out the function `expected_match_score(r_player, r_opponent)` to satisfy the following requirements:
#
# Given a player's rating (Integer) and their opponent's rating (Integer), compute the player's expected score in a game against that opponent. The formula for the expected score is:
#
# $$\text{Expected Score} =  \frac{1}{1 + 10^{d}}$$
# where
# $$d = \frac{r_{\text{opponent}} - r_{\text{player}}}{400}$$
#
# Output the expected score as a Float. **Do not round**.
#
# For example:
#
# `expected_match_score(1900, 1500)` should return about `0.909`
# `expected_match_score(1500, 1500)` should return about `0.5`
# `expected_match_score(1900, 1700)` should return about `0.76`

# %%
demo_ratings = [(1900, 1500), (1500, 1500), (1900, 1700)]

# %%
def expected_match_score(r_player, r_opponent):
    ###
    d = (r_opponent - r_player)/400
    expectedScore = 1/(1+10**d)
    return expectedScore
    ###

# Demo
for rp, ro in demo_ratings:
    print(f'expected_match_score({rp}, {ro}) = {expected_match_score(rp, ro)}')
# Out:
# expected_match_score(1900, 1500) = 0.9090909090909091
# expected_match_score(1500, 1500) = 0.5
# expected_match_score(1900, 1700) = 0.7597469266479578

# %% [markdown]
# The test cell below runs your function **many times**. Remove or comment out any `print` statements to avoid generating excessive output.

# %%
# `ex4_test`: Test cell
###
### AUTOGRADER TEST - DO NOT REMOVE
###
from run_tests import ex4_test
for _ in range(200):
    ex4_test(expected_match_score)
print('Passed!')

###
### AUTOGRADER TEST - DO NOT REMOVE
###
test_utils.get_mem_usage_str()
# Out:
# Passed!
# '79.5 MiB'

# %% [markdown]
# ## Aside - Functional Programming
#
# It is often useful to write functions which take other functions as arguments. Inside of your function, the functional argument is called in a consistent way. This allows the caller of your function to customize it's behavior.
#
# Here is an over-engineered arithmetic calculator as an example. These functions define mathematical operations.

# %%
# add
def a(a, b):
    return a+b
# subtract
def s(a, b):
    return a-b
# multiply
def m(a, b):
    return a*b
# divide
def d(a,b):
    return a/b

# %% [markdown]
# This function, `calc`, takes the two numbers as an argument and a third argument which determines how they are combined.

# %%
def calc(a, b, opp):
    return opp(a,b)

# %% [markdown]
# Now we can use any function that takes two arguments, like the 4 defined above to determine the behavior of `calc`.

# %%
calc(3,5,a)
# Out:
# 8

# %%
calc(3,5,d)
# Out:
# 0.6

# %% [markdown]
# # Exercise 5 (3 points)
#
# Our next task is to write some functionality to determine each player's expected tournament score.
#
# Fill in the function `expected_tournament_score(player_results, player_ratings, es_func)` to satisfy the following requirements:
#
# Given a dictionary, `player_results`, mapping players to their tournament results as a list of tuples (similar to the output from Exercise 1) and a dictionary, `player_ratings`, mapping players to their Elo ratings, compute the **total** expected score for each player (you only need to compute total expected score for players that are keys in `player_results`). The total expected score is simply the sum of the expected scores for each of that players games. Output the results as a dictionary mapping players (String) to their expected tournament score (Float).
#
# The third argument `es_func` is a function that takes two arguments (the player's rating and opponent's rating respectively) and returns an "expected score". You should use it to compute the expected scores for this exercise. **It might not be the same as the solution to Exercise 4!**
#
# A call to `es_func(1450, 1575)` inside of your function would compute the "expected score" for the 1450-rated player against a 1575-rated player.
#
# For example given:
#
# `player_results = {'Angela Martin': [('Dwight Schrute', 1.0), ('Stanley Hudson', 0.5)], 'Dwight Schrute': [('Angela Martin', 0.0), ('Jim Halpert', 0.5)]}`
#
# `player_ratings = {'Angela Martin': 1600, 'Dwight Schrute': 1750, 'Stanley Hudson': 1800, 'Jim Halpert': 1700}`
#
# `es_func = lambda r_player, r_opponent: float(r_player - r_opponent)`
#
# The output would be:
#
# `{'Angela Martin': -350.0, 'Dwight Schrute': 200.0}`

# %%
demo_player_results = {'Angela Martin': [('Dwight Schrute', 1.0), ('Stanley Hudson', 0.5)], 'Dwight Schrute': [('Angela Martin', 0.0), ('Jim Halpert', 0.5)]}
demo_player_ratings = {'Angela Martin': 1600, 'Dwight Schrute': 1750, 'Stanley Hudson': 1800, 'Jim Halpert': 1700}
demo_es_func = lambda r_player, r_opponent: float(r_player - r_opponent)

# %%
def expected_tournament_score(player_results, player_ratings, es_func):
    ###
    from collections import defaultdict
    scoresUpdate = defaultdict(float)

    print(player_results)

    for key in player_results:
        for j in player_results[key]:
            esScore = es_func(player_ratings[key], player_ratings[j[0]])
            scoresUpdate[key] += esScore
            
    return scoresUpdate
    ###

# Demo
expected_tournament_score(demo_player_results, demo_player_ratings, demo_es_func)
# Out:
# {'Angela Martin': [('Dwight Schrute', 1.0), ('Stanley Hudson', 0.5)], 'Dwight Schrute': [('Angela Martin', 0.0), ('Jim Halpert', 0.5)]}
# defaultdict(float, {'Angela Martin': -350.0, 'Dwight Schrute': 200.0})

# %% [markdown]
# The test cell below runs your function **many times**. Remove or comment out any `print` statements to avoid generating excessive output.

# %%
# `ex5_test`: Test cell
from run_tests import ex5_test
for _ in range(200):
    ex5_test(10, 4, expected_tournament_score)
print('Passed!')

###
### AUTOGRADER TEST - DO NOT REMOVE
###
test_utils.get_mem_usage_str()
# Out:
# defaultdict(<class 'list'>, {'Dcxsio,Q': [('Ltttfxhawrm,Qznch', 1.0), ('Xfuvczaikib,Mh', 0.0), ('Eskfagnic,Gmqcedor', 0.0), ('Nvkepvdvbp,Nultuc', 0.0)], 'Zkhnix,Dbclrfna': [('Ynirxfj,Ed', 1.0), ('Cgxtlzficggm,Aj', 0.5), ('Zbgtrcetyk,Oduj', 0.0), ('Jpwjmxmhili,Vc', 0.0)], 'Jdvksrt,Mcf': [('Razwhggicbea,Uycidxes', 0.0), ('Pqgrkqc,Yrtr', 0.0), ('Avsumapfiaiu,Pdu', 0.0), ('Vatkvs,Ic', 0.0)], 'Diwmxiguytu,Cxzfymkw': [('Ncvaylgllql,Wzth', 0.5), ('Gnoiuhfpokor,Ruakcth', 1.0), ('Lvcwmx,Jnvmrzs', 0.0), ('Xfnkwkfh,Uwaavg', 0.0)], 'Fijxqdo,Qkejewcuv': [('Pwrdif,Pn', 1.0), ('Oaxroiqmgy,Iwxsnzm', 1.0), ('Gkvnfkwnr,Nb', 1.0), ('Mepqnqe,Zdearabz', 0.5)], 'Cbredxnp,Afsvhsq': [('Vzhidbbukvacp,Ob', 0.0), ('Zngkwjyxton,Wlmucbn', 1.0), ('Spetruhwsf,Xf', 1.0), ('Xmkbmhknq,Cpreaza', 0.5)], 'Yjyutfbvbgwk,Xvkbebuzl': [('Eyjjpkpajx,Szo', 0.0), ('Mzmbuwdmqp,Qu', 1.0), ('Ysrofua,Hyi', 1.0), ('Diunyiak,Hs', 0.0)], 'Aqyntzf,Dfohwz': [('Rohgtva,Gamkdx', 0.5), ('Hygajod,Jt', 0.5), ('Jizxbvrtlycy,M', 0.5), ('Dogoqauny,Kkjks', 1.0)], 'Wiynonrizzztu,Azixpom': [('Jqspmutwrqt,Jwsmfr', 0.0), ('Wmcyrqmv,Wxriovhhq', 0.5), ('Mpesimuryxesp,Mcfw', 0.0), ('Pcwmgibejmb,Ida', 1.0)], 'Npxdldjgulshm,Khqk': [('Mokqxz,Of', 1.0), ('Yvvovqf,Kgvpsrd', 0.5), ('Mnoiomyrui,Qqhs', 0.0), ('Mcboihuyoeeeq,Oetrmcgs', 0.5)]})
# defaultdict(<class 'list'>, {'Dcxsio,Q': [('Ltttfxhawrm,Qznch', 1.0), ('Xfuvczaikib,Mh', 0.0), ('Eskfagnic,Gmqcedor', 0.0), ('Nvkepvdvbp,Nultuc', 0.0)], 'Zkhnix,Dbclrfna': [('Ynirxfj,Ed', 1.0), ('Cgxtlzficggm,Aj', 0.5), ('Zbgtrcetyk,Oduj', 0.0), ('Jpwjmxmhili,Vc', 0.0)], 'Jdvksrt,Mcf': [('Razwhggicbea,Uycidxes', 0.0), ('Pqgrkqc,Yrtr', 0.0), ('Avsumapfiaiu,Pdu', 0.0), ('Vatkvs,Ic', 0.0)], 'Diwmxiguytu,Cxzfymkw': [('Ncvaylgllql,Wzth', 0.5), ('Gnoiuhfpokor,Ruakcth', 1.0), ('Lvcwmx,Jnvmrzs', 0.0), ('Xfnkwkfh,Uwaavg', 0.0)], 'Fijxqdo,Qkejewcuv': [('Pwrdif,Pn', 1.0), ('Oaxroiqmgy,Iwxsnzm', 1.0), ('Gkvnfkwnr,Nb', 1.0), ('Mepqnqe,Zdearabz', 0.5)], 'Cbredxnp,Afsvhsq': [('Vzhidbbukvacp,Ob', 0.0), ('Zngkwjyxton,Wlmucbn', 1.0), ('Spetruhwsf,Xf', 1.0), ('Xmkbmhknq,Cpreaza', 0.5)], 'Yjyutfbvbgwk,Xvkbebuzl': [('Eyjjpkpajx,Szo', 0.0), ('Mzmbuwdmqp,Qu', 1.0), ('Ysrofua,Hyi', 1.0), ('Diunyiak,Hs', 0.0)], 'Aqyntzf,Dfohwz': [('Rohgtva,Gamkdx', 0.5), ('Hygajod,Jt', 0.5), ('Jizxbvrtlycy,M', 0.5), ('Dogoqauny,Kkjks', 1.0)], 'Wiynonrizzztu,Azixpom': [('Jqspmutwrqt,Jwsmfr', 0.0), ('Wmcyrqmv,Wxriovhhq', 0.5), ('Mpesimuryxesp,Mcfw', 0.0), ('Pcwmgibejmb,Ida', 1.0)], 'Npxdldjgulshm,Khqk': [('Mokqxz,Of', 1.0), ('Yvvovqf,Kgvpsrd', 0.5), ('Mnoiomyrui,Qqhs', 0.0), ('Mcboihuyoeeeq,Oetrmcgs', 0.5)]})
# defaultdict(<class 'list'>, {'Amkvfn,Gzbshvho': [('Uauysuqaw,Ydmhgmkq', 0.5), ('Zewmod,Fb', 0.0), ('Ccecskaftkim,Y', 0.5), ('Tunaxcc,Rmevvnhd', 1.0)], 'Polmxiqxbcs,Ajo': [('Cndjpskjrxrqa,Tp', 1.0), ('Phfytglxvng,Wmorkyzq', 1.0), ('Srpnqtokxm,B', 1.0), ('Eslqlanenb,Qiov', 0.0)], 'Sfczrvcrj,Zgea': [('Dvtwdytstpjya,Nlv', 1.0), ('Pfmmnjcsztwi,Peoo', 0.0), ('Gqhdeyvemv,Ugvmhx', 0.5), ('Srhabspw,M', 1.0)], 'Frzgukql,Pbfkmr': [('Izgndscwj,Beu', 0.5), ('Mxaxhms,Uvb', 1.0), ('Lvphtwx,Ptll', 1.0), ('Rwwysawfwst,H', 0.0)], 'Jbtwfbu,Xqyq': [('Iwjbkmkbywny,S', 0.5), ('Krvqahxrii,Twete', 0.5), ('Rwlkdwbomgwl,Gljrmmg', 0.5), ('Lnsuzfed,Frfd', 1.0)], 'Fkpmdxj,Jmyh': [('Ybvpmu,Skx', 0.0), ('Adjcqdjp,Jwppqgkdk', 0.0), ('Ryanewvk,Dio', 1.0), ('Prbbgob,V', 0.0)], 'Cishle,Ciixgbap': [('Fehlzte,Xqoiltp', 1.0), ('Jgmymysec,Amlrsvb', 1.0), ('Eoltdaapij,Bekx', 1.0), ('Yxktxkc,Zvjnxdqnr', 1.0)], 'Wwklqoybqe,Ysro': [('Lkfwdf,Y', 0.5), ('Mbhpsftrylq,Eiqafod', 1.0), ('Eabtczmv,Fe', 0.0), ('Tdhzjgqko,Kbbijtyx', 0.0)], 'Ttvwaoohfh,Ceszsoeb': [('Vpyhju,Kzxpdlqa', 1.0), ('Ylniqevqnx,Uh', 1.0), ('Upigpwkn,Niohudtd', 1.0), ('Lklhmb,Jwnbltfa', 0.0)], 'Drfacaz,Ae': [('Zpvpnakfqmoj,A', 0.0), ('Itbkzxs,Xs', 0.0), ('Hwbmmaplj,Gm', 0.0), ('Sdkjiflkkskdd,Dfhkx', 0.0)]})
# defaultdict(<class 'list'>, {'Amkvfn,Gzbshvho': [('Uauysuqaw,Ydmhgmkq', 0.5), ('Zewmod,Fb', 0.0), ('Ccecskaftkim,Y', 0.5), ('Tunaxcc,Rmevvnhd', 1.0)], 'Polmxiqxbcs,Ajo': [('Cndjpskjrxrqa,Tp', 1.0), ('Phfytglxvng,Wmorkyzq', 1.0), ('Srpnqtokxm,B', 1.0), ('Eslqlanenb,Qiov', 0.0)], 'Sfczrvcrj,Zgea': [('Dvtwdytstpjya,Nlv', 1.0), ('Pfmmnjcsztwi,Peoo', 0.0), ('Gqhdeyvemv,Ugvmhx', 0.5), ('Srhabspw,M', 1.0)], 'Frzgukql,Pbfkmr': [('Izgndscwj,Beu', 0.5), ('Mxaxhms,Uvb', 1.0), ('Lvphtwx,Ptll', 1.0), ('Rwwysawfwst,H', 0.0)], 'Jbtwfbu,Xqyq': [('Iwjbkmkbywny,S', 0.5), ('Krvqahxrii,Twete', 0.5), ('Rwlkdwbomgwl,Gljrmmg', 0.5), ('Lnsuzfed,Frfd', 1.0)], 'Fkpmdxj,Jmyh': [('Ybvpmu,Skx', 0.0), ('Adjcqdjp,Jwppqgkdk', 0.0), ('Ryanewvk,Dio', 1.0), ('Prbbgob,V', 0.0)], 'Cishle,Ciixgbap': [('Fehlzte,Xqoiltp', 1.0), ('Jgmymysec,Amlrsvb', 1.0), ('Eoltdaapij,Bekx', 1.0), ('Yxktxkc,Zvjnxdqnr', 1.0)], 'Wwklqoybqe,Ysro': [('Lkfwdf,Y', 0.5), ('Mbhpsftrylq,Eiqafod', 1.0), ('Eabtczmv,Fe', 0.0), ('Tdhzjgqko,Kbbijtyx', 0.0)], 'Ttvwaoohfh,Ceszsoeb': [('Vpyhju,Kzxpdlqa', 1.0), ('Ylniqevqnx,Uh', 1.0), ('Upigpwkn,Niohudtd', 1.0), ('Lklhmb,Jwnbltfa', 0.0)], 'Drfacaz,Ae': [('Zpvpnakfqmoj,A', 0.0), ('Itbkzxs,Xs', 0.0), ('Hwbmmaplj,Gm', 0.0), ('Sdkjiflkkskdd,Dfhkx', 0.0)]})
# defaultdict(<class 'list'>, {'Jdinhgebpy,D': [('Odaisfgcjiga,Sfijxtxn', 0.0), ('Mvgxnbqx,S', 1.0), ('Fblvjw,Tpq', 1.0), ('Vxrxninpu,Ufheiwker', 0.0)], 'Fuzyxmrwv,S': [('Syevftnfcund,Przjyv', 1.0), ('Uufhny,Evoxv', 0.0), ('Fqitxw,Jbauytb', 0.5), ('Rzrqdifx,Ivearbz', 1.0)], 'Stdlipeavwkwu,Icorlh': [('Brmehwtpx,Cvdqoh', 0.0), ('Gkcvfsrl,Jxzsg', 0.5), ('Gthirkynudzew,Gvat', 0.0), ('Eviirawybpzpp,Nnzh', 0.5)], 'Hfvaic,Ouwjvx': [('Ilwbdaekersb,Itdwtafx', 0.0), ('Lxilmburglqju,Jug', 1.0), ('Klllwsuj,Uk', 0.5), ('Efxxkiu,O', 0.0)], 'Whrebwhcol,Hfkmqyyqj': [('Mmtigulbwt,Xystkmwhx', 1.0), ('Vznyyuwtw,Wpvnrt', 0.5), ('Xbsfscsqsnol,Qgrr', 0.5), ('Nswphbtz,Ulul', 0.0)], 'Olqndpdbn,Qpn': [('Qvbjvrp,E', 0.5), ('Ywwsuyprkbbuc,Vvs', 0.5), ('Gernexdttzwuf,Ufpucfyz', 0.5), ('Xdrhxbaxejjvs,Lt', 0.5)], 'Hgcrzmbf,Cysgafj': [('Ijncxwqicq,Zeata', 0.0), ('Gnldtmhaiylvp,Xbmj', 0.5), ('Rrjpmkgey,Qjkkx', 0.5), ('Tmbfcumhuqwk,T', 0.0)], 'Oyhmtpiiuz,K': [('Ofjybcjlz,Yszdulstf', 1.0), ('Dbvtnq,Cfeiktwvw', 1.0), ('Hmcspjdxgzdbv,Kmqcw', 0.5), ('Mwetnohsux,Cprpesxc', 0.0)], 'Vkhmduklhw,Aftyjw': [('Vmgmesvbg,O', 0.5), ('Rupfqz,Pocsls', 0.5), ('Hszxkxv,Hkujoabw', 0.5), ('Lajpzkjcx,Fumjx', 0.0)], 'Wvxeeomkce,Xvn': [('Viitkid,Mvtl', 1.0), ('Ikpbsxin,Hgnhomz', 0.0), ('Mkqqlidvzimrb,Rukzyqj', 1.0), ('Tctlhjtve,Es', 0.5)]})
# defaultdict(<class 'list'>, {'Jdinhgebpy,D': [('Odaisfgcjiga,Sfijxtxn', 0.0), ('Mvgxnbqx,S', 1.0), ('Fblvjw,Tpq', 1.0), ('Vxrxninpu,Ufheiwker', 0.0)], 'Fuzyxmrwv,S': [('Syevftnfcund,Przjyv', 1.0), ('Uufhny,Evoxv', 0.0), ('Fqitxw,Jbauytb', 0.5), ('Rzrqdifx,Ivearbz', 1.0)], 'Stdlipeavwkwu,Icorlh': [('Brmehwtpx,Cvdqoh', 0.0), ('Gkcvfsrl,Jxzsg', 0.5), ('Gthirkynudzew,Gvat', 0.0), ('Eviirawybpzpp,Nnzh', 0.5)], 'Hfvaic,Ouwjvx': [('Ilwbdaekersb,Itdwtafx', 0.0), ('Lxilmburglqju,Jug', 1.0), ('Klllwsuj,Uk', 0.5), ('Efxxkiu,O', 0.0)], 'Whrebwhcol,Hfkmqyyqj': [('Mmtigulbwt,Xystkmwhx', 1.0), ('Vznyyuwtw,Wpvnrt', 0.5), ('Xbsfscsqsnol,Qgrr', 0.5), ('Nswphbtz,Ulul', 0.0)], 'Olqndpdbn,Qpn': [('Qvbjvrp,E', 0.5), ('Ywwsuyprkbbuc,Vvs', 0.5), ('Gernexdttzwuf,Ufpucfyz', 0.5), ('Xdrhxbaxejjvs,Lt', 0.5)], 'Hgcrzmbf,Cysgafj': [('Ijncxwqicq,Zeata', 0.0), ('Gnldtmhaiylvp,Xbmj', 0.5), ('Rrjpmkgey,Qjkkx', 0.5), ('Tmbfcumhuqwk,T', 0.0)], 'Oyhmtpiiuz,K': [('Ofjybcjlz,Yszdulstf', 1.0), ('Dbvtnq,Cfeiktwvw', 1.0), ('Hmcspjdxgzdbv,Kmqcw', 0.5), ('Mwetnohsux,Cprpesxc', 0.0)], 'Vkhmduklhw,Aftyjw': [('Vmgmesvbg,O', 0.5), ('Rupfqz,Pocsls', 0.5), ('Hszxkxv,Hkujoabw', 0.5), ('Lajpzkjcx,Fumjx', 0.0)], 'Wvxeeomkce,Xvn': [('Viitkid,Mvtl', 1.0), ('Ikpbsxin,Hgnhomz', 0.0), ('Mkqqlidvzimrb,Rukzyqj', 1.0), ('Tctlhjtve,Es', 0.5)]})
# defaultdict(<class 'list'>, {'Xuoqja,Dynvuwddr': [('Cgwdrlxnxamr,Wpyngs', 0.5), ('Jimogbnjrwsrg,Gwf', 0.0), ('Cvetfdqbraa,Bxumwilw', 0.5), ('Raftdbkohr,Afv', 0.5)], 'Qrdocbazbfdxk,Qwcaqbn': [('Kuhspcvbae,Ghqieahef', 1.0), ('Ecmnjab,R', 0.5), ('Zyjqbidgtkmnw,Zmbemv', 0.5), ('Zrurshbyri,Dc', 0.0)], 'Jnmptuu,Ylzazu': [('Oshqvqszjumyc,Auqcne', 0.5), ('Qmntcqsnmk,Zaytnleq', 1.0), ('Xpffomhzxqe,Olvgrhw', 1.0), ('Ltuvvmh,Yt', 0.0)], 'Uuhmmjfeoqas,Exwfavol': [('Ewgsyk,Ababl', 0.0), ('Allwfywdegbze,Vrgvhsk', 0.0), ('Srvksodo,Bcwtayfuu', 1.0), ('Nojepmejuhjmv,Ytmmj', 0.5)], 'Shqfoomrlhmsb,C': [('Igzllbjqs,Dpltmxjk', 0.5), ('Sksoufikb,Seexxzs', 0.0), ('Yzpoqw,Smfo', 1.0), ('Fvsihdorgswe,Obez', 1.0)], 'Gamnsi,Icljivw': [('Szztszggmpao,Bbfc', 0.0), ('Skstyrhhs,Xdrpyydll', 0.0), ('Klagxqwxbuw,Dhhnzjqzh', 0.5), ('Pmrmynezithal,Skyclwk', 1.0)], 'Amfyrqgydkyq,Ue': [('Alokqmkc,Ccgn', 1.0), ('Wvhipzfx,Ojaefxxi', 1.0), ('Kfstegrisfbr,Mcrzx', 0.5), ('Nhgrgwvcy,Kddxbu', 0.0)], 'Mypqptkauwvaz,Zbysui': [('Xnuvzmddqvqh,Jzhe', 1.0), ('Vhgcnnjfi,Tpgjjla', 1.0), ('Bktwokqlwix,Stbtvimmh', 0.0), ('Vtmjkuaqzqvh,Ikyjmqo', 0.5)], 'Ydoiblwl,Hugl': [('Jrxykjwjhjq,Xenuefv', 0.0), ('Ofsrtlhu,Wsazsfjbo', 0.0), ('Hkogvcjiygtgw,Qnsjcwr', 1.0), ('Bvletrydbmka,J', 0.5)], 'Ejpbjimyrr,Yyiuanz': [('Wlpnjomlljprf,Ruejcpj', 0.0), ('Gcpknw,Fp', 0.0), ('Wspodncpz,M', 0.0), ('Wnxmxmmom,Iohjym', 0.5)]})
# defaultdict(<class 'list'>, {'Xuoqja,Dynvuwddr': [('Cgwdrlxnxamr,Wpyngs', 0.5), ('Jimogbnjrwsrg,Gwf', 0.0), ('Cvetfdqbraa,Bxumwilw', 0.5), ('Raftdbkohr,Afv', 0.5)], 'Qrdocbazbfdxk,Qwcaqbn': [('Kuhspcvbae,Ghqieahef', 1.0), ('Ecmnjab,R', 0.5), ('Zyjqbidgtkmnw,Zmbemv', 0.5), ('Zrurshbyri,Dc', 0.0)], 'Jnmptuu,Ylzazu': [('Oshqvqszjumyc,Auqcne', 0.5), ('Qmntcqsnmk,Zaytnleq', 1.0), ('Xpffomhzxqe,Olvgrhw', 1.0), ('Ltuvvmh,Yt', 0.0)], 'Uuhmmjfeoqas,Exwfavol': [('Ewgsyk,Ababl', 0.0), ('Allwfywdegbze,Vrgvhsk', 0.0), ('Srvksodo,Bcwtayfuu', 1.0), ('Nojepmejuhjmv,Ytmmj', 0.5)], 'Shqfoomrlhmsb,C': [('Igzllbjqs,Dpltmxjk', 0.5), ('Sksoufikb,Seexxzs', 0.0), ('Yzpoqw,Smfo', 1.0), ('Fvsihdorgswe,Obez', 1.0)], 'Gamnsi,Icljivw': [('Szztszggmpao,Bbfc', 0.0), ('Skstyrhhs,Xdrpyydll', 0.0), ('Klagxqwxbuw,Dhhnzjqzh', 0.5), ('Pmrmynezithal,Skyclwk', 1.0)], 'Amfyrqgydkyq,Ue': [('Alokqmkc,Ccgn', 1.0), ('Wvhipzfx,Ojaefxxi', 1.0), ('Kfstegrisfbr,Mcrzx', 0.5), ('Nhgrgwvcy,Kddxbu', 0.0)], 'Mypqptkauwvaz,Zbysui': [('Xnuvzmddqvqh,Jzhe', 1.0), ('Vhgcnnjfi,Tpgjjla', 1.0), ('Bktwokqlwix,Stbtvimmh', 0.0), ('Vtmjkuaqzqvh,Ikyjmqo', 0.5)], 'Ydoiblwl,Hugl': [('Jrxykjwjhjq,Xenuefv', 0.0), ('Ofsrtlhu,Wsazsfjbo', 0.0), ('Hkogvcjiygtgw,Qnsjcwr', 1.0), ('Bvletrydbmka,J', 0.5)], 'Ejpbjimyrr,Yyiuanz': [('Wlpnjomlljprf,Ruejcpj', 0.0), ('Gcpknw,Fp', 0.0), ('Wspodncpz,M', 0.0), ('Wnxmxmmom,Iohjym', 0.5)]})
# defaultdict(<class 'list'>, {'Csryjv,Pddt': [('Ctwhyvzvmmz,Omqd', 1.0), ('Tzcsbarhnjsr,Nu', 0.0), ('Efnbjpu,Jozgdi', 1.0), ('Qzivghkhyo,Penoc', 0.5)], 'Gemltsocrawny,Cjlyjb': [('Ljuctouxs,Nwrexxley', 1.0), ('Xvonnkysiws,B', 0.0), ('Erobzxodagc,Wicvi', 1.0), ('Lhnuzuqy,Hemzvhwqk', 0.5)], 'Sgjrpwlyvrlzv,Nnf': [('Lwbcttwficg,Zfkcksxyb', 0.0), ('Kikrdvcypasq,Pzcx', 0.5), ('Rlwvisqza,Tll', 0.0), ('Kdjzpjede,Lauvwepkd', 0.0)], 'Mmoyabxj,Lcsb': [('Hvmvnba,Sqnvmqus', 0.5), ('Rqrsrk,Mlcqkcel', 0.0), ('Hbssrcdexr,Sokbilb', 0.5), ('Ikormpnbvzl,Gtk', 0.0)], 'Mwnaftuzq,Uktsquam': [('Gtrscup,Vyq', 1.0), ('Xamngtmwva,Wepuysmqw', 0.0), ('Cplmxdzh,Jvrez', 0.0), ('Npplnggpobej,Avd', 1.0)], 'Cbkyule,Tijcmoaea': [('Iptwdhxfpc,Cmebpmbwr', 0.0), ('Cqidflyehuwp,Pp', 0.5), ('Rpfxhrrkuctz,Tashcv', 1.0), ('Fthwnur,Lzqwbrq', 0.0)], 'Yyrhjsmprojd,Vh': [('Fwnvkzmmndxjd,Hcylp', 0.5), ('Chdykcdwwj,Lxl', 0.0), ('Sqhegc,Rqwagwnsi', 0.0), ('Wcarfhrdds,Cwvveto', 0.0)], 'Agrclbbkzefpy,Ktdjpn': [('Crlvwtv,Zf', 0.5), ('Lwjxmqgpycvxg,T', 1.0), ('Dfmamovwsa,J', 0.0), ('Colwfceisuge,Czuib', 0.0)], 'Nglpnhcxr,Nhqoaa': [('Zkrixk,Rgzdko', 0.5), ('Kiyhamyr,Dovp', 0.5), ('Ulzrqtkjrpafs,Swamibdpk', 0.0), ('Rsernm,Hybq', 0.5)], 'Nxlswjuy,Xcpsgqqz': [('Dewjoztq,Jqyeshj', 0.0), ('Lzbiphxuka,S', 1.0), ('Utvweedxcun,Daxax', 1.0), ('Qkgordrimdc,Dx', 0.0)]})
# defaultdict(<class 'list'>, {'Csryjv,Pddt': [('Ctwhyvzvmmz,Omqd', 1.0), ('Tzcsbarhnjsr,Nu', 0.0), ('Efnbjpu,Jozgdi', 1.0), ('Qzivghkhyo,Penoc', 0.5)], 'Gemltsocrawny,Cjlyjb': [('Ljuctouxs,Nwrexxley', 1.0), ('Xvonnkysiws,B', 0.0), ('Erobzxodagc,Wicvi', 1.0), ('Lhnuzuqy,Hemzvhwqk', 0.5)], 'Sgjrpwlyvrlzv,Nnf': [('Lwbcttwficg,Zfkcksxyb', 0.0), ('Kikrdvcypasq,Pzcx', 0.5), ('Rlwvisqza,Tll', 0.0), ('Kdjzpjede,Lauvwepkd', 0.0)], 'Mmoyabxj,Lcsb': [('Hvmvnba,Sqnvmqus', 0.5), ('Rqrsrk,Mlcqkcel', 0.0), ('Hbssrcdexr,Sokbilb', 0.5), ('Ikormpnbvzl,Gtk', 0.0)], 'Mwnaftuzq,Uktsquam': [('Gtrscup,Vyq', 1.0), ('Xamngtmwva,Wepuysmqw', 0.0), ('Cplmxdzh,Jvrez', 0.0), ('Npplnggpobej,Avd', 1.0)], 'Cbkyule,Tijcmoaea': [('Iptwdhxfpc,Cmebpmbwr', 0.0), ('Cqidflyehuwp,Pp', 0.5), ('Rpfxhrrkuctz,Tashcv', 1.0), ('Fthwnur,Lzqwbrq', 0.0)], 'Yyrhjsmprojd,Vh': [('Fwnvkzmmndxjd,Hcylp', 0.5), ('Chdykcdwwj,Lxl', 0.0), ('Sqhegc,Rqwagwnsi', 0.0), ('Wcarfhrdds,Cwvveto', 0.0)], 'Agrclbbkzefpy,Ktdjpn': [('Crlvwtv,Zf', 0.5), ('Lwjxmqgpycvxg,T', 1.0), ('Dfmamovwsa,J', 0.0), ('Colwfceisuge,Czuib', 0.0)], 'Nglpnhcxr,Nhqoaa': [('Zkrixk,Rgzdko', 0.5), ('Kiyhamyr,Dovp', 0.5), ('Ulzrqtkjrpafs,Swamibdpk', 0.0), ('Rsernm,Hybq', 0.5)], 'Nxlswjuy,Xcpsgqqz': [('Dewjoztq,Jqyeshj', 0.0), ('Lzbiphxuka,S', 1.0), ('Utvweedxcun,Daxax', 1.0), ('Qkgordrimdc,Dx', 0.0)]})
# defaultdict(<class 'list'>, {'Ohvsgn,Ofcgly': [('Jwbpswvirince,Ii', 0.0), ('Srezybem,Bfwjdhlxn', 1.0), ('Azixyj,Acfbrgp', 0.5), ('Wiregr,Fb', 1.0)], 'Qeztvpvpkvtqx,Xujocee': [('Qjhljikwhn,Pwzc', 0.5), ('Kbnomnupyeh,G', 1.0), ('Tkxgna,Slodouyf', 0.0), ('Pkjust,Avoueppy', 0.5)], 'Mncudebmxwc,R': [('Jynynnvzmp,Yseeriv', 1.0), ('Lpuzesgb,Pnxf', 0.5), ('Gpzpjml,Mim', 0.0), ('Cprqiycmni,Yunlwfmzn', 0.5)], 'Tsyxtzvs,Aqezbl': [('Dupdrssktr,Strsy', 1.0), ('Uzeyuotxkk,Zsodvv', 0.5), ('Iognjbbf,Q', 0.0), ('Cajnjhwxyue,Stmqkzkcf', 0.5)], 'Creuso,Gqezig': [('Eikvjuqd,Ukfv', 0.5), ('Prswvkrpa,Bqvsksch', 0.0), ('Tqppxcxctk,Nukbl', 1.0), ('Cvngatusiuz,Ahz', 0.5)], 'Zrmpiflpxa,Ad': [('Bimaihoo,Nxa', 0.5), ('Efgthpijhnp,Xoeniyp', 1.0), ('Eygekqgz,Xctql', 0.5), ('Mbuumrfngsn,R', 1.0)], 'Mispbkntqth,Apl': [('Cuoxvvpbok,Gulx', 0.0), ('Jafsuuxhnnycs,Rsvdutrcj', 0.5), ('Mdvmcxlisutq,Yw', 0.0), ('Ufutsqz,Mfxjtjgpj', 0.5)], 'Iulhoebzzkilz,J': [('Tzvmrkaxkx,Hxiyy', 0.0), ('Ftjkmnbokgag,War', 1.0), ('Rlikrey,Kspoyagn', 0.0), ('Llwoovvgog,Ada', 0.0)], 'Udghkgamu,Ysq': [('Niupdhqo,Rdkqrrr', 0.5), ('Kfugnzw,Mhhxia', 0.0), ('Cowgpmhhp,Mkshqa', 1.0), ('Ihdqal,Dhe', 0.0)], 'Nwopgvncqt,Cfdqsgmu': [('Wmredfzbwf,Tpdglhsl', 1.0), ('Wcqkpjxf,Dfizgz', 1.0), ('Uakfprhj,Hk', 0.5), ('Qmufkbvueeos,Ndxgsbko', 0.0)]})
# defaultdict(<class 'list'>, {'Ohvsgn,Ofcgly': [('Jwbpswvirince,Ii', 0.0), ('Srezybem,Bfwjdhlxn', 1.0), ('Azixyj,Acfbrgp', 0.5), ('Wiregr,Fb', 1.0)], 'Qeztvpvpkvtqx,Xujocee': [('Qjhljikwhn,Pwzc', 0.5), ('Kbnomnupyeh,G', 1.0), ('Tkxgna,Slodouyf', 0.0), ('Pkjust,Avoueppy', 0.5)], 'Mncudebmxwc,R': [('Jynynnvzmp,Yseeriv', 1.0), ('Lpuzesgb,Pnxf', 0.5), ('Gpzpjml,Mim', 0.0), ('Cprqiycmni,Yunlwfmzn', 0.5)], 'Tsyxtzvs,Aqezbl': [('Dupdrssktr,Strsy', 1.0), ('Uzeyuotxkk,Zsodvv', 0.5), ('Iognjbbf,Q', 0.0), ('Cajnjhwxyue,Stmqkzkcf', 0.5)], 'Creuso,Gqezig': [('Eikvjuqd,Ukfv', 0.5), ('Prswvkrpa,Bqvsksch', 0.0), ('Tqppxcxctk,Nukbl', 1.0), ('Cvngatusiuz,Ahz', 0.5)], 'Zrmpiflpxa,Ad': [('Bimaihoo,Nxa', 0.5), ('Efgthpijhnp,Xoeniyp', 1.0), ('Eygekqgz,Xctql', 0.5), ('Mbuumrfngsn,R', 1.0)], 'Mispbkntqth,Apl': [('Cuoxvvpbok,Gulx', 0.0), ('Jafsuuxhnnycs,Rsvdutrcj', 0.5), ('Mdvmcxlisutq,Yw', 0.0), ('Ufutsqz,Mfxjtjgpj', 0.5)], 'Iulhoebzzkilz,J': [('Tzvmrkaxkx,Hxiyy', 0.0), ('Ftjkmnbokgag,War', 1.0), ('Rlikrey,Kspoyagn', 0.0), ('Llwoovvgog,Ada', 0.0)], 'Udghkgamu,Ysq': [('Niupdhqo,Rdkqrrr', 0.5), ('Kfugnzw,Mhhxia', 0.0), ('Cowgpmhhp,Mkshqa', 1.0), ('Ihdqal,Dhe', 0.0)], 'Nwopgvncqt,Cfdqsgmu': [('Wmredfzbwf,Tpdglhsl', 1.0), ('Wcqkpjxf,Dfizgz', 1.0), ('Uakfprhj,Hk', 0.5), ('Qmufkbvueeos,Ndxgsbko', 0.0)]})
# defaultdict(<class 'list'>, {'Rhfnugcyfh,Xrmcyrf': [('Sddwusw,Svv', 1.0), ('Ryyunlplkdgo,Kl', 0.0), ('Acsbursmvtl,D', 0.0), ('Yjrvzwpncbgk,Azgxztl', 0.5)], 'Faoqqmserh,Laiqtx': [('Svzwxhupw,Foszac', 1.0), ('Gdtxketz,Bky', 0.5), ('Zqpncuwytcb,A', 0.0), ('Icyekkzqx,Obp', 0.0)], 'Qputchm,Dizf': [('Pslvftowyyub,Bu', 1.0), ('Kdmhddm,Kgmmjlsz', 1.0), ('Mfpahcwp,Cokox', 1.0), ('Xsozjurcopr,Gzjt', 0.0)], 'Idbuchbmkxpf,Pvwg': [('Ejetrrhjabxqu,P', 0.0), ('Obhiwkiw,L', 1.0), ('Pkulqftsjls,F', 1.0), ('Rkfrcasvmg,Umzhz', 0.0)], 'Pstykvfpyx,L': [('Beqvlcjisd,Agq', 1.0), ('Emasdtyvjmo,Lqzdphqf', 0.5), ('Pypwtapq,Sgsr', 0.0), ('Typgfutyvkao,Gwcqqjmb', 0.5)], 'Lyenedgqjrxvp,Hqmimwzpj': [('Snmxvh,Skwsnpm', 0.0), ('Arzqbs,Fyjq', 0.5), ('Bbnfkopb,Axrwidr', 0.0), ('Onhfwgalk,Bxvugwtxe', 0.5)], 'Bdxnhuegmn,Yia': [('Killezgfswoqs,Nakqlxw', 0.5), ('Bolcrycecjfbx,Rgosoc', 1.0), ('Xtfivraa,Edlehyiyx', 0.0), ('Lfrxhjxarur,Okgervnr', 0.5)], 'Vfxdryzj,Ew': [('Iqmrxy,Nbm', 0.0), ('Nvnwsotll,Qvucbvna', 0.0), ('Sbbvog,Rwwme', 1.0), ('Hsfzssbq,T', 1.0)], 'Ydibbdmeelnuv,Vezxjbv': [('Ylkryr,Q', 1.0), ('Lvxwem,S', 0.5), ('Eounbbvvwsn,Mbn', 0.5), ('Phunelwugmqaq,Tjitmbt', 0.5)], 'Pewblttrgdoy,Lt': [('Lriddluyytz,Spbjolu', 0.0), ('Kvgzreb,Tdioosv', 1.0), ('Rllpeswybw,Um', 0.5), ('Rfczcwmz,Drzayjh', 0.0)]})
# defaultdict(<class 'list'>, {'Rhfnugcyfh,Xrmcyrf': [('Sddwusw,Svv', 1.0), ('Ryyunlplkdgo,Kl', 0.0), ('Acsbursmvtl,D', 0.0), ('Yjrvzwpncbgk,Azgxztl', 0.5)], 'Faoqqmserh,Laiqtx': [('Svzwxhupw,Foszac', 1.0), ('Gdtxketz,Bky', 0.5), ('Zqpncuwytcb,A', 0.0), ('Icyekkzqx,Obp', 0.0)], 'Qputchm,Dizf': [('Pslvftowyyub,Bu', 1.0), ('Kdmhddm,Kgmmjlsz', 1.0), ('Mfpahcwp,Cokox', 1.0), ('Xsozjurcopr,Gzjt', 0.0)], 'Idbuchbmkxpf,Pvwg': [('Ejetrrhjabxqu,P', 0.0), ('Obhiwkiw,L', 1.0), ('Pkulqftsjls,F', 1.0), ('Rkfrcasvmg,Umzhz', 0.0)], 'Pstykvfpyx,L': [('Beqvlcjisd,Agq', 1.0), ('Emasdtyvjmo,Lqzdphqf', 0.5), ('Pypwtapq,Sgsr', 0.0), ('Typgfutyvkao,Gwcqqjmb', 0.5)], 'Lyenedgqjrxvp,Hqmimwzpj': [('Snmxvh,Skwsnpm', 0.0), ('Arzqbs,Fyjq', 0.5), ('Bbnfkopb,Axrwidr', 0.0), ('Onhfwgalk,Bxvugwtxe', 0.5)], 'Bdxnhuegmn,Yia': [('Killezgfswoqs,Nakqlxw', 0.5), ('Bolcrycecjfbx,Rgosoc', 1.0), ('Xtfivraa,Edlehyiyx', 0.0), ('Lfrxhjxarur,Okgervnr', 0.5)], 'Vfxdryzj,Ew': [('Iqmrxy,Nbm', 0.0), ('Nvnwsotll,Qvucbvna', 0.0), ('Sbbvog,Rwwme', 1.0), ('Hsfzssbq,T', 1.0)], 'Ydibbdmeelnuv,Vezxjbv': [('Ylkryr,Q', 1.0), ('Lvxwem,S', 0.5), ('Eounbbvvwsn,Mbn', 0.5), ('Phunelwugmqaq,Tjitmbt', 0.5)], 'Pewblttrgdoy,Lt': [('Lriddluyytz,Spbjolu', 0.0), ('Kvgzreb,Tdioosv', 1.0), ('Rllpeswybw,Um', 0.5), ('Rfczcwmz,Drzayjh', 0.0)]})
# defaultdict(<class 'list'>, {'Rmkvjrjbiwt,Kjqow': [('Gfrsklviafd,S', 1.0), ('Uyobvxfyw,Xzajqf', 0.0), ('Evfkjsmd,Hfsw', 0.0), ('Eakeeayqjnd,Nmjkjk', 0.5)], 'Gxjqfdvj,Gjrpdzuez': [('Dhqfyul,Uxsbzqmun', 1.0), ('Kbxrtjzhlsa,Xlhiugn', 0.5), ('Fmacon,Ywteiyl', 1.0), ('Ptsowrke,Aansqsr', 0.5)], 'Dtzetvwo,Ajrh': [('Watkzsqtvi,Pdi', 0.0), ('Chrmavon,Rqdcn', 0.5), ('Ztscezhquimv,Mzwaezj', 0.0), ('Cjggmuz,Gp', 0.5)], 'Tpgwmlsb,Fqu': [('Fiwzxsja,Dgsem', 1.0), ('Adnhsmchbtihl,Loxosyz', 0.0), ('Spuosvnuduruw,Hiohpen', 1.0), ('Wjlkyzdetpjn,Ffnj', 0.0)], 'Xgqulud,Hpm': [('Ligwhvwcxybkx,Gfo', 1.0), ('Megvroyekt,Pyvf', 0.5), ('Hhyhbxb,Sfcxuoy', 0.5), ('Gmpkiupgdyn,Zizh', 0.0)], 'Vtbfyv,Zlvxle': [('Sfqntkcuttp,Iyjuf', 0.0), ('Sydgaptqoy,Qqudwr', 0.5), ('Lllxdpuy,Htcdihh', 0.5), ('Kvdwkntaxlpu,Pj', 0.0)], 'Vfegpaoextw,Wd': [('Hnzpmsv,N', 1.0), ('Nmmsvmq,Xd', 0.0), ('Hzonkzziwl,U', 0.5), ('Seeesdbov,Cv', 1.0)], 'Scmmxtojzhj,Veahrvn': [('Htrbyv,Op', 0.0), ('Dbvjruongii,Q', 1.0), ('Bdfclfdd,Go', 1.0), ('Pwjoeeqy,Wbf', 0.0)], 'Lqdxwtydfzf,Ldxcytf': [('Anakitpandje,Rapera', 0.0), ('Iqxmidlqa,Zhwlu', 0.0), ('Gfyboemz,Ujjag', 0.0), ('Nzlycj,Bjs', 0.0)], 'Ojtuyy,Hxyotuxy': [('Spuymd,B', 0.5), ('Mlxedhdlq,Mb', 0.5), ('Eopwiyd,Mctjex', 0.0), ('Dvdbqzugmiuzn,Pwfkylor', 1.0)]})
# defaultdict(<class 'list'>, {'Rmkvjrjbiwt,Kjqow': [('Gfrsklviafd,S', 1.0), ('Uyobvxfyw,Xzajqf', 0.0), ('Evfkjsmd,Hfsw', 0.0), ('Eakeeayqjnd,Nmjkjk', 0.5)], 'Gxjqfdvj,Gjrpdzuez': [('Dhqfyul,Uxsbzqmun', 1.0), ('Kbxrtjzhlsa,Xlhiugn', 0.5), ('Fmacon,Ywteiyl', 1.0), ('Ptsowrke,Aansqsr', 0.5)], 'Dtzetvwo,Ajrh': [('Watkzsqtvi,Pdi', 0.0), ('Chrmavon,Rqdcn', 0.5), ('Ztscezhquimv,Mzwaezj', 0.0), ('Cjggmuz,Gp', 0.5)], 'Tpgwmlsb,Fqu': [('Fiwzxsja,Dgsem', 1.0), ('Adnhsmchbtihl,Loxosyz', 0.0), ('Spuosvnuduruw,Hiohpen', 1.0), ('Wjlkyzdetpjn,Ffnj', 0.0)], 'Xgqulud,Hpm': [('Ligwhvwcxybkx,Gfo', 1.0), ('Megvroyekt,Pyvf', 0.5), ('Hhyhbxb,Sfcxuoy', 0.5), ('Gmpkiupgdyn,Zizh', 0.0)], 'Vtbfyv,Zlvxle': [('Sfqntkcuttp,Iyjuf', 0.0), ('Sydgaptqoy,Qqudwr', 0.5), ('Lllxdpuy,Htcdihh', 0.5), ('Kvdwkntaxlpu,Pj', 0.0)], 'Vfegpaoextw,Wd': [('Hnzpmsv,N', 1.0), ('Nmmsvmq,Xd', 0.0), ('Hzonkzziwl,U', 0.5), ('Seeesdbov,Cv', 1.0)], 'Scmmxtojzhj,Veahrvn': [('Htrbyv,Op', 0.0), ('Dbvjruongii,Q', 1.0), ('Bdfclfdd,Go', 1.0), ('Pwjoeeqy,Wbf', 0.0)], 'Lqdxwtydfzf,Ldxcytf': [('Anakitpandje,Rapera', 0.0), ('Iqxmidlqa,Zhwlu', 0.0), ('Gfyboemz,Ujjag', 0.0), ('Nzlycj,Bjs', 0.0)], 'Ojtuyy,Hxyotuxy': [('Spuymd,B', 0.5), ('Mlxedhdlq,Mb', 0.5), ('Eopwiyd,Mctjex', 0.0), ('Dvdbqzugmiuzn,Pwfkylor', 1.0)]})
# defaultdict(<class 'list'>, {'Qsixrnayw,Njhv': [('Becevm,H', 1.0), ('Byzplxfu,Tlfvy', 0.5), ('Prmhlxadomj,Vkmzh', 1.0), ('Cajxxwb,Sag', 0.5)], 'Dmsfjuiunj,Nvrcw': [('Hrmneurdiml,F', 0.0), ('Fjnmchxrrf,Voem', 0.0), ('Naxlkwqz,O', 0.5), ('Clvvuwggxpbg,Ml', 0.0)], 'Dlfevni,Jgzakq': [('Rmqnsth,Zotbm', 0.5), ('Aftgmjyh,Djvuc', 0.5), ('Jnqikiu,Zxtfrjxzt', 0.5), ('Vakzqwjrdije,Wkktg', 1.0)], 'Qbszhuwinmodm,Bn': [('Rijdahzo,Dafqmg', 1.0), ('Vifhregzsz,Iuhkjdze', 1.0), ('Ktuxklsj,Vtpkzh', 0.5), ('Hhyshm,Dwjn', 0.5)], 'Fnzpoo,Qs': [('Nfquqhcommeqs,Jhbpjaf', 1.0), ('Wyifccvww,Iqesjy', 1.0), ('Hykuywns,Ekzdploif', 0.5), ('Woiedjhyux,K', 1.0)], 'Ykeuqtiervnh,Becpal': [('Ccqocijdl,Nshzswor', 0.0), ('Npwcosdv,Duntw', 0.5), ('Aggansvontnja,Rylut', 0.5), ('Fiyjgrybavpdr,Bctpyqaaq', 0.5)], 'Ovaiwiwso,Rffemqaz': [('Nqadudi,Vk', 1.0), ('Fnuxiejkei,Vzaih', 0.0), ('Ymrjjjw,Tuijlovla', 1.0), ('Qtdhgehroz,Xuwdo', 1.0)], 'Utstvhmasw,Mrfebqs': [('Dpfbyjqda,Fzi', 1.0), ('Owgmaibm,Ohc', 1.0), ('Sckkzmyxmsr,Y', 0.0), ('Qykpslwnx,Nvgsqjdzi', 0.5)], 'Nicikur,Drlgevnz': [('Mrayxvbhft,Ti', 0.5), ('Bcpwtd,Cbhpd', 1.0), ('Njqxvmtxqqhz,Nrpva', 0.0), ('Wyoogyxmojjcj,Pgoguh', 0.0)], 'Xpveueax,Wzilh': [('Vdayvrllqw,Qa', 1.0), ('Lrkrneeyxjkj,Ybobn', 0.0), ('Dxdkmaxw,X', 0.5), ('Bjaiatpbvu,Aabwwrmc', 0.0)]})
# defaultdict(<class 'list'>, {'Qsixrnayw,Njhv': [('Becevm,H', 1.0), ('Byzplxfu,Tlfvy', 0.5), ('Prmhlxadomj,Vkmzh', 1.0), ('Cajxxwb,Sag', 0.5)], 'Dmsfjuiunj,Nvrcw': [('Hrmneurdiml,F', 0.0), ('Fjnmchxrrf,Voem', 0.0), ('Naxlkwqz,O', 0.5), ('Clvvuwggxpbg,Ml', 0.0)], 'Dlfevni,Jgzakq': [('Rmqnsth,Zotbm', 0.5), ('Aftgmjyh,Djvuc', 0.5), ('Jnqikiu,Zxtfrjxzt', 0.5), ('Vakzqwjrdije,Wkktg', 1.0)], 'Qbszhuwinmodm,Bn': [('Rijdahzo,Dafqmg', 1.0), ('Vifhregzsz,Iuhkjdze', 1.0), ('Ktuxklsj,Vtpkzh', 0.5), ('Hhyshm,Dwjn', 0.5)], 'Fnzpoo,Qs': [('Nfquqhcommeqs,Jhbpjaf', 1.0), ('Wyifccvww,Iqesjy', 1.0), ('Hykuywns,Ekzdploif', 0.5), ('Woiedjhyux,K', 1.0)], 'Ykeuqtiervnh,Becpal': [('Ccqocijdl,Nshzswor', 0.0), ('Npwcosdv,Duntw', 0.5), ('Aggansvontnja,Rylut', 0.5), ('Fiyjgrybavpdr,Bctpyqaaq', 0.5)], 'Ovaiwiwso,Rffemqaz': [('Nqadudi,Vk', 1.0), ('Fnuxiejkei,Vzaih', 0.0), ('Ymrjjjw,Tuijlovla', 1.0), ('Qtdhgehroz,Xuwdo', 1.0)], 'Utstvhmasw,Mrfebqs': [('Dpfbyjqda,Fzi', 1.0), ('Owgmaibm,Ohc', 1.0), ('Sckkzmyxmsr,Y', 0.0), ('Qykpslwnx,Nvgsqjdzi', 0.5)], 'Nicikur,Drlgevnz': [('Mrayxvbhft,Ti', 0.5), ('Bcpwtd,Cbhpd', 1.0), ('Njqxvmtxqqhz,Nrpva', 0.0), ('Wyoogyxmojjcj,Pgoguh', 0.0)], 'Xpveueax,Wzilh': [('Vdayvrllqw,Qa', 1.0), ('Lrkrneeyxjkj,Ybobn', 0.0), ('Dxdkmaxw,X', 0.5), ('Bjaiatpbvu,Aabwwrmc', 0.0)]})
# defaultdict(<class 'list'>, {'Eclytscln,Zlcisctvk': [('Imjlztvoloro,L', 0.0), ('Ckcrkuryjt,Cakb', 0.5), ('Ghtdhys,Tt', 0.0), ('Pgpnavamc,Hox', 1.0)], 'Jokyzbnqk,Duzotxx': [('Yegooqb,Pe', 0.5), ('Pudmkoxytg,Drjmgagd', 0.0), ('Aisraw,Ube', 1.0), ('Bdhyuyrtsp,Duek', 1.0)], 'Wkuakpb,Dgbh': [('Pgenlun,Zvzdlt', 1.0), ('Swwddtsuiihd,Dnrcy', 1.0), ('Ekznheqamtuh,Jheqjdav', 0.0), ('Elwseiwxtzdku,Bmekds', 0.5)], 'Hxskpiuc,Drocbww': [('Cqjcevqd,O', 0.5), ('Hgzpfvt,Wghmxoyw', 1.0), ('Xjrclh,Atr', 1.0), ('Mxxneees,Tye', 0.5)], 'Adbkwghh,Rgzvv': [('Ptudpvl,Jlgmb', 0.5), ('Yvraageppi,Ylqovfr', 1.0), ('Tzmgbpdkb,Imczp', 0.5), ('Zzjtenfbcnld,Hjatvtcnd', 1.0)], 'Gpyfucitevs,Oisuit': [('Kyfpoqiexet,Kamdfpb', 1.0), ('Acawvpagzijx,Vggmndxi', 0.0), ('Rdnhvgtnnuu,Qn', 0.0), ('Igwdzonq,Wm', 1.0)], 'Njqwpi,Pqilyuejm': [('Yrhxjvpsczqq,Uumpnur', 1.0), ('Qswfwfwnokwa,Mat', 0.5), ('Vpzmteby,Rslxw', 0.0), ('Rlythvnqq,Ofdluox', 1.0)], 'Edeojwzzg,Cshkin': [('Nbrphcdctgeg,Ckqbbt', 0.0), ('Nubiatp,Mktanfj', 1.0), ('Vrerfb,Erql', 1.0), ('Udxlpptcfhz,Tjntzzs', 0.5)], 'Vsymyutpvs,Gg': [('Bckvyihkda,Gpakipkzd', 0.0), ('Cqvmqo,Wvjvaf', 1.0), ('Qdezmma,Xuokouxu', 0.0), ('Hsbcxjugz,Zmkjdy', 0.5)], 'Dqqxhbat,Q': [('Yiulljjznf,Wdnkqydt', 0.5), ('Qkunncdbxj,Ncwno', 1.0), ('Hlcqli,Ssvvhdg', 1.0), ('Qmgbpwxiowtat,Mfbxw', 1.0)]})
# defaultdict(<class 'list'>, {'Eclytscln,Zlcisctvk': [('Imjlztvoloro,L', 0.0), ('Ckcrkuryjt,Cakb', 0.5), ('Ghtdhys,Tt', 0.0), ('Pgpnavamc,Hox', 1.0)], 'Jokyzbnqk,Duzotxx': [('Yegooqb,Pe', 0.5), ('Pudmkoxytg,Drjmgagd', 0.0), ('Aisraw,Ube', 1.0), ('Bdhyuyrtsp,Duek', 1.0)], 'Wkuakpb,Dgbh': [('Pgenlun,Zvzdlt', 1.0), ('Swwddtsuiihd,Dnrcy', 1.0), ('Ekznheqamtuh,Jheqjdav', 0.0), ('Elwseiwxtzdku,Bmekds', 0.5)], 'Hxskpiuc,Drocbww': [('Cqjcevqd,O', 0.5), ('Hgzpfvt,Wghmxoyw', 1.0), ('Xjrclh,Atr', 1.0), ('Mxxneees,Tye', 0.5)], 'Adbkwghh,Rgzvv': [('Ptudpvl,Jlgmb', 0.5), ('Yvraageppi,Ylqovfr', 1.0), ('Tzmgbpdkb,Imczp', 0.5), ('Zzjtenfbcnld,Hjatvtcnd', 1.0)], 'Gpyfucitevs,Oisuit': [('Kyfpoqiexet,Kamdfpb', 1.0), ('Acawvpagzijx,Vggmndxi', 0.0), ('Rdnhvgtnnuu,Qn', 0.0), ('Igwdzonq,Wm', 1.0)], 'Njqwpi,Pqilyuejm': [('Yrhxjvpsczqq,Uumpnur', 1.0), ('Qswfwfwnokwa,Mat', 0.5), ('Vpzmteby,Rslxw', 0.0), ('Rlythvnqq,Ofdluox', 1.0)], 'Edeojwzzg,Cshkin': [('Nbrphcdctgeg,Ckqbbt', 0.0), ('Nubiatp,Mktanfj', 1.0), ('Vrerfb,Erql', 1.0), ('Udxlpptcfhz,Tjntzzs', 0.5)], 'Vsymyutpvs,Gg': [('Bckvyihkda,Gpakipkzd', 0.0), ('Cqvmqo,Wvjvaf', 1.0), ('Qdezmma,Xuokouxu', 0.0), ('Hsbcxjugz,Zmkjdy', 0.5)], 'Dqqxhbat,Q': [('Yiulljjznf,Wdnkqydt', 0.5), ('Qkunncdbxj,Ncwno', 1.0), ('Hlcqli,Ssvvhdg', 1.0), ('Qmgbpwxiowtat,Mfbxw', 1.0)]})
# defaultdict(<class 'list'>, {'Fzcktjubpwx,Lhwz': [('Bgkgytxgzi,Utblvypt', 0.0), ('Ksfkeyfmlosz,B', 0.5), ('Tpaevonak,Lwev', 0.0), ('Htcgbgxuutwjx,Yqans', 0.5)], 'Xyjzakqiuoa,G': [('Ywticwvquu,Uardg', 0.5), ('Wirkpbsn,Aq', 0.0), ('Wlaiearfcbwc,Vqi', 0.5), ('Egivdygqrjapy,F', 1.0)], 'Jgsjpemkgmibz,Eqz': [('Pjumqft,Kijxnyk', 1.0), ('Viysbbk,Zjrgsocc', 0.5), ('Aaxrvkbuamffi,D', 0.0), ('Nugemsycz,Z', 0.5)], 'Ssehlkuo,Eywirfd': [('Zqqdzsh,B', 1.0), ('Czkpzmuijtswb,Fqfn', 0.0), ('Flwrmjeyvwz,Kywkwuygf', 0.5), ('Vcmmlcinxggs,Ecbt', 1.0)], 'Beqsragidv,Hh': [('Qoqgsxirc,Ji', 0.0), ('Agikyvzww,Cqieeame', 0.5), ('Ntxhysq,Daljv', 0.5), ('Jpvijvy,Sutdjs', 1.0)], 'Enqtizgl,T': [('Bqhnwtr,Iabzi', 1.0), ('Uqtbwlrhqi,Puvml', 0.5), ('Qzseiswgpv,U', 1.0), ('Gjxhtewfhler,Imdiey', 1.0)], 'Bnqfwcredlm,Leafu': [('Xlcvrdp,Xz', 0.0), ('Vjvwxp,Xjalm', 1.0), ('Akksqnlbqpu,Holmlpc', 0.5), ('Nfuqefmffywqf,Tify', 0.0)], 'Kljqodjcjczg,Vo': [('Weknqy,Uunjleyb', 1.0), ('Geskcjsfwz,Vorrsudb', 1.0), ('Npznwqopmel,Jwmh', 1.0), ('Sthnzc,Wehx', 1.0)], 'Brtuasu,Ins': [('Icxeqlaqqw,T', 1.0), ('Sljjnslibsypj,Vrmkt', 0.5), ('Veiggvzf,Hyyk', 1.0), ('Opumtf,Mms', 0.0)], 'Ogrbpmmw,Hpfpcwz': [('Ncenmukuy,Rksuy', 1.0), ('Lsnickvmsuksi,Hrzm', 0.0), ('Orfpqyzdrf,Dvf', 0.0), ('Zlwkmb,Fmtbzunv', 1.0)]})
# defaultdict(<class 'list'>, {'Fzcktjubpwx,Lhwz': [('Bgkgytxgzi,Utblvypt', 0.0), ('Ksfkeyfmlosz,B', 0.5), ('Tpaevonak,Lwev', 0.0), ('Htcgbgxuutwjx,Yqans', 0.5)], 'Xyjzakqiuoa,G': [('Ywticwvquu,Uardg', 0.5), ('Wirkpbsn,Aq', 0.0), ('Wlaiearfcbwc,Vqi', 0.5), ('Egivdygqrjapy,F', 1.0)], 'Jgsjpemkgmibz,Eqz': [('Pjumqft,Kijxnyk', 1.0), ('Viysbbk,Zjrgsocc', 0.5), ('Aaxrvkbuamffi,D', 0.0), ('Nugemsycz,Z', 0.5)], 'Ssehlkuo,Eywirfd': [('Zqqdzsh,B', 1.0), ('Czkpzmuijtswb,Fqfn', 0.0), ('Flwrmjeyvwz,Kywkwuygf', 0.5), ('Vcmmlcinxggs,Ecbt', 1.0)], 'Beqsragidv,Hh': [('Qoqgsxirc,Ji', 0.0), ('Agikyvzww,Cqieeame', 0.5), ('Ntxhysq,Daljv', 0.5), ('Jpvijvy,Sutdjs', 1.0)], 'Enqtizgl,T': [('Bqhnwtr,Iabzi', 1.0), ('Uqtbwlrhqi,Puvml', 0.5), ('Qzseiswgpv,U', 1.0), ('Gjxhtewfhler,Imdiey', 1.0)], 'Bnqfwcredlm,Leafu': [('Xlcvrdp,Xz', 0.0), ('Vjvwxp,Xjalm', 1.0), ('Akksqnlbqpu,Holmlpc', 0.5), ('Nfuqefmffywqf,Tify', 0.0)], 'Kljqodjcjczg,Vo': [('Weknqy,Uunjleyb', 1.0), ('Geskcjsfwz,Vorrsudb', 1.0), ('Npznwqopmel,Jwmh', 1.0), ('Sthnzc,Wehx', 1.0)], 'Brtuasu,Ins': [('Icxeqlaqqw,T', 1.0), ('Sljjnslibsypj,Vrmkt', 0.5), ('Veiggvzf,Hyyk', 1.0), ('Opumtf,Mms', 0.0)], 'Ogrbpmmw,Hpfpcwz': [('Ncenmukuy,Rksuy', 1.0), ('Lsnickvmsuksi,Hrzm', 0.0), ('Orfpqyzdrf,Dvf', 0.0), ('Zlwkmb,Fmtbzunv', 1.0)]})
# defaultdict(<class 'list'>, {'Ipliftzaexei,Aqxrle': [('Xtqslh,Wgogzpgpc', 1.0), ('Nnddrndkmwnrd,Y', 0.5), ('Gmxzkrqcrql,Pyjq', 0.5), ('Gluyccruiymxe,Bwpxog', 0.5)], 'Dmkrtygzmajm,Em': [('Ltbcexop,V', 0.0), ('Zefwbtvby,Iecicefw', 0.5), ('Tntrcal,Yu', 0.0), ('Cftgig,W', 0.5)], 'Cxsktgngnvlz,Reajommau': [('Jlxpkhuc,Jofkwib', 0.0), ('Cxchkazd,Xdyp', 0.0), ('Xsdbfwg,Rt', 1.0), ('Dkldpwkxtap,X', 0.0)], 'Gpfemdzjbw,Sbtgyqutk': [('Mjypblfvccfe,To', 1.0), ('Rkutvz,Jbs', 0.5), ('Mdbznbuuz,Qi', 1.0), ('Dzsmzxgu,Yllcs', 0.5)], 'Qpbmlvjfqw,Nzhsrupb': [('Aopxybfwxvokn,Sldgav', 0.5), ('Zvaccwsozgdph,Hfbaemcc', 1.0), ('Qbgucmlvdpw,Fybh', 1.0), ('Duuwjkozfc,F', 0.0)], 'Edkncnoiktv,L': [('Isscqjd,Nlgbc', 0.5), ('Rmtftzau,L', 1.0), ('Zqmcldoi,Cs', 1.0), ('Qwehrkyq,Xlzosdsj', 1.0)], 'Vooeno,J': [('Xdolnzyarsn,I', 1.0), ('Owfvzqx,Irtnqidus', 1.0), ('Rwoclf,R', 0.0), ('Bxqeyxkr,Ofcbl', 0.5)], 'Ydlniedcnh,Zgcbudb': [('Xqqovrat,Lbu', 1.0), ('Jegmbqfvqp,Izffo', 1.0), ('Wrwbddn,Rcs', 0.0), ('Rrnbbeouruha,Ec', 0.5)], 'Bsmtmfp,O': [('Dzkwfvbmvdnkd,Zt', 0.0), ('Zijxvjs,Knfmh', 0.0), ('Mjarlvz,Hdttswpj', 1.0), ('Pyqanf,Zvhrlbmn', 0.5)], 'Cscksw,Fwrdhsbp': [('Jojurzailqoun,Copoeml', 1.0), ('Iqgvlhfct,W', 0.5), ('Qvwbmotvcfb,Dxflsvu', 0.5), ('Iehggapmwttp,Dynqotdpp', 0.0)]})
# defaultdict(<class 'list'>, {'Ipliftzaexei,Aqxrle': [('Xtqslh,Wgogzpgpc', 1.0), ('Nnddrndkmwnrd,Y', 0.5), ('Gmxzkrqcrql,Pyjq', 0.5), ('Gluyccruiymxe,Bwpxog', 0.5)], 'Dmkrtygzmajm,Em': [('Ltbcexop,V', 0.0), ('Zefwbtvby,Iecicefw', 0.5), ('Tntrcal,Yu', 0.0), ('Cftgig,W', 0.5)], 'Cxsktgngnvlz,Reajommau': [('Jlxpkhuc,Jofkwib', 0.0), ('Cxchkazd,Xdyp', 0.0), ('Xsdbfwg,Rt', 1.0), ('Dkldpwkxtap,X', 0.0)], 'Gpfemdzjbw,Sbtgyqutk': [('Mjypblfvccfe,To', 1.0), ('Rkutvz,Jbs', 0.5), ('Mdbznbuuz,Qi', 1.0), ('Dzsmzxgu,Yllcs', 0.5)], 'Qpbmlvjfqw,Nzhsrupb': [('Aopxybfwxvokn,Sldgav', 0.5), ('Zvaccwsozgdph,Hfbaemcc', 1.0), ('Qbgucmlvdpw,Fybh', 1.0), ('Duuwjkozfc,F', 0.0)], 'Edkncnoiktv,L': [('Isscqjd,Nlgbc', 0.5), ('Rmtftzau,L', 1.0), ('Zqmcldoi,Cs', 1.0), ('Qwehrkyq,Xlzosdsj', 1.0)], 'Vooeno,J': [('Xdolnzyarsn,I', 1.0), ('Owfvzqx,Irtnqidus', 1.0), ('Rwoclf,R', 0.0), ('Bxqeyxkr,Ofcbl', 0.5)], 'Ydlniedcnh,Zgcbudb': [('Xqqovrat,Lbu', 1.0), ('Jegmbqfvqp,Izffo', 1.0), ('Wrwbddn,Rcs', 0.0), ('Rrnbbeouruha,Ec', 0.5)], 'Bsmtmfp,O': [('Dzkwfvbmvdnkd,Zt', 0.0), ('Zijxvjs,Knfmh', 0.0), ('Mjarlvz,Hdttswpj', 1.0), ('Pyqanf,Zvhrlbmn', 0.5)], 'Cscksw,Fwrdhsbp': [('Jojurzailqoun,Copoeml', 1.0), ('Iqgvlhfct,W', 0.5), ('Qvwbmotvcfb,Dxflsvu', 0.5), ('Iehggapmwttp,Dynqotdpp', 0.0)]})
# defaultdict(<class 'list'>, {'Udyyekqeveb,Us': [('Yulauhe,Jzzlyx', 0.0), ('Blwlxjtotjv,Iug', 0.0), ('Svzqsagajn,Brviis', 0.0), ('Kiacufjtntn,Goyqzj', 0.0)], 'Mvxfutnavi,Ljwqx': [('Fcoiblqxq,Blrztdu', 1.0), ('Powkvemyl,Cixi', 0.5), ('Iwrqypaj,Dlnknrxa', 0.5), ('Cigcvffkd,Wckziku', 0.0)], 'Ecyiuzppl,Wns': [('Xqedkezkhmtxk,Pdpxrxl', 1.0), ('Yjkgdftowr,Ngksdmerr', 1.0), ('Pgersghzlaw,Bigwydp', 0.0), ('Yrmppwqnjh,Uo', 1.0)], 'Qbavpadpwuwc,Yizgtlpz': [('Zfkmlecwlzxd,Moiig', 0.5), ('Selwdec,Kbbzkchve', 1.0), ('Sbqnebzn,Ywjpaiifp', 0.5), ('Vbmyqmcnchb,Ksl', 1.0)], 'Prbwkovonbszw,G': [('Lqbxcjzuau,Fnnstm', 0.0), ('Lzwteicrrn,Mwbfsv', 0.0), ('Zkzkvjzln,Hjix', 1.0), ('Iweouj,Tyvc', 1.0)], 'Vmdvocyxfijq,Dzuhsrbz': [('Dktorvwkmdjs,Qyme', 0.5), ('Fnlbbtz,Rwiediljt', 1.0), ('Fsbpzktdu,Jeql', 1.0), ('Bkxjqxtw,Fc', 0.0)], 'Oeztzfitnn,Tyqqa': [('Hsyqwphefp,Crdfpuvl', 0.0), ('Yptgktt,Fhsdbpr', 1.0), ('Fuzygzepud,Eeqf', 1.0), ('Ztcxxiw,Yjz', 0.0)], 'Cencahmlvgn,E': [('Kfngiy,Aj', 0.0), ('Gnikxobjccsh,C', 1.0), ('Bzrgmf,Szrlwrv', 1.0), ('Oetppizqjljbn,Revytsfe', 1.0)], 'Wfbnvhwteb,Ut': [('Pxvlicc,Awmhs', 0.0), ('Zylhswkn,S', 0.5), ('Mgxhqodxetecq,De', 0.5), ('Hjsphztarswfg,Vfptxjy', 0.0)], 'Idjhjjw,Fllylwoq': [('Dmtndntgynfk,Jotvpzbs', 0.5), ('Xzqzqhi,Lmtv', 0.0), ('Vchnuvw,Qm', 0.5), ('Qmlsvtnu,Qse', 0.0)]})
# defaultdict(<class 'list'>, {'Udyyekqeveb,Us': [('Yulauhe,Jzzlyx', 0.0), ('Blwlxjtotjv,Iug', 0.0), ('Svzqsagajn,Brviis', 0.0), ('Kiacufjtntn,Goyqzj', 0.0)], 'Mvxfutnavi,Ljwqx': [('Fcoiblqxq,Blrztdu', 1.0), ('Powkvemyl,Cixi', 0.5), ('Iwrqypaj,Dlnknrxa', 0.5), ('Cigcvffkd,Wckziku', 0.0)], 'Ecyiuzppl,Wns': [('Xqedkezkhmtxk,Pdpxrxl', 1.0), ('Yjkgdftowr,Ngksdmerr', 1.0), ('Pgersghzlaw,Bigwydp', 0.0), ('Yrmppwqnjh,Uo', 1.0)], 'Qbavpadpwuwc,Yizgtlpz': [('Zfkmlecwlzxd,Moiig', 0.5), ('Selwdec,Kbbzkchve', 1.0), ('Sbqnebzn,Ywjpaiifp', 0.5), ('Vbmyqmcnchb,Ksl', 1.0)], 'Prbwkovonbszw,G': [('Lqbxcjzuau,Fnnstm', 0.0), ('Lzwteicrrn,Mwbfsv', 0.0), ('Zkzkvjzln,Hjix', 1.0), ('Iweouj,Tyvc', 1.0)], 'Vmdvocyxfijq,Dzuhsrbz': [('Dktorvwkmdjs,Qyme', 0.5), ('Fnlbbtz,Rwiediljt', 1.0), ('Fsbpzktdu,Jeql', 1.0), ('Bkxjqxtw,Fc', 0.0)], 'Oeztzfitnn,Tyqqa': [('Hsyqwphefp,Crdfpuvl', 0.0), ('Yptgktt,Fhsdbpr', 1.0), ('Fuzygzepud,Eeqf', 1.0), ('Ztcxxiw,Yjz', 0.0)], 'Cencahmlvgn,E': [('Kfngiy,Aj', 0.0), ('Gnikxobjccsh,C', 1.0), ('Bzrgmf,Szrlwrv', 1.0), ('Oetppizqjljbn,Revytsfe', 1.0)], 'Wfbnvhwteb,Ut': [('Pxvlicc,Awmhs', 0.0), ('Zylhswkn,S', 0.5), ('Mgxhqodxetecq,De', 0.5), ('Hjsphztarswfg,Vfptxjy', 0.0)], 'Idjhjjw,Fllylwoq': [('Dmtndntgynfk,Jotvpzbs', 0.5), ('Xzqzqhi,Lmtv', 0.0), ('Vchnuvw,Qm', 0.5), ('Qmlsvtnu,Qse', 0.0)]})
# defaultdict(<class 'list'>, {'Uusmqzzonp,Spdd': [('Fhhnqtg,Uszipr', 1.0), ('Ovfwssk,Quh', 1.0), ('Pahaknkju,Pmomhpioo', 1.0), ('Ussyvxrsjtzyd,Xkmdcw', 1.0)], 'Bnjgwxhkbqdrk,Vacuufvs': [('Adylirextac,Tely', 0.0), ('Widntsb,U', 1.0), ('Jopwrfxkp,Zrx', 0.0), ('Xaserm,Wuqemmpk', 0.5)], 'Mbxzytzgt,Rc': [('Cuzgsyt,Nxmah', 1.0), ('Thhbrbvmav,Qzfcz', 0.0), ('Idwvpfzbhcnca,Bg', 0.5), ('Pivstwc,Ec', 0.0)], 'Cdixhhbpbor,Vtf': [('Agabtnsm,Or', 1.0), ('Gfcusxr,Dx', 0.5), ('Udujndaiwbam,Hmcwcxk', 0.0), ('Ldmplu,Tbsbkyucm', 1.0)], 'Twwjugfl,Bgr': [('Gpaiyhvfhiw,Ocu', 0.5), ('Gmoepkrdti,Y', 0.5), ('Rqsekuscjw,Habujhkcj', 1.0), ('Ctuzqgox,Yjnbwj', 1.0)], 'Aqemjpaglt,Ysb': [('Sxgwxoajhrtq,Zclu', 0.0), ('Sylmakkb,Pcg', 0.5), ('Zqagdsa,Gryxmvdd', 0.0), ('Ggmlnkwrceg,Uuc', 0.5)], 'Ndnfcvbqhho,K': [('Valkxj,Hixfz', 0.5), ('Usqjcswdzso,Rtg', 0.5), ('Nwyllpbtqte,Qvb', 0.5), ('Dlbydyzx,Aovk', 0.0)], 'Mpnekrasxyf,Fpjotrsy': [('Ywgdvhaxsfz,Kauokmvkq', 1.0), ('Wfrtkpohawaq,Us', 0.0), ('Mpablvorhyn,Iwxuxvy', 0.0), ('Dulrfdhqe,Mkbgs', 1.0)], 'Kgsdlqppxklm,Wqsvpz': [('Kkygqywdmgcpj,Avlplj', 0.5), ('Tvemkorroluel,Gjh', 1.0), ('Omturkpr,Ge', 0.5), ('Ovgqhkd,Zj', 0.5)], 'Jbhjvvye,Irwkipdpl': [('Tkxnwcbroa,Tl', 0.0), ('Pvuqnf,Ur', 0.0), ('Vaippzo,Pcpmarwg', 1.0), ('Eysbbghjbpb,K', 1.0)]})
# defaultdict(<class 'list'>, {'Uusmqzzonp,Spdd': [('Fhhnqtg,Uszipr', 1.0), ('Ovfwssk,Quh', 1.0), ('Pahaknkju,Pmomhpioo', 1.0), ('Ussyvxrsjtzyd,Xkmdcw', 1.0)], 'Bnjgwxhkbqdrk,Vacuufvs': [('Adylirextac,Tely', 0.0), ('Widntsb,U', 1.0), ('Jopwrfxkp,Zrx', 0.0), ('Xaserm,Wuqemmpk', 0.5)], 'Mbxzytzgt,Rc': [('Cuzgsyt,Nxmah', 1.0), ('Thhbrbvmav,Qzfcz', 0.0), ('Idwvpfzbhcnca,Bg', 0.5), ('Pivstwc,Ec', 0.0)], 'Cdixhhbpbor,Vtf': [('Agabtnsm,Or', 1.0), ('Gfcusxr,Dx', 0.5), ('Udujndaiwbam,Hmcwcxk', 0.0), ('Ldmplu,Tbsbkyucm', 1.0)], 'Twwjugfl,Bgr': [('Gpaiyhvfhiw,Ocu', 0.5), ('Gmoepkrdti,Y', 0.5), ('Rqsekuscjw,Habujhkcj', 1.0), ('Ctuzqgox,Yjnbwj', 1.0)], 'Aqemjpaglt,Ysb': [('Sxgwxoajhrtq,Zclu', 0.0), ('Sylmakkb,Pcg', 0.5), ('Zqagdsa,Gryxmvdd', 0.0), ('Ggmlnkwrceg,Uuc', 0.5)], 'Ndnfcvbqhho,K': [('Valkxj,Hixfz', 0.5), ('Usqjcswdzso,Rtg', 0.5), ('Nwyllpbtqte,Qvb', 0.5), ('Dlbydyzx,Aovk', 0.0)], 'Mpnekrasxyf,Fpjotrsy': [('Ywgdvhaxsfz,Kauokmvkq', 1.0), ('Wfrtkpohawaq,Us', 0.0), ('Mpablvorhyn,Iwxuxvy', 0.0), ('Dulrfdhqe,Mkbgs', 1.0)], 'Kgsdlqppxklm,Wqsvpz': [('Kkygqywdmgcpj,Avlplj', 0.5), ('Tvemkorroluel,Gjh', 1.0), ('Omturkpr,Ge', 0.5), ('Ovgqhkd,Zj', 0.5)], 'Jbhjvvye,Irwkipdpl': [('Tkxnwcbroa,Tl', 0.0), ('Pvuqnf,Ur', 0.0), ('Vaippzo,Pcpmarwg', 1.0), ('Eysbbghjbpb,K', 1.0)]})
# defaultdict(<class 'list'>, {'Eutlylweyevtl,Snj': [('Qlnoxcqo,Nx', 0.5), ('Bnxozom,Qlue', 0.5), ('Zichwvvq,Plkedixcn', 0.0), ('Bflmawckrsovn,Z', 1.0)], 'Dmzesw,Labgche': [('Vexkkegfvgjor,Igp', 1.0), ('Cbfmqbp,Z', 0.5), ('Qehfoz,Gwytwbo', 0.5), ('Dcxsndoxjbeu,Agvtfxr', 0.0)], 'Vguirbzikhl,Klxavqjz': [('Cdmrznzprahrt,Pcg', 0.0), ('Wsmbvvdmrqr,Jx', 0.0), ('Zanftnhkrhav,Clbhkdxop', 0.0), ('Kotpachmuug,Mdvefcz', 1.0)], 'Spnlkirlpk,Fpfiw': [('Whjxlfv,Bkppsqb', 0.5), ('Pbujvvl,Da', 0.5), ('Jrqcebzop,Png', 0.5), ('Latdgvhtrx,Efgdhje', 0.5)], 'Flebrgnrkhpba,Dzb': [('Dvjlpny,Yogsyh', 0.0), ('Krgkfmaebndbd,Yytycyohi', 0.5), ('Dsatpvlkait,A', 0.5), ('Bxzjzeb,Xyu', 1.0)], 'Qpfnvospdmz,Rd': [('Bmvjvk,Fmeoon', 0.0), ('Rfpgfnt,U', 1.0), ('Rfhtnqklxe,Wzwthnq', 1.0), ('Qyxrfvsdpml,Ymlykkqw', 0.5)], 'Cffvygvbk,Rm': [('Sxaascrz,Hty', 0.5), ('Efrmokcch,Pznzgzo', 0.0), ('Jayzxcftyp,Rsinxor', 1.0), ('Hnyhbhzu,Mu', 0.5)], 'Mfmwkcm,Sjtqae': [('Aideoi,Jxqaor', 1.0), ('Prswzyglpgdx,Obzsof', 0.0), ('Avafgb,Bemivg', 0.5), ('Znvdkampjqewt,Iciluvbr', 0.0)], 'Mqhndunintzcl,Nwgcirb': [('Nzriwcu,F', 0.5), ('Nrixsaqepe,Yud', 0.0), ('Aoqotzfzx,Bekgow', 0.0), ('Bynkmkuxov,Ihwrtw', 1.0)], 'Fsttkseplchq,Hkaasc': [('Lhjjea,Slgkljbsn', 1.0), ('Dvlcvtl,Uqlj', 0.5), ('Yuaqqxtb,W', 1.0), ('Uoclwwzugc,Vjcfiqw', 1.0)]})
# defaultdict(<class 'list'>, {'Eutlylweyevtl,Snj': [('Qlnoxcqo,Nx', 0.5), ('Bnxozom,Qlue', 0.5), ('Zichwvvq,Plkedixcn', 0.0), ('Bflmawckrsovn,Z', 1.0)], 'Dmzesw,Labgche': [('Vexkkegfvgjor,Igp', 1.0), ('Cbfmqbp,Z', 0.5), ('Qehfoz,Gwytwbo', 0.5), ('Dcxsndoxjbeu,Agvtfxr', 0.0)], 'Vguirbzikhl,Klxavqjz': [('Cdmrznzprahrt,Pcg', 0.0), ('Wsmbvvdmrqr,Jx', 0.0), ('Zanftnhkrhav,Clbhkdxop', 0.0), ('Kotpachmuug,Mdvefcz', 1.0)], 'Spnlkirlpk,Fpfiw': [('Whjxlfv,Bkppsqb', 0.5), ('Pbujvvl,Da', 0.5), ('Jrqcebzop,Png', 0.5), ('Latdgvhtrx,Efgdhje', 0.5)], 'Flebrgnrkhpba,Dzb': [('Dvjlpny,Yogsyh', 0.0), ('Krgkfmaebndbd,Yytycyohi', 0.5), ('Dsatpvlkait,A', 0.5), ('Bxzjzeb,Xyu', 1.0)], 'Qpfnvospdmz,Rd': [('Bmvjvk,Fmeoon', 0.0), ('Rfpgfnt,U', 1.0), ('Rfhtnqklxe,Wzwthnq', 1.0), ('Qyxrfvsdpml,Ymlykkqw', 0.5)], 'Cffvygvbk,Rm': [('Sxaascrz,Hty', 0.5), ('Efrmokcch,Pznzgzo', 0.0), ('Jayzxcftyp,Rsinxor', 1.0), ('Hnyhbhzu,Mu', 0.5)], 'Mfmwkcm,Sjtqae': [('Aideoi,Jxqaor', 1.0), ('Prswzyglpgdx,Obzsof', 0.0), ('Avafgb,Bemivg', 0.5), ('Znvdkampjqewt,Iciluvbr', 0.0)], 'Mqhndunintzcl,Nwgcirb': [('Nzriwcu,F', 0.5), ('Nrixsaqepe,Yud', 0.0), ('Aoqotzfzx,Bekgow', 0.0), ('Bynkmkuxov,Ihwrtw', 1.0)], 'Fsttkseplchq,Hkaasc': [('Lhjjea,Slgkljbsn', 1.0), ('Dvlcvtl,Uqlj', 0.5), ('Yuaqqxtb,W', 1.0), ('Uoclwwzugc,Vjcfiqw', 1.0)]})
# defaultdict(<class 'list'>, {'Iuyyfpixsg,Vkg': [('Khwpzlmwpes,Jopybx', 1.0), ('Vkeatcn,G', 0.0), ('Hpqdwaswohu,Rbcf', 0.5), ('Vccihue,Ijegbzoja', 1.0)], 'Tfdoddvromj,Klifovg': [('Vjalzkp,Tdxsjs', 0.5), ('Eppeics,Ipvspdw', 0.0), ('Votenxonvk,Uoxqex', 1.0), ('Iisrysnhstgg,Lsiduf', 1.0)], 'Pilhpg,Wwjkvt': [('Lwuxhcp,Cycp', 1.0), ('Pnvkzbebh,Lwttym', 0.0), ('Adjzxzfkx,Tpmfwu', 1.0), ('Nfkczd,Opddrlnof', 0.5)], 'Ublfqawhx,Koorejemc': [('Gtwbubwefnuzt,Wal', 0.5), ('Pkqhuoppcjfjo,Rgnegz', 1.0), ('Ofozslnuc,Ptlof', 0.0), ('Wqrsnggd,Jqma', 0.0)], 'Tlauavnwpces,Cd': [('Rfntbveiueouy,Rhcgapco', 1.0), ('Mhmjxhbh,Scpswwya', 0.5), ('Yuhvzgkqbasi,O', 1.0), ('Ktlgqqeptie,H', 1.0)], 'Xgbkjknzw,Yppn': [('Sbgifh,Imu', 0.5), ('Ceylzzobsam,Yxprtbp', 0.5), ('Jxvubjvfwsglh,Bfu', 1.0), ('Huvgyoa,Eviokguy', 0.5)], 'Lnharwf,Oh': [('Uonvtvgxn,Xzoleuwky', 0.5), ('Wsynhfbwqnmt,Ko', 1.0), ('Fyfnacx,Pg', 0.5), ('Gojfjvulamlg,Jxliwh', 0.5)], 'Pykqqztj,Olarlmgz': [('Bxurrpcce,Nlntdwsie', 0.5), ('Flaargt,I', 0.0), ('Gvorpyzx,Rslzfca', 1.0), ('Bsrpexcctvls,Zifaqmbx', 0.0)], 'Hfaqramswygtb,Bxa': [('Ksbqzc,Hypjr', 0.5), ('Fysqhz,Ydozua', 0.0), ('Uzsyop,Jdztj', 1.0), ('Mumhsdinkr,Qofgucd', 0.0)], 'Cpeawzyrw,Mfd': [('Tkkhtlyjn,Vt', 1.0), ('Jcdbezymq,Pcp', 0.0), ('Pnyvxhhi,Vjqubrfc', 0.5), ('Zctfgcsqaygsj,Rzm', 1.0)]})
# defaultdict(<class 'list'>, {'Iuyyfpixsg,Vkg': [('Khwpzlmwpes,Jopybx', 1.0), ('Vkeatcn,G', 0.0), ('Hpqdwaswohu,Rbcf', 0.5), ('Vccihue,Ijegbzoja', 1.0)], 'Tfdoddvromj,Klifovg': [('Vjalzkp,Tdxsjs', 0.5), ('Eppeics,Ipvspdw', 0.0), ('Votenxonvk,Uoxqex', 1.0), ('Iisrysnhstgg,Lsiduf', 1.0)], 'Pilhpg,Wwjkvt': [('Lwuxhcp,Cycp', 1.0), ('Pnvkzbebh,Lwttym', 0.0), ('Adjzxzfkx,Tpmfwu', 1.0), ('Nfkczd,Opddrlnof', 0.5)], 'Ublfqawhx,Koorejemc': [('Gtwbubwefnuzt,Wal', 0.5), ('Pkqhuoppcjfjo,Rgnegz', 1.0), ('Ofozslnuc,Ptlof', 0.0), ('Wqrsnggd,Jqma', 0.0)], 'Tlauavnwpces,Cd': [('Rfntbveiueouy,Rhcgapco', 1.0), ('Mhmjxhbh,Scpswwya', 0.5), ('Yuhvzgkqbasi,O', 1.0), ('Ktlgqqeptie,H', 1.0)], 'Xgbkjknzw,Yppn': [('Sbgifh,Imu', 0.5), ('Ceylzzobsam,Yxprtbp', 0.5), ('Jxvubjvfwsglh,Bfu', 1.0), ('Huvgyoa,Eviokguy', 0.5)], 'Lnharwf,Oh': [('Uonvtvgxn,Xzoleuwky', 0.5), ('Wsynhfbwqnmt,Ko', 1.0), ('Fyfnacx,Pg', 0.5), ('Gojfjvulamlg,Jxliwh', 0.5)], 'Pykqqztj,Olarlmgz': [('Bxurrpcce,Nlntdwsie', 0.5), ('Flaargt,I', 0.0), ('Gvorpyzx,Rslzfca', 1.0), ('Bsrpexcctvls,Zifaqmbx', 0.0)], 'Hfaqramswygtb,Bxa': [('Ksbqzc,Hypjr', 0.5), ('Fysqhz,Ydozua', 0.0), ('Uzsyop,Jdztj', 1.0), ('Mumhsdinkr,Qofgucd', 0.0)], 'Cpeawzyrw,Mfd': [('Tkkhtlyjn,Vt', 1.0), ('Jcdbezymq,Pcp', 0.0), ('Pnyvxhhi,Vjqubrfc', 0.5), ('Zctfgcsqaygsj,Rzm', 1.0)]})
# defaultdict(<class 'list'>, {'Dbpgufvpd,Smlb': [('Fxjkikupb,Yl', 0.0), ('Wvioykjzpzyby,Dtpashx', 0.5), ('Glhajiprmdzm,Rtwjxt', 0.0), ('Hksjaz,Rvbcanb', 0.0)], 'Ilbqkdiihq,Gm': [('Slwdakasmuvzq,Aky', 1.0), ('Tcjuzwmhh,Rxsauy', 0.0), ('Plfcyhuyzndlp,Qyqs', 1.0), ('Dlchhyooqm,Sjtvvrgtu', 1.0)], 'Mqiarpy,Pzmgr': [('Gqyifnj,Tzlmz', 0.5), ('Fhskhpiyancrd,Yp', 0.0), ('Ajtavrtxzd,Ur', 0.0), ('Fpqwcenwbxdva,Nvxbtc', 1.0)], 'Ivpvzmaz,R': [('Mgpesubyvsceu,Fnterei', 0.5), ('Gbqser,Gugjthyvl', 0.0), ('Qkzkouakfvei,Hcubxdzx', 1.0), ('Yofdeooyrtum,Hxgs', 0.0)], 'Tlhkoba,Wzvhp': [('Ummnskjywphct,L', 0.5), ('Gqufyvnctip,Cnvesqiol', 0.0), ('Vkuafhce,N', 0.0), ('Zjxhohh,Bflto', 1.0)], 'Vookjtwotxnl,Ftkxh': [('Dcrffme,Jwpeyqmr', 0.5), ('Hkynfyu,Sabaycrcs', 0.0), ('Nxqzhvspv,Vweihzqi', 0.5), ('Lwkgwt,Z', 1.0)], 'Nyxfbpdij,Nyjxivz': [('Jpchfmrbjb,Nhe', 1.0), ('Nztqmojy,Zeffzhwg', 0.5), ('Lsepwrkvqbap,Mjp', 1.0), ('Ibusfugfzsj,Imihbbv', 1.0)], 'Illxuowizj,Dj': [('Tleszyeuxi,Aifl', 1.0), ('Inofrxn,R', 1.0), ('Zcjmmgbxzbug,Egj', 0.0), ('Bgnikkjwuitxh,Ognb', 0.5)], 'Zscaxxmduuzq,Cs': [('Udfosvxpykxl,Uso', 0.0), ('Gsbvkuwsjz,Swnzp', 0.0), ('Dyiibcq,Q', 0.5), ('Jdagtiahr,Sks', 1.0)], 'Ysbxjpnboncut,Fak': [('Gjwrxgprxd,X', 0.5), ('Uexecbmxceh,Npegm', 0.5), ('Xtwcsnkzcfcum,Wlzrqrp', 0.0), ('Loedqghtt,Gragytbu', 1.0)]})
# defaultdict(<class 'list'>, {'Dbpgufvpd,Smlb': [('Fxjkikupb,Yl', 0.0), ('Wvioykjzpzyby,Dtpashx', 0.5), ('Glhajiprmdzm,Rtwjxt', 0.0), ('Hksjaz,Rvbcanb', 0.0)], 'Ilbqkdiihq,Gm': [('Slwdakasmuvzq,Aky', 1.0), ('Tcjuzwmhh,Rxsauy', 0.0), ('Plfcyhuyzndlp,Qyqs', 1.0), ('Dlchhyooqm,Sjtvvrgtu', 1.0)], 'Mqiarpy,Pzmgr': [('Gqyifnj,Tzlmz', 0.5), ('Fhskhpiyancrd,Yp', 0.0), ('Ajtavrtxzd,Ur', 0.0), ('Fpqwcenwbxdva,Nvxbtc', 1.0)], 'Ivpvzmaz,R': [('Mgpesubyvsceu,Fnterei', 0.5), ('Gbqser,Gugjthyvl', 0.0), ('Qkzkouakfvei,Hcubxdzx', 1.0), ('Yofdeooyrtum,Hxgs', 0.0)], 'Tlhkoba,Wzvhp': [('Ummnskjywphct,L', 0.5), ('Gqufyvnctip,Cnvesqiol', 0.0), ('Vkuafhce,N', 0.0), ('Zjxhohh,Bflto', 1.0)], 'Vookjtwotxnl,Ftkxh': [('Dcrffme,Jwpeyqmr', 0.5), ('Hkynfyu,Sabaycrcs', 0.0), ('Nxqzhvspv,Vweihzqi', 0.5), ('Lwkgwt,Z', 1.0)], 'Nyxfbpdij,Nyjxivz': [('Jpchfmrbjb,Nhe', 1.0), ('Nztqmojy,Zeffzhwg', 0.5), ('Lsepwrkvqbap,Mjp', 1.0), ('Ibusfugfzsj,Imihbbv', 1.0)], 'Illxuowizj,Dj': [('Tleszyeuxi,Aifl', 1.0), ('Inofrxn,R', 1.0), ('Zcjmmgbxzbug,Egj', 0.0), ('Bgnikkjwuitxh,Ognb', 0.5)], 'Zscaxxmduuzq,Cs': [('Udfosvxpykxl,Uso', 0.0), ('Gsbvkuwsjz,Swnzp', 0.0), ('Dyiibcq,Q', 0.5), ('Jdagtiahr,Sks', 1.0)], 'Ysbxjpnboncut,Fak': [('Gjwrxgprxd,X', 0.5), ('Uexecbmxceh,Npegm', 0.5), ('Xtwcsnkzcfcum,Wlzrqrp', 0.0), ('Loedqghtt,Gragytbu', 1.0)]})
# defaultdict(<class 'list'>, {'Qilxsptcfhdq,A': [('Vsiqsu,Xzjffim', 1.0), ('Zhpxfyojwp,Wjhitoi', 0.0), ('Hlbswqifxuc,Chb', 0.0), ('Eowzwapqmxrwc,Wtbsyk', 1.0)], 'Xcaexs,Ulnaefh': [('Nsnovaenr,Gjid', 0.5), ('Jyoxsgsn,Sdyypmtc', 1.0), ('Sjeusbxlj,Nywqfag', 1.0), ('Daytfdimjwoh,Yozyb', 0.0)], 'Jdczfu,Mginh': [('Skxakleu,Jralk', 1.0), ('Abvixoccd,Ojbnd', 1.0), ('Hgkgunj,Mrz', 0.0), ('Gmufxvqale,Titymucgj', 1.0)], 'Tvmhxxvjkf,Yspbto': [('Edlkofbt,Dgoclla', 1.0), ('Vamsauwy,Rl', 0.5), ('Fkawvmhtyhrkm,Ivk', 1.0), ('Yftnwjnvy,Iemx', 0.5)], 'Qpyfry,Xxl': [('Bqogrslvdzlce,Byk', 0.0), ('Pwqimlvbihb,L', 0.5), ('Vzdegcipqwjs,Uoo', 0.0), ('Llwlmb,Bpg', 0.5)], 'Iobmvexeb,Lgjdwvtyl': [('Hbketd,Swqyfy', 0.5), ('Wzmvsnpls,Jz', 0.0), ('Sjmnarzr,Hrahogbu', 1.0), ('Ojshlvaz,Baqgxg', 0.0)], 'Mnjrijy,Zhorsskl': [('Wsslwrr,Q', 0.0), ('Zngcyneeqpvq,Bwslcapj', 0.5), ('Emcssjaaw,Adlwxjz', 0.5), ('Xjbdseawebwe,Vohnlfx', 0.0)], 'Krgvpyy,Xunn': [('Fymziqi,L', 0.0), ('Zhqroevszdi,X', 0.5), ('Bkfkryvnp,Mzylaqqm', 1.0), ('Idvtawopaex,Lcwxj', 0.0)], 'Iebhwtborlvk,Tskfb': [('Iqfywliplhqs,Ecijc', 1.0), ('Hupbjyqo,Ncf', 0.0), ('Bhrcyqokzkcj,Dshhs', 1.0), ('Npwmuzdy,Hehec', 0.0)], 'Snbkyb,Gdbu': [('Eeffqridlmrf,Kk', 0.0), ('Ozhracj,K', 0.0), ('Cnxvfnqh,Ftk', 1.0), ('Oqxudselu,I', 0.5)]})
# defaultdict(<class 'list'>, {'Qilxsptcfhdq,A': [('Vsiqsu,Xzjffim', 1.0), ('Zhpxfyojwp,Wjhitoi', 0.0), ('Hlbswqifxuc,Chb', 0.0), ('Eowzwapqmxrwc,Wtbsyk', 1.0)], 'Xcaexs,Ulnaefh': [('Nsnovaenr,Gjid', 0.5), ('Jyoxsgsn,Sdyypmtc', 1.0), ('Sjeusbxlj,Nywqfag', 1.0), ('Daytfdimjwoh,Yozyb', 0.0)], 'Jdczfu,Mginh': [('Skxakleu,Jralk', 1.0), ('Abvixoccd,Ojbnd', 1.0), ('Hgkgunj,Mrz', 0.0), ('Gmufxvqale,Titymucgj', 1.0)], 'Tvmhxxvjkf,Yspbto': [('Edlkofbt,Dgoclla', 1.0), ('Vamsauwy,Rl', 0.5), ('Fkawvmhtyhrkm,Ivk', 1.0), ('Yftnwjnvy,Iemx', 0.5)], 'Qpyfry,Xxl': [('Bqogrslvdzlce,Byk', 0.0), ('Pwqimlvbihb,L', 0.5), ('Vzdegcipqwjs,Uoo', 0.0), ('Llwlmb,Bpg', 0.5)], 'Iobmvexeb,Lgjdwvtyl': [('Hbketd,Swqyfy', 0.5), ('Wzmvsnpls,Jz', 0.0), ('Sjmnarzr,Hrahogbu', 1.0), ('Ojshlvaz,Baqgxg', 0.0)], 'Mnjrijy,Zhorsskl': [('Wsslwrr,Q', 0.0), ('Zngcyneeqpvq,Bwslcapj', 0.5), ('Emcssjaaw,Adlwxjz', 0.5), ('Xjbdseawebwe,Vohnlfx', 0.0)], 'Krgvpyy,Xunn': [('Fymziqi,L', 0.0), ('Zhqroevszdi,X', 0.5), ('Bkfkryvnp,Mzylaqqm', 1.0), ('Idvtawopaex,Lcwxj', 0.0)], 'Iebhwtborlvk,Tskfb': [('Iqfywliplhqs,Ecijc', 1.0), ('Hupbjyqo,Ncf', 0.0), ('Bhrcyqokzkcj,Dshhs', 1.0), ('Npwmuzdy,Hehec', 0.0)], 'Snbkyb,Gdbu': [('Eeffqridlmrf,Kk', 0.0), ('Ozhracj,K', 0.0), ('Cnxvfnqh,Ftk', 1.0), ('Oqxudselu,I', 0.5)]})
# defaultdict(<class 'list'>, {'Yenlnctbngeoh,Niix': [('Lftfducyebg,Uiyjb', 0.0), ('Inkjzzee,Jav', 0.5), ('Hkrhrhqcfbxbi,Tnft', 1.0), ('Jwjxpslqcvvt,Djuuk', 0.0)], 'Wkadaknzgmjog,Ugtvsx': [('Yqfzaahh,Tbus', 0.0), ('Cycdxnm,Txoupco', 0.5), ('Kyvlucmnarf,Xtiwbhsu', 0.0), ('Iwbcnpnuxqn,Apirnj', 0.0)], 'Icrlxmefo,Ocqgeopxx': [('Jghuxkcbm,Bs', 0.5), ('Gfkaziwfv,Vwtwumlul', 1.0), ('Sljbsr,Cntr', 0.5), ('Jhtndsiy,Caqlyz', 1.0)], 'Ebvblgw,Bkq': [('Crylwyfyvq,Ywcm', 1.0), ('Bulvkdw,Tiwzo', 1.0), ('Fylioq,Tiga', 1.0), ('Dogfrqfaufgs,Wq', 1.0)], 'Ihdyqsc,Jm': [('Sbtrdghqheai,Kydffyp', 0.5), ('Pgpqibc,Kihs', 0.0), ('Xqzfjtinylfr,Afsnvfvi', 0.5), ('Hpswuf,N', 0.5)], 'Odbfmrk,Tnzcx': [('Djbkxazukqzz,Whqayf', 1.0), ('Zyfwjufhsb,Kzpnxe', 1.0), ('Upgcxcskzgyba,Asafnlyv', 0.5), ('Mnsolg,Yzludeku', 0.5)], 'Liadktzcflf,Myl': [('Hxtuhrtjh,Tbyfrl', 0.0), ('Obrade,R', 0.5), ('Smyhowos,Affz', 0.0), ('Tmiteqk,Cgkwd', 1.0)], 'Mjdotfffyu,Bcjgvyuc': [('Xuecgnsq,Ejy', 0.5), ('Kgygnyghto,Qvqak', 0.5), ('Qrckyplbj,Dwxmlphwf', 0.0), ('Vctjtxzp,Ymqmfqln', 1.0)], 'Easudx,Suosxlik': [('Wnafpqqs,Odfg', 0.0), ('Dqbzrfeowvy,Sbv', 0.0), ('Oouielyxu,Lqgo', 1.0), ('Fhhxanqs,Eyxpte', 1.0)], 'Mmclrxlolwv,Nyyp': [('Mrlyrxzb,P', 0.5), ('Hydxmxlm,Oxpa', 0.0), ('Aidubcnqb,Qqb', 0.0), ('Mukxrxcfqpqn,Xdkf', 0.0)]})
# ...
# defaultdict(<class 'list'>, {'Tgszfjdxigeen,Eqmpvoam': [('Xpwylnu,Wlzmpxh', 0.0), ('Rqjxdsjzihf,Nlrhqlu', 1.0), ('Eihozdstgyubu,Kybqbrtu', 0.0), ('Qlbmqcestrma,Wmelc', 0.0)], 'Amjvgvhcvyzg,Fljvben': [('Fyrcycodigars,Uapvdg', 0.0), ('Xvyfsltqrzr,Isjmrrrg', 0.0), ('Cneqznxqlb,T', 0.5), ('Nzsnephjz,Bpqkc', 1.0)], 'Afmkpdqpla,Mjqmhczci': [('Cyrfxchdnoc,Ntb', 1.0), ('Rvpxenyfg,Yuf', 1.0), ('Snpqbkk,Cqv', 1.0), ('Gzgfuuecgxpkg,Vhjefzrhl', 0.0)], 'Kcgrjwsl,Ehbbw': [('Uqozkpbki,Cmzhfqg', 1.0), ('Fwpuvwltvemiy,Faczb', 0.5), ('Laisqkm,Ira', 0.0), ('Mtsubecbgh,F', 0.0)], 'Gpdzgslezpft,Ufkb': [('Wzxxhkc,Utdm', 0.0), ('Xhrnrdujdn,Y', 0.0), ('Rhofddtfn,Oiv', 0.0), ('Gifvjocidie,Mamjgowx', 1.0)], 'Fwdzcerknmpog,Qf': [('Tkhawoyan,Palpke', 1.0), ('Ickmircfhqblv,Godibaa', 0.0), ('Slspzrmai,Nn', 1.0), ('Jkmtvx,Ftf', 0.5)], 'Mbaedltqlum,Exdrwiu': [('Pnbvxpxga,Ogjoudw', 0.0), ('Wthnolvi,Dqtvj', 0.0), ('Hmubnqksvwibb,Xrnzlqqd', 0.5), ('Rqxjhnnn,Q', 0.0)], 'Tkpsoxfbe,Uw': [('Geruuwbjk,Daggb', 1.0), ('Plvjbioy,Yx', 1.0), ('Rdsnke,Pb', 0.5), ('Mlejhhmr,Cyymtuh', 1.0)], 'Kgsxhnde,Bjfycpb': [('Eowkxjj,Wdhz', 0.0), ('Kaheexjnqlyz,Wd', 1.0), ('Nlpqvunwpk,Fwwkidg', 0.5), ('Pckrlr,Njeau', 1.0)], 'Kzeueehibyt,Awampvo': [('Uyqaczdwe,Oh', 0.0), ('Mipnhi,Wsv', 0.0), ('Sjkzgkn,X', 0.5), ('Tvbyvwsh,Nh', 0.0)]})
# defaultdict(<class 'list'>, {'Tgszfjdxigeen,Eqmpvoam': [('Xpwylnu,Wlzmpxh', 0.0), ('Rqjxdsjzihf,Nlrhqlu', 1.0), ('Eihozdstgyubu,Kybqbrtu', 0.0), ('Qlbmqcestrma,Wmelc', 0.0)], 'Amjvgvhcvyzg,Fljvben': [('Fyrcycodigars,Uapvdg', 0.0), ('Xvyfsltqrzr,Isjmrrrg', 0.0), ('Cneqznxqlb,T', 0.5), ('Nzsnephjz,Bpqkc', 1.0)], 'Afmkpdqpla,Mjqmhczci': [('Cyrfxchdnoc,Ntb', 1.0), ('Rvpxenyfg,Yuf', 1.0), ('Snpqbkk,Cqv', 1.0), ('Gzgfuuecgxpkg,Vhjefzrhl', 0.0)], 'Kcgrjwsl,Ehbbw': [('Uqozkpbki,Cmzhfqg', 1.0), ('Fwpuvwltvemiy,Faczb', 0.5), ('Laisqkm,Ira', 0.0), ('Mtsubecbgh,F', 0.0)], 'Gpdzgslezpft,Ufkb': [('Wzxxhkc,Utdm', 0.0), ('Xhrnrdujdn,Y', 0.0), ('Rhofddtfn,Oiv', 0.0), ('Gifvjocidie,Mamjgowx', 1.0)], 'Fwdzcerknmpog,Qf': [('Tkhawoyan,Palpke', 1.0), ('Ickmircfhqblv,Godibaa', 0.0), ('Slspzrmai,Nn', 1.0), ('Jkmtvx,Ftf', 0.5)], 'Mbaedltqlum,Exdrwiu': [('Pnbvxpxga,Ogjoudw', 0.0), ('Wthnolvi,Dqtvj', 0.0), ('Hmubnqksvwibb,Xrnzlqqd', 0.5), ('Rqxjhnnn,Q', 0.0)], 'Tkpsoxfbe,Uw': [('Geruuwbjk,Daggb', 1.0), ('Plvjbioy,Yx', 1.0), ('Rdsnke,Pb', 0.5), ('Mlejhhmr,Cyymtuh', 1.0)], 'Kgsxhnde,Bjfycpb': [('Eowkxjj,Wdhz', 0.0), ('Kaheexjnqlyz,Wd', 1.0), ('Nlpqvunwpk,Fwwkidg', 0.5), ('Pckrlr,Njeau', 1.0)], 'Kzeueehibyt,Awampvo': [('Uyqaczdwe,Oh', 0.0), ('Mipnhi,Wsv', 0.0), ('Sjkzgkn,X', 0.5), ('Tvbyvwsh,Nh', 0.0)]})
# defaultdict(<class 'list'>, {'Jerimlwqs,Phjwog': [('Ktrktf,Ilmw', 0.5), ('Kvvfpgsore,W', 0.0), ('Cioham,Ukfhiug', 1.0), ('Reinoeh,Ckstwgsl', 0.0)], 'Jwjyxtpewozkh,Xo': [('Sqyoqasec,Obtvvslb', 0.5), ('Xiddguprgxo,Gcwcvkar', 1.0), ('Bblcujhxcq,Euuxyah', 0.0), ('Ilnsuepctys,Dic', 0.5)], 'Iikhlp,Lhrhmkmza': [('Jkogodxja,Rwniyyv', 1.0), ('Wgmqqlnrqrp,Pfmsjhi', 0.5), ('Yzjvtyugs,Bknuuv', 0.0), ('Rnqlfmmek,Hpf', 1.0)], 'Bzvhbizej,X': [('Hmswfmvirmxj,Dgituohyo', 0.0), ('Vlwuqvehpf,W', 1.0), ('Ebgsuwfownwek,Sklhdk', 0.0), ('Rjetuffm,Dkjcln', 1.0)], 'Qniufd,Eigoqk': [('Tcpaoqos,Zzvqea', 0.5), ('Teqjdf,Rogfynotn', 0.5), ('Nhiuvx,Zdsxemez', 0.5), ('Nhrewyvcq,Ookgq', 0.0)], 'Nommbxjuard,Hk': [('Apawpjqaemhr,Lqfh', 0.5), ('Mmhknlcdl,Bwx', 0.5), ('Gerfojimuzlfb,Jpy', 1.0), ('Apwejljmfrh,Uxlewfwk', 1.0)], 'Iweivzmoqxuj,Phepb': [('Ylwzceokdr,Osdyzf', 1.0), ('Lyrwxpm,Xuhwejbh', 0.5), ('Iglwpjhizbipw,Uhb', 0.5), ('Ftzurmcly,Rjawk', 0.5)], 'Syxmato,Sdytyetyy': [('Hvzwohggvhct,K', 0.0), ('Muobnocxsrfw,Vjzma', 1.0), ('Mgthkogqp,Xod', 0.5), ('Prxmzygvhorta,Defgd', 1.0)], 'Qjwzhahiveqiz,Kqmbaj': [('Dvxyfqern,Pjhi', 0.0), ('Uukkbe,Deyhgjlvf', 1.0), ('Ecyhitwfbjve,Pksw', 1.0), ('Vwfaproj,Xvfhoggu', 0.5)], 'Krsbasrqh,Wjgyjq': [('Gwfraelfsgnf,Lyqboqol', 1.0), ('Zugowvingwyi,Grznuk', 0.5), ('Wbfadklevyh,Amxna', 0.5), ('Dyplxvwu,Dwdufji', 0.5)]})
# defaultdict(<class 'list'>, {'Jerimlwqs,Phjwog': [('Ktrktf,Ilmw', 0.5), ('Kvvfpgsore,W', 0.0), ('Cioham,Ukfhiug', 1.0), ('Reinoeh,Ckstwgsl', 0.0)], 'Jwjyxtpewozkh,Xo': [('Sqyoqasec,Obtvvslb', 0.5), ('Xiddguprgxo,Gcwcvkar', 1.0), ('Bblcujhxcq,Euuxyah', 0.0), ('Ilnsuepctys,Dic', 0.5)], 'Iikhlp,Lhrhmkmza': [('Jkogodxja,Rwniyyv', 1.0), ('Wgmqqlnrqrp,Pfmsjhi', 0.5), ('Yzjvtyugs,Bknuuv', 0.0), ('Rnqlfmmek,Hpf', 1.0)], 'Bzvhbizej,X': [('Hmswfmvirmxj,Dgituohyo', 0.0), ('Vlwuqvehpf,W', 1.0), ('Ebgsuwfownwek,Sklhdk', 0.0), ('Rjetuffm,Dkjcln', 1.0)], 'Qniufd,Eigoqk': [('Tcpaoqos,Zzvqea', 0.5), ('Teqjdf,Rogfynotn', 0.5), ('Nhiuvx,Zdsxemez', 0.5), ('Nhrewyvcq,Ookgq', 0.0)], 'Nommbxjuard,Hk': [('Apawpjqaemhr,Lqfh', 0.5), ('Mmhknlcdl,Bwx', 0.5), ('Gerfojimuzlfb,Jpy', 1.0), ('Apwejljmfrh,Uxlewfwk', 1.0)], 'Iweivzmoqxuj,Phepb': [('Ylwzceokdr,Osdyzf', 1.0), ('Lyrwxpm,Xuhwejbh', 0.5), ('Iglwpjhizbipw,Uhb', 0.5), ('Ftzurmcly,Rjawk', 0.5)], 'Syxmato,Sdytyetyy': [('Hvzwohggvhct,K', 0.0), ('Muobnocxsrfw,Vjzma', 1.0), ('Mgthkogqp,Xod', 0.5), ('Prxmzygvhorta,Defgd', 1.0)], 'Qjwzhahiveqiz,Kqmbaj': [('Dvxyfqern,Pjhi', 0.0), ('Uukkbe,Deyhgjlvf', 1.0), ('Ecyhitwfbjve,Pksw', 1.0), ('Vwfaproj,Xvfhoggu', 0.5)], 'Krsbasrqh,Wjgyjq': [('Gwfraelfsgnf,Lyqboqol', 1.0), ('Zugowvingwyi,Grznuk', 0.5), ('Wbfadklevyh,Amxna', 0.5), ('Dyplxvwu,Dwdufji', 0.5)]})
# defaultdict(<class 'list'>, {'Vkvjko,Nti': [('Xsrlddgp,Ow', 0.5), ('Egdwgsrwu,Mhfhhql', 0.0), ('Znobrcawfakx,Sxm', 0.5), ('Kuqspuppeiv,Qvlecn', 0.0)], 'Uhaejfhs,Rjjnibw': [('Tmgrsruek,Bavfvf', 1.0), ('Fjsklbtkytlj,Udpiuo', 1.0), ('Fmpltiebm,Nakguv', 0.0), ('Tyhvhn,A', 0.5)], 'Qbnpovijvc,Mzbmnu': [('Aagomrfnt,Rgsqv', 0.5), ('Hnulnwwpnv,Pvhiuqr', 0.0), ('Htoolbuwwpo,Pphavfpxy', 0.0), ('Bictia,Irmjz', 0.0)], 'Mktihyxpkbmxp,Q': [('Yiazxgwvdkcxa,Cmzhg', 1.0), ('Faxethamju,Xihstspa', 1.0), ('Dqcltwnpqj,Ddbxpac', 0.0), ('Ygmfviii,Gie', 1.0)], 'Qqvbiat,Ewjnzzzsl': [('Cqllaxxz,Jzkm', 1.0), ('Redqzvsayq,Kkzul', 0.5), ('Kawhyvwyyynv,Tu', 1.0), ('Sogstwdblqgj,Yijcjqqc', 1.0)], 'Eiksbseqkvi,Omix': [('Lsuflttypy,Pcin', 1.0), ('Zpjlnwffvtkfh,Foheoaebp', 1.0), ('Fcirfdyegxyrd,Ub', 1.0), ('Ruhkdwrnqmoji,Dj', 1.0)], 'Tyafugbqremzi,Kosqeuj': [('Mzrnedsbjrw,Gfehzsr', 0.0), ('Ruonzor,Naivbudya', 1.0), ('Bivhhfjovz,Juxwy', 0.0), ('Zexgwt,Qpb', 0.5)], 'Apjoraglozbx,Ppcvm': [('Toblmgw,Y', 0.5), ('Mvrhzquzqkmsj,Gzmte', 0.5), ('Xlorjejrxyhk,Mdxjrukmg', 1.0), ('Kgkxtbcrxspk,Bhob', 0.0)], 'Wlnllneqo,Momkujie': [('Czcjzjmf,Xawf', 1.0), ('Aadswaandy,Jkzw', 0.5), ('Zmpulrdzs,Awmohp', 1.0), ('Dexgewp,Zbklatnsq', 0.0)], 'Uaoddmwbtd,Ry': [('Hdkefkmmn,Pxzlxsik', 1.0), ('Wrqrjeyz,Pmw', 0.0), ('Vgagmok,Pqkd', 0.0), ('Utexiqsbcniiv,Skghrzwp', 0.0)]})
# defaultdict(<class 'list'>, {'Vkvjko,Nti': [('Xsrlddgp,Ow', 0.5), ('Egdwgsrwu,Mhfhhql', 0.0), ('Znobrcawfakx,Sxm', 0.5), ('Kuqspuppeiv,Qvlecn', 0.0)], 'Uhaejfhs,Rjjnibw': [('Tmgrsruek,Bavfvf', 1.0), ('Fjsklbtkytlj,Udpiuo', 1.0), ('Fmpltiebm,Nakguv', 0.0), ('Tyhvhn,A', 0.5)], 'Qbnpovijvc,Mzbmnu': [('Aagomrfnt,Rgsqv', 0.5), ('Hnulnwwpnv,Pvhiuqr', 0.0), ('Htoolbuwwpo,Pphavfpxy', 0.0), ('Bictia,Irmjz', 0.0)], 'Mktihyxpkbmxp,Q': [('Yiazxgwvdkcxa,Cmzhg', 1.0), ('Faxethamju,Xihstspa', 1.0), ('Dqcltwnpqj,Ddbxpac', 0.0), ('Ygmfviii,Gie', 1.0)], 'Qqvbiat,Ewjnzzzsl': [('Cqllaxxz,Jzkm', 1.0), ('Redqzvsayq,Kkzul', 0.5), ('Kawhyvwyyynv,Tu', 1.0), ('Sogstwdblqgj,Yijcjqqc', 1.0)], 'Eiksbseqkvi,Omix': [('Lsuflttypy,Pcin', 1.0), ('Zpjlnwffvtkfh,Foheoaebp', 1.0), ('Fcirfdyegxyrd,Ub', 1.0), ('Ruhkdwrnqmoji,Dj', 1.0)], 'Tyafugbqremzi,Kosqeuj': [('Mzrnedsbjrw,Gfehzsr', 0.0), ('Ruonzor,Naivbudya', 1.0), ('Bivhhfjovz,Juxwy', 0.0), ('Zexgwt,Qpb', 0.5)], 'Apjoraglozbx,Ppcvm': [('Toblmgw,Y', 0.5), ('Mvrhzquzqkmsj,Gzmte', 0.5), ('Xlorjejrxyhk,Mdxjrukmg', 1.0), ('Kgkxtbcrxspk,Bhob', 0.0)], 'Wlnllneqo,Momkujie': [('Czcjzjmf,Xawf', 1.0), ('Aadswaandy,Jkzw', 0.5), ('Zmpulrdzs,Awmohp', 1.0), ('Dexgewp,Zbklatnsq', 0.0)], 'Uaoddmwbtd,Ry': [('Hdkefkmmn,Pxzlxsik', 1.0), ('Wrqrjeyz,Pmw', 0.0), ('Vgagmok,Pqkd', 0.0), ('Utexiqsbcniiv,Skghrzwp', 0.0)]})
# defaultdict(<class 'list'>, {'Vwfqgjknb,Culbfafo': [('Qsdwhnwzomiuc,Xrh', 1.0), ('Qgqwwfwxevmf,Eki', 0.5), ('Vfhcjt,Uwfuyffp', 1.0), ('Oidakjhgfshpm,Obbeqhz', 1.0)], 'Lfhdsruqj,Qapqzg': [('Hdjyicq,Zurgqo', 0.5), ('Sjtusjndlvj,Wceimw', 1.0), ('Hgpuol,Jozq', 0.0), ('Wytojsdo,Kx', 1.0)], 'Plyfmwdqhd,Uzynszgkn': [('Nxkjxhdqg,Twfb', 0.5), ('Uuqtvkzxaa,Mpaoj', 0.5), ('Tzeerbhrams,Tgtvalbby', 0.0), ('Mudhylsgz,Gbmso', 0.5)], 'Tfvkuzk,Ascum': [('Armozosmasn,Vgrijypsh', 1.0), ('Voymvyhg,Qycghype', 1.0), ('Ktwfqmytazmb,K', 0.0), ('Ryhzhpvqiz,Vglyn', 0.5)], 'Xrutqvrx,Ebww': [('Kbqblzzeq,Seuh', 1.0), ('Rbwvdjkvolu,Yo', 0.5), ('Fagznkdejbkw,Ek', 1.0), ('Erlgrrkyztb,Fhdroi', 0.5)], 'Dpovsbeafatm,Apfhpp': [('Klvfkpexbrffk,Hwsndz', 0.0), ('Dopwreaf,Xpdetngt', 1.0), ('Jxqeskuuajpb,Kbhkoef', 0.5), ('Iubsppthcae,Ionqg', 0.5)], 'Wnovkuw,Dydrdfiky': [('Wwrbdjpm,Sfvefobxq', 0.5), ('Xnaratkbshloz,Jwdftwt', 1.0), ('Tysnuzr,Lizrx', 0.5), ('Qsausbqc,Tfkkngis', 0.0)], 'Ansszpocn,Sz': [('Fourjdbbo,Laneci', 0.0), ('Wmtitcl,I', 1.0), ('Gnvocr,Smfjie', 1.0), ('Fjdbfzxlbsn,Zw', 0.0)], 'Cgavnsomlmmj,Supnpdeh': [('Uxxlqzfidv,B', 0.0), ('Todqih,Xilmltxhn', 1.0), ('Xtrqweshej,Wr', 0.5), ('Ymkulxrs,Odtqfpz', 0.0)], 'Duyimry,Nyquxzhb': [('Ycwplk,Ctdktldvl', 1.0), ('Vvvcaouyp,Vnif', 0.5), ('Qvghkzjafjhj,Spj', 0.5), ('Nvoujuhegvh,Tf', 0.5)]})
# defaultdict(<class 'list'>, {'Vwfqgjknb,Culbfafo': [('Qsdwhnwzomiuc,Xrh', 1.0), ('Qgqwwfwxevmf,Eki', 0.5), ('Vfhcjt,Uwfuyffp', 1.0), ('Oidakjhgfshpm,Obbeqhz', 1.0)], 'Lfhdsruqj,Qapqzg': [('Hdjyicq,Zurgqo', 0.5), ('Sjtusjndlvj,Wceimw', 1.0), ('Hgpuol,Jozq', 0.0), ('Wytojsdo,Kx', 1.0)], 'Plyfmwdqhd,Uzynszgkn': [('Nxkjxhdqg,Twfb', 0.5), ('Uuqtvkzxaa,Mpaoj', 0.5), ('Tzeerbhrams,Tgtvalbby', 0.0), ('Mudhylsgz,Gbmso', 0.5)], 'Tfvkuzk,Ascum': [('Armozosmasn,Vgrijypsh', 1.0), ('Voymvyhg,Qycghype', 1.0), ('Ktwfqmytazmb,K', 0.0), ('Ryhzhpvqiz,Vglyn', 0.5)], 'Xrutqvrx,Ebww': [('Kbqblzzeq,Seuh', 1.0), ('Rbwvdjkvolu,Yo', 0.5), ('Fagznkdejbkw,Ek', 1.0), ('Erlgrrkyztb,Fhdroi', 0.5)], 'Dpovsbeafatm,Apfhpp': [('Klvfkpexbrffk,Hwsndz', 0.0), ('Dopwreaf,Xpdetngt', 1.0), ('Jxqeskuuajpb,Kbhkoef', 0.5), ('Iubsppthcae,Ionqg', 0.5)], 'Wnovkuw,Dydrdfiky': [('Wwrbdjpm,Sfvefobxq', 0.5), ('Xnaratkbshloz,Jwdftwt', 1.0), ('Tysnuzr,Lizrx', 0.5), ('Qsausbqc,Tfkkngis', 0.0)], 'Ansszpocn,Sz': [('Fourjdbbo,Laneci', 0.0), ('Wmtitcl,I', 1.0), ('Gnvocr,Smfjie', 1.0), ('Fjdbfzxlbsn,Zw', 0.0)], 'Cgavnsomlmmj,Supnpdeh': [('Uxxlqzfidv,B', 0.0), ('Todqih,Xilmltxhn', 1.0), ('Xtrqweshej,Wr', 0.5), ('Ymkulxrs,Odtqfpz', 0.0)], 'Duyimry,Nyquxzhb': [('Ycwplk,Ctdktldvl', 1.0), ('Vvvcaouyp,Vnif', 0.5), ('Qvghkzjafjhj,Spj', 0.5), ('Nvoujuhegvh,Tf', 0.5)]})
# defaultdict(<class 'list'>, {'Bqbkro,Qonzkc': [('Yzaxbxqvaabfm,Ivnwhvn', 0.0), ('Pdjnpyf,Sfaode', 0.5), ('Sypvqp,O', 0.5), ('Ifqyfoi,Zdahoq', 0.0)], 'Rbbixpjfhibqk,Yqoozgk': [('Fcjulhoh,Kjufupi', 1.0), ('Pmmnrcgol,Pv', 0.0), ('Bshafikum,Jttiavovy', 0.5), ('Wlkhutndx,Rkcdiwum', 0.0)], 'Cnaahhic,Aqs': [('Gxmemwjaizjyb,Cyea', 0.5), ('Sskresakuc,Hvbcwnij', 0.0), ('Cqjxpjuyhu,R', 0.5), ('Iipiowwelpewe,Stre', 0.0)], 'Omurwdh,Esu': [('Qlcvknbcl,B', 0.5), ('Yfidqxqzu,Wxvwz', 0.5), ('Fxgszdtaatc,Miczflv', 1.0), ('Qjttixpbwoq,Eh', 0.0)], 'Xbrjltecjry,Mslbuu': [('Jezndboqxhdi,Wdti', 1.0), ('Aiovcuazp,Ozutykia', 0.5), ('Vhbgca,E', 0.5), ('Vamvncagntx,Phlmhq', 0.0)], 'Oalwdbe,Ldqxtwxds': [('Eupeltmi,Hrcbbqxil', 0.0), ('Aozqjuvxjpu,Chvltf', 0.0), ('Pcaysayoqtith,Ngm', 0.0), ('Fkxmkqkx,Owrku', 0.0)], 'Vtcpipg,Va': [('Rbmqcxlrmzzh,C', 0.0), ('Blccruqw,Fuldyv', 0.0), ('Bxjrudxcaegv,Tbb', 0.0), ('Yquksydo,Q', 0.0)], 'Iatzkhocvn,Q': [('Femxfyza,Rgxfbi', 0.0), ('Kakxoyscadmsx,Ftkod', 0.0), ('Eeukiyf,Wr', 0.5), ('Zspelxdl,Jr', 0.5)], 'Dlfcek,Ps': [('Gfvtcmc,C', 0.5), ('Uwimghlvbs,Tvshpgudj', 0.0), ('Vsotkcy,Juynvb', 0.5), ('Xnyebvgzhjovq,L', 1.0)], 'Zqvrdk,Ei': [('Ufrhke,Nphitf', 0.0), ('Gsysvkjq,Rc', 0.0), ('Fvdgobuv,Jt', 1.0), ('Tubegtjtxgkpz,Cjzhrfv', 0.5)]})
# defaultdict(<class 'list'>, {'Bqbkro,Qonzkc': [('Yzaxbxqvaabfm,Ivnwhvn', 0.0), ('Pdjnpyf,Sfaode', 0.5), ('Sypvqp,O', 0.5), ('Ifqyfoi,Zdahoq', 0.0)], 'Rbbixpjfhibqk,Yqoozgk': [('Fcjulhoh,Kjufupi', 1.0), ('Pmmnrcgol,Pv', 0.0), ('Bshafikum,Jttiavovy', 0.5), ('Wlkhutndx,Rkcdiwum', 0.0)], 'Cnaahhic,Aqs': [('Gxmemwjaizjyb,Cyea', 0.5), ('Sskresakuc,Hvbcwnij', 0.0), ('Cqjxpjuyhu,R', 0.5), ('Iipiowwelpewe,Stre', 0.0)], 'Omurwdh,Esu': [('Qlcvknbcl,B', 0.5), ('Yfidqxqzu,Wxvwz', 0.5), ('Fxgszdtaatc,Miczflv', 1.0), ('Qjttixpbwoq,Eh', 0.0)], 'Xbrjltecjry,Mslbuu': [('Jezndboqxhdi,Wdti', 1.0), ('Aiovcuazp,Ozutykia', 0.5), ('Vhbgca,E', 0.5), ('Vamvncagntx,Phlmhq', 0.0)], 'Oalwdbe,Ldqxtwxds': [('Eupeltmi,Hrcbbqxil', 0.0), ('Aozqjuvxjpu,Chvltf', 0.0), ('Pcaysayoqtith,Ngm', 0.0), ('Fkxmkqkx,Owrku', 0.0)], 'Vtcpipg,Va': [('Rbmqcxlrmzzh,C', 0.0), ('Blccruqw,Fuldyv', 0.0), ('Bxjrudxcaegv,Tbb', 0.0), ('Yquksydo,Q', 0.0)], 'Iatzkhocvn,Q': [('Femxfyza,Rgxfbi', 0.0), ('Kakxoyscadmsx,Ftkod', 0.0), ('Eeukiyf,Wr', 0.5), ('Zspelxdl,Jr', 0.5)], 'Dlfcek,Ps': [('Gfvtcmc,C', 0.5), ('Uwimghlvbs,Tvshpgudj', 0.0), ('Vsotkcy,Juynvb', 0.5), ('Xnyebvgzhjovq,L', 1.0)], 'Zqvrdk,Ei': [('Ufrhke,Nphitf', 0.0), ('Gsysvkjq,Rc', 0.0), ('Fvdgobuv,Jt', 1.0), ('Tubegtjtxgkpz,Cjzhrfv', 0.5)]})
# defaultdict(<class 'list'>, {'Lxszlaiz,Rmygpmb': [('Urbzezqcap,Wxdcau', 0.0), ('Hqxnmqorrwo,Wfthdfnm', 1.0), ('Tysaybyppsuk,Ntrb', 1.0), ('Dswupqw,K', 0.0)], 'Vzfsel,Tdalh': [('Azbqsqomp,Qtv', 0.5), ('Bqtcyxba,Cvjgpa', 1.0), ('Yjcnhwestiv,Y', 1.0), ('Pcfbas,Sl', 0.5)], 'Xsniwrpbcvvp,Ayvzwk': [('Qrhuhzgw,Kzapzcer', 0.0), ('Eeoyrgd,Qbbk', 1.0), ('Jsagwv,Ypjrm', 0.0), ('Xdhvbxibb,Jhs', 0.0)], 'Sgiinux,Oeikr': [('Kahukgfc,Whsai', 1.0), ('Idnhlkybq,Cdihnwmei', 0.0), ('Zdlfsefhxins,Sxtwrbpx', 1.0), ('Srgrltovzvhb,Dp', 0.0)], 'Mpwyhuc,Xcf': [('Nuvotzmjk,Uoiw', 0.5), ('Bxowxkuyg,Kxds', 0.0), ('Zeatlvyfkfdh,Jgzokorl', 0.5), ('Hnvmjjoeng,K', 1.0)], 'Xofulff,Wpr': [('Lmrqthdeqbdu,Jlnixo', 0.5), ('Bnyvsmgd,Zgk', 0.5), ('Funhkkqgqo,Lx', 0.0), ('Xokdfduxaen,Obzuoyxl', 0.5)], 'Egrqnkz,Svygdotv': [('Gnvawixybw,Zl', 0.5), ('Qsfnnsh,J', 0.0), ('Noewifblgrnt,Ufgqkkuci', 0.0), ('Pvnxvceuf,Bhey', 0.5)], 'Zxnfdqqhmnq,Aji': [('Vdbcsadzdimp,Vtluvx', 0.5), ('Wqmfdbvdhtnkl,Bkgjyndad', 1.0), ('Zehmoerw,Kxaudh', 1.0), ('Znjqeppk,Libqz', 0.5)], 'Szkykhykco,Bfi': [('Zojebcchuji,Svgya', 0.5), ('Jxjgbztmhg,Ssvswauxo', 0.0), ('Hucuwahegcirn,Xjde', 0.5), ('Bnfdkoqzch,Vvsydnhon', 0.0)], 'Tzhaaloprm,Gmvlczunk': [('Kjspklz,D', 1.0), ('Ermdgnpuvo,Xzcmbq', 0.0), ('Jvoaiicjma,Jx', 0.5), ('Vktwrtwahkcf,Srodula', 1.0)]})
# defaultdict(<class 'list'>, {'Lxszlaiz,Rmygpmb': [('Urbzezqcap,Wxdcau', 0.0), ('Hqxnmqorrwo,Wfthdfnm', 1.0), ('Tysaybyppsuk,Ntrb', 1.0), ('Dswupqw,K', 0.0)], 'Vzfsel,Tdalh': [('Azbqsqomp,Qtv', 0.5), ('Bqtcyxba,Cvjgpa', 1.0), ('Yjcnhwestiv,Y', 1.0), ('Pcfbas,Sl', 0.5)], 'Xsniwrpbcvvp,Ayvzwk': [('Qrhuhzgw,Kzapzcer', 0.0), ('Eeoyrgd,Qbbk', 1.0), ('Jsagwv,Ypjrm', 0.0), ('Xdhvbxibb,Jhs', 0.0)], 'Sgiinux,Oeikr': [('Kahukgfc,Whsai', 1.0), ('Idnhlkybq,Cdihnwmei', 0.0), ('Zdlfsefhxins,Sxtwrbpx', 1.0), ('Srgrltovzvhb,Dp', 0.0)], 'Mpwyhuc,Xcf': [('Nuvotzmjk,Uoiw', 0.5), ('Bxowxkuyg,Kxds', 0.0), ('Zeatlvyfkfdh,Jgzokorl', 0.5), ('Hnvmjjoeng,K', 1.0)], 'Xofulff,Wpr': [('Lmrqthdeqbdu,Jlnixo', 0.5), ('Bnyvsmgd,Zgk', 0.5), ('Funhkkqgqo,Lx', 0.0), ('Xokdfduxaen,Obzuoyxl', 0.5)], 'Egrqnkz,Svygdotv': [('Gnvawixybw,Zl', 0.5), ('Qsfnnsh,J', 0.0), ('Noewifblgrnt,Ufgqkkuci', 0.0), ('Pvnxvceuf,Bhey', 0.5)], 'Zxnfdqqhmnq,Aji': [('Vdbcsadzdimp,Vtluvx', 0.5), ('Wqmfdbvdhtnkl,Bkgjyndad', 1.0), ('Zehmoerw,Kxaudh', 1.0), ('Znjqeppk,Libqz', 0.5)], 'Szkykhykco,Bfi': [('Zojebcchuji,Svgya', 0.5), ('Jxjgbztmhg,Ssvswauxo', 0.0), ('Hucuwahegcirn,Xjde', 0.5), ('Bnfdkoqzch,Vvsydnhon', 0.0)], 'Tzhaaloprm,Gmvlczunk': [('Kjspklz,D', 1.0), ('Ermdgnpuvo,Xzcmbq', 0.0), ('Jvoaiicjma,Jx', 0.5), ('Vktwrtwahkcf,Srodula', 1.0)]})
# Passed!
# '83.3 MiB'

# %% [markdown]
# **Run the following cell, even if you skipped Exercise 5.**
#
# We are loading a pre-computed solution that will be used in the following sections. The first two entries are displayed.

# %%
# Sample result for ex5
player_expected_score = test_utils.read_pickle('player_expected_score')
{k:v for k, v in list(player_expected_score.items())[:2]}
# Out:
# {'Deac,Bogdan-Daniel': 2.827559638896802, 'Giri,A': 4.389932419673484}

# %% [markdown]
# ## Exercise 6 (2 points)
#
# Fill in the function `compute_final_ratings(player_scores, expected_player_scores, player_ratings)` to meet the following requirements:
#
# Given three dictionaries:
#
# * `player_scores`: mapping players (String) to their observed tournament scores (Float)
# * `expected_player_scores`: mapping players (String) to their expected tournament scores (Float)
# * `player_ratings`: mapping players (String) to their pre-tournament Elo ratings (Float)
#
# calculate each player's post-tournament Elo ratings using this formula:
#
# $$\text{Rating}_{\text{post}} = \text{Rating}_{\text{pre}} + 10(\text{Score}_{\text{observed}} - \text{Score}_{\text{expected}})$$
#
# Return a dictionary mapping each player (String) to their post-tournament rating **rounded to the nearest integer**.
#
# You can assume that all keys are common between the three input dictionaries.
#
# For example:
#
# `player_scores = {'Jim Halpert': 3.0, 'Dwight Schrute': 4.0, 'Stanley Hudson': 3.0}`
#
# `expected_player_scores = {'Jim Halpert': 2.736, 'Dwight Schrute': 4.67, 'Stanley Hudson': 2.85}`
#
# `player_ratings = {'Jim Halpert': 1500, 'Dwight Schrute': 1575, 'Stanley Hudson': 1452}`
#
# Results:
# `{'Jim Halpert': 1503, 'Dwight Schrute': 1568, 'Stanley Hudson': 1454}`

# %%
demo_player_scores = {'Jim Halpert': 3.0, 'Dwight Schrute': 4.0, 'Stanley Hudson': 3.0}
demo_expected_player_scores = {'Jim Halpert': 2.736, 'Dwight Schrute': 4.67, 'Stanley Hudson': 2.85}
demo_player_ratings = {'Jim Halpert': 1500, 'Dwight Schrute': 1575, 'Stanley Hudson': 1452}

# %%
def compute_final_ratings(player_scores, expected_player_scores, player_ratings):
    ###
    from collections import defaultdict
    results = defaultdict(int)
    
    for key in player_ratings:
        postRating = player_ratings[key] + (10*(player_scores[key] - expected_player_scores[key]))
        results[key] = round(postRating)
    
    return results
    ###

# Demo
compute_final_ratings(demo_player_scores, demo_expected_player_scores, demo_player_ratings)
# Out:
# defaultdict(int,
#             {'Jim Halpert': 1503,
#              'Dwight Schrute': 1568,
#              'Stanley Hudson': 1454})

# %% [markdown]
# The test cell below runs your function **many times**. Remove or comment out any `print` statements to avoid generating excessive output.

# %%
# `ex6_test`: Test cell
from run_tests import ex6_test
for _ in range(200):
    ex6_test(10, compute_final_ratings)
print('Passed!')

###
### AUTOGRADER TEST - DO NOT REMOVE
###
test_utils.get_mem_usage_str()
# Out:
# Passed!
# '84.3 MiB'

# %% [markdown]
# **Run the following cell, even if you skipped Exercise 6.**
#
# We are loading a pre-computed solution that will be used in the following sections. The first two entries are displayed.

# %%
# Sample result for ex6
player_final_ratings = test_utils.read_pickle('player_final_ratings')
{k:v for k, v in list(player_final_ratings.items())[:2]}
# Out:
# {'Deac,Bogdan-Daniel': 2639, 'Giri,A': 2776}

# %% [markdown]
# ## Exercise 7 (2 points)
#
# The last task we have is to compute the change in rating. This isn't just an intermediate step in Exercise 6, because we have to handle some special cases as well.
#
# Fill in the function `compute_deltas(old_ratings, new_ratings)` to meet the following requirements:
#
# Given dictionaries `old_ratings` mapping players (String) to their pre-tournament Elo ratings (Integer) and `new_ratings` mapping players (String) to their post-tournament Elo ratings, determine the change in each player's rating. Return your result as a dictionary mapping players (String) to their delta (Integer).
#
# Compute the delta as $$\Delta = \text{Rating}_{\text{new}} - \text{Rating}_{\text{old}}$$
#
# If a player is not present as a key in the `old_ratings` input but is present as a key in the `new_ratings` input, then assume this is a new player with a starting rating of `1200`. Likewise, if a player is present as a key in `old_ratings` but is not present in `new_ratings`, assume that player did not play in the tournament and their rating is unchanged.
#
# For example:
#
# `old_ratings = {'Ryan Howard': 1755, 'Dwight Schrute': 1675}`
#
# `new_ratings = {'Michael Scott': 1250, 'Ryan Howard': 1750}`
#
# Should return:
#
# `{'Michael Scott': 50, 'Ryan Howard': -5, 'Dwight Schrute': 0}`

# %%
demo_old_ratings = {'Ryan Howard': 1755, 'Dwight Schrute': 1675}
demo_new_ratings = {'Michael Scott': 1250, 'Ryan Howard': 1750}

# %%
def compute_deltas(old_ratings, new_ratings):
    ###
    from collections import defaultdict
    results = defaultdict(int)
    
    for key in old_ratings:
        results[key] = -123456789
        for new in new_ratings:
            if key == new:
                delta = new_ratings[new] - old_ratings[key]
                results[key] = delta
            elif results[key] == -123456789:
                results[key] = 0
    for key in new_ratings:
        if key not in results:
            results[key] = -123456789
        if results[key] == -123456789:
                results[key] = new_ratings[key] - 1200
    return results
    ###

# Demo
compute_deltas(demo_old_ratings, demo_new_ratings)
# Out:
# defaultdict(int, {'Ryan Howard': -5, 'Dwight Schrute': 0, 'Michael Scott': 50})

# %% [markdown]
# The test cell below runs your function **many times**. Remove or comment out any `print` statements to avoid generating excessive output.

# %%
# `ex7_test`: Test cell
from run_tests import ex7_test
for _ in range(200):
    ex7_test(10, compute_deltas)
print('Passed!')

###
### AUTOGRADER TEST - DO NOT REMOVE
###
test_utils.get_mem_usage_str()
# Out:
# Passed!
# '84.3 MiB'

# %% [markdown]
# ## Wrapping up
# After parsing all of the information from the text file, we can display a summary of the tournament results.

# %%
import pandas as pd
df = pd.DataFrame(index=player_scores.keys())
df['Initial Rating'] = pd.Series(player_ratings)
df['Score'] = pd.Series(player_scores)
df['Expected Score'] = pd.Series(player_expected_score)
df['Final Rating'] = pd.Series(player_final_ratings)
df['Delta'] = pd.Series(test_utils.read_pickle('player_deltas'))
display(df)
# Out:
#                     Initial Rating  Score  Expected Score  Final Rating  Delta
# Deac,Bogdan-Daniel            2627    4.0        2.827560          2639     12
# Giri,A                        2780    4.0        4.389932          2776     -4
# Lupulescu,C                   2656    3.5        3.197736          2659      3
# Aronian,L                     2781    4.5        4.395254          2782      1
# Grischuk,A                    2776    5.0        4.848488          2778      2
# Vachier                       2760    3.0        4.131705          2749    -11
# Mamedyarov,S                  2770    5.5        4.278985          2782     12
# So,W                          2770    5.0        4.764597          2772      2
# Caruana,F                     2820    3.5        4.876846          2806    -14
# Radjabov,T                    2765    3.0        3.288897          2762     -3

# %% [markdown]
# **Fin!** You’ve reached the end of this part. Don’t forget to restart and run all cells again to make sure it’s all working when run in sequence; and make sure your work passes the submission process. Good luck!
